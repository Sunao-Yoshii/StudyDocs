# %% [markdown]
# ### まずはライブラリのインポート

# %%
# Load class room dump.
import pickle

# Regex
import re

# Import class room
from class_rooms import ClassRoom

# pandas セット
import pandas as pd
from pandas import DataFrame
import numpy as np

# pip install janome
from janome.tokenizer import Tokenizer

# %% [markdown]
# ### 勉強会データの読み込みと、データ加工の準備
#
# 勉強会の名称バックアップを読み込んで

# %%
# load class rooms
class_rooms = []
with open('backup.pickle', 'rb') as f:
    class_rooms.extend(pickle.load(f))

# %% [markdown]
# 品詞分解後の格納リストを用意する

# %%
# to lists
tokenized_list = []

# Tokenized
cur_idx = 0
tokenizer = Tokenizer()

# %% [markdown]
# 記録したく無い名前（ここでは「数字記号のみ」「テコンドー」「練習」みたいな名詞は無視＋一文字はキーワードと認めない）を決め打ちする。
# これだけだと、R言語とかが割を食うけど、まぁ今回は諦め。
#
# 形態素解析しながらリストを作成していく（ただし、一つの勉強会タイトル中に複数回同じ単語が出たらカウントしない）。

# %%
# ただしここで列挙されるような単語は記録しない
remove_names = ['^[0-9\/\(\)\!]+$', '[#\*]', 'テコンドー', '練習']
def is_valid(value: str):
    if len(value) <= 1:
        return False
    for r in remove_names:
        if re.match(r, value):
            return False
    return True
    

# 勉強会を形態素解析して、名詞単位の行に分割
for cr in class_rooms:
    tokens = tokenizer.tokenize(cr.title)  # 形態素解析
    already = []  # 既出名詞

    for token in tokens:
        pos = token.part_of_speech.split(',')[0]  # 品詞名取得

        if ('名詞' in pos) and (token.surface not in already) and is_valid(token.surface):
            # 新出の名詞なら
            already.append(token.surface)
            tokenized_list.append(
                [cur_idx, token.surface, cr.joins, cr.limit])
    cur_idx += 1

# %% [markdown]
# リスト化したら、ヘッダをつけて Pandas に食わせ、DataFrame に変換する。

# %%
# Pandas DataFrame 変換
cr_df = DataFrame(data=tokenized_list, columns=['index', 'surface', 'joins', 'limit'])
cr_df
# Out:
#       index      surface  joins  limit
# 0         0           体験      0      5
# 1         0           歓迎      0      5
# 2         0           自分      0      5
# 3         0           可能      0      5
# 4         0           東京      0      5
# 5         0          下北沢      0      5
# 6         1         パルフェ      5    120
# 7         1           閉館      5    120
# 8         1          ラスト      5    120
# 9         1         イベント      5    120
# 10        1           全館      5    120
# 11        1          シェア      5    120
# 12        1        AZITO      5    120
# 13        1        プレゼンツ      5    120
# 14        1        ファイナル      5    120
# 15        1           祭り      5    120
# 16        2           楽園      2     10
# 17        2  エンデューロマッドネス      2     10
# 18        2           体験      2     10
# 19        2           in      2     10
# 20        2           タイ      2     10
# 21        3          全日本      0     10
# 22        3         カラオケ      0     10
# 23        3          バトル      0     10
# 24        3           GP      0     10
# 25        3         mini      0     10
# 26        3           予選      0     10
# 27        3           兵庫      0     10
# 28        3           神戸      0     10
# 29        3           大会      0     10
# ...     ...          ...    ...    ...
# 5063    892           強化     82     55
# 5064    892           学習     82     55
# 5065    892           最適     82     55
# 5066    893           量子     66     55
# 5067    893          ゲート     66     55
# 5068    893       アニーリング     66     55
# 5069    893      プログラミング     66     55
# 5070    894           量子     61     55
# 5071    894       コンピュータ     61     55
# 5072    894           化学     61     55
# 5073    894           全般     61     55
# 5074    895           衛星     79     51
# 5075    895           画像     79     51
# 5076    895           地表     79     51
# 5077    895           物体     79     51
# 5078    895           認識     79     51
# 5079    895           分類     79     51
# 5080    896           年度      0     20
# 5081    896         オープン      0     20
# 5082    896           新入      0     20
# 5083    896           社員      0     20
# 5084    896         Java      0     20
# 5085    896           AI      0     20
# 5086    896           研修      0     20
# 5087    897        スプラウト      0      0
# 5088    897           rb      0      0
# 5089    898           関西     14     50
# 5090    898           日曜     14     50
# 5091    898           数学     14     50
# 5092    898          友の会     14     50
#
# [5093 rows x 4 columns]

# %% [markdown]
# ### 簡単にキーワード抽出
#
# まずは際頻出キーワード集計する。
# 色々行なっているけど、行ごとに説明すると
#
# 1. キーワードでグループ化＋集計する。
#    この時点で、「キー:件数」の pandas.Series 型に変換される。
# 2. カウント数がこのままだと加工しづらいので、DataFrame に変換する。
#    reset_index をしてやることで、インデックス行が自動で作成され、ちゃんと合計数に count のラベルがつく
# 3. count が 10 以上の物を、逆順ソートで取得

# %%
group_sizes = cr_df.groupby('surface').size()
gs_df = DataFrame({ 'count': group_sizes }).reset_index()
gs_df[gs_df['count'] > 10].sort_values('count', ascending = False)
# Out:
#         surface  count
# 1319         勉強    102
# 746        もくもく     71
# 625          in     66
# 947        セミナー     57
# 1277         入門     55
# 1916         開催     50
# 1357         向け     49
# 1610         東京     48
# 1303        初心者     44
# 110   CoderDojo     41
# 21           AI     40
# 414      Python     40
# 1256         体験     37
# 1684         無料     36
# 1867         講座     35
# 1645         歓迎     32
# 723          ため     31
# 1226         交流     30
# 1086    プログラミング     30
# 674         vol     27
# 1665         活用     25
# 801       エンジニア     25
# 1402         大阪     25
# 1918         開発     22
# 1344         参加     22
# 1039       ビジネス     21
# 1863         読書     20
# 1017      ハンズオン     20
# 292          LT     20
# 988        デザイン     19
# 572         Web     19
# 1415         学習     19
# 529       Tokyo     19
# 321      Meetup     18
# 1355        名古屋     18
# 992         データ     17
# 564         Vol     17
# 243          IT     17
# 1395         大会     15
# 1640         機械     14
# 769         アプリ     14
# 1925         限定     13
# 1440         実践     13
# 1382         基礎     13
# 1790         統計     13
# 1534         技術     12
# 761         アップ     12
# 1204        下北沢     12
# 1192    ワークショップ     12
# 1922         関西     11
# 1350         可能     11
# 1675         渋谷     11
# 1631         業種     11
# 106       Cloud     11
# 427         RPA     11
# 1249         会場     11

# %% [markdown]
# この中から技術単語を拾うと
#
# 1. AI : 40
# 2. Python : 40
# 3. デザイン : 19
# 4. Web : 19
# 5. 機械(学習) : 14
# 6. 統計 : 13
# 7. Clowd : 11
# 8. RPA : 11
#
# 勉強会の開催頻度だけで見ると、AI(with Python)がダントツ。
# どれだけ注目されているかがよくわかる。
#
# ちなみに、「機械」に関しても以下を見ればわかるが、全て機械学習。
# AI と被ってる勉強会は 3 件だけなので、重複排除で見れば
#
# 1. AI : 50
# 2. Python : 40
# 3. デザイン : 19
# 4. Web : 19
# 5. 統計 : 13
# 6. Clowd : 11
# 7. RPA : 11

# %%
for cr in class_rooms:
    if '機械' in cr.title:
        print(cr)
# Out:
# ClassRoom(【実務で使える機械学習講座】経験豊富なデータサイエンティストが基礎から実務レベルまで教えます, 20, 0)
# ClassRoom(【初参加者向け】【少人数制】AI・機械学習と数学・プログラミングの学び方, 5, 0)
# ClassRoom(Python機械学習入門, 3, 0)
# ClassRoom(機械学習論文輪読­­会(NIPS他) by Team AI 4/10(水), 17, 4)
# ClassRoom(音 x 機械学習はどこまで実現できているか？ - 最新理論とユースケース -, 25, 0)
# ClassRoom(PyData.Fukui  AI機械学習コラボでコラボ, 4, 4)
# ClassRoom(第四陣 信玄パイ「機械学習を業務で利用するのに必要なこと」, 10, 5)
# ClassRoom(【無料ワークショップ@大阪】機械学習を成功させるためのデータ前処理と特徴量エンジニアリング（再演）, 66, 11)
# ClassRoom(【デモ】iPadで AI:人工知能・ML:機械学習を体験, 20, 7)
# ClassRoom([機械学習/DL/TDA]ReNom User Group (RNUG) #11, 80, 49)
# ClassRoom(第18回　機械学習超入門, 6, 4)
# ClassRoom(第17回　機械学習超入門, 6, 6)
# ClassRoom(パターン認識と機械学習(下) by Christopher M. Bishop 輪読会 #11, 12, 8)
# ClassRoom(4AI #2 - 機械学習(基礎 & 自然言語処理), 35, 5)

# %% [markdown]
# 統計も機械学習じゃないか？と思って見てみたが、AI に関連したものは 2 件のみ。
# それを移動すると
#
# 1. AI : 52
# 2. Python : 40
# 3. デザイン : 19
# 4. Web : 19
# 5. 統計 : 11
# 6. Clowd : 11
# 7. RPA : 11

# %%
for cr in class_rooms:
    if '統計' in cr.title:
        print(cr)
# Out:
# ClassRoom(【Facebookのデータサイエンティスト】が基礎から実務レベルまで教える統計＋R講座, 20, 0)
# ClassRoom(『ベイズ統計モデリング―R,JAGS,Stanによるチュートリアル―』読書会 #16, 8, 4)
# ClassRoom(【AI】第3回 【統計・情報科学専攻】学生向け ビジネスへのAI適用勉強会 in 名古屋, 20, 0)
# ClassRoom(【AI】第1回  【統計・情報科学専攻】学生向け ビジネスへのAI適用勉強会 in 名古屋, 10, 0)
# ClassRoom(@大阪淀屋橋開催　第14回 文系のための「統計超入門セミナー」 ～目で見てわかるビジネス統計学, 6, 3)
# ClassRoom(【上級者も歓迎】ハンズオンで学ぶ実践的ベイズ統計モデリング【発展編】, 5, 2)
# ClassRoom(@大阪淀屋橋開催　第15回 文系のための「統計超入門セミナー」 ～目で見てわかるビジネス統計学, 6, 2)
# ClassRoom(@新橋回　第2回 文系のための「統計超入門セミナー」 ～目で見てわかるビジネス統計学～, 6, 3)
# ClassRoom(第211回 文系のための「統計超入門セミナー」 ～目で見てわかるビジネス統計学～, 8, 0)
# ClassRoom(第212回 文系のための「統計超入門セミナー」 ～目で見てわかるビジネス統計学～, 8, 2)
# ClassRoom(第210回 文系のための「統計超入門セミナー」 ～目で見てわかるビジネス統計学～, 8, 1)
# ClassRoom(第209回 文系のための「統計超入門セミナー」 ～目で見てわかるビジネス統計学～, 8, 0)
# ClassRoom(ゼロからまなぶ統計学(Python編), 10, 0)

# %% [markdown]
# ### 勉強会のトレンドは…
#
# **機械学習（AI）で決まり** というのは流石に議論の余地はなさそう。
# では隠れた需要はあるのか？
#
# つまり、勉強会自体の開催は少ないが、注目度の高いものはあるのか？
#
# ということで考えてみる。
# これは普通に考えれば、「参加したい人数/募集人数」でスコアリングしてやれば良さそうなのだけど、問題は募集人数不明の奴らである。
#
# これはみてみると結構いる。
#
# 単純に、モールとかで開催通知だけする（何人来てもOK）もあれば、単に募集人数書いてなさそうなだけの奴もいる。

# %%
for cr in class_rooms:
    if cr.limit == 0:
        print(cr.title)
# Out:
# ★第4土曜日・BACHAFIESTA NIGHT
# 2019年春　M3前日飲み会
# 2019年春 M3前日練習会
# ★4/27(土)28(日)29(月祝)東京ベッド『柏工場大開放セール！』
# ★4/27(土)28(日)29(月祝)フランスベッド・東京工場『ベッド・ソファセール！』
# ★4/27(土)28(日)29(月祝)カリモク家具鶴見アウトレット『理由(ワケ)ありフェア！』
# 腹筋さん退職壮行会
# ★第3土曜日・FIESTAMIGOS NIGHT
# BIT VALLEY -INSIDE- Vol.8
# ★第2土曜日・ VIENTO SALSA NIGHT
# 17周年記念イベント　ネットショップカンファレンス2019
# ワイワイ麻雀
# メーン会場のセルフ誕生日会 〜一斗缶ビリヤニピクニック編〜
# ★4/13(土)14(日)東京ベッド『柏工場大開放セール！』
# OSS活用勉強会 第12回(2019) 勉強会
# Arinite | Health and Safety Consultants
# アナタのための“トクベツ”なマルシェ！Dear Venus Marche VOL.5 ‐ spring ‐
# 不祥事対策と「健全に儲け続けるための仕組み」の本質・課題・実効性向上策
# 監査人のための職業的懐疑心・予兆把握スキルアップ講座
# 「手づくりマルシェ　ハルフェス2019」
# 🔸４/７（日）開催！春のそろばんフェスティバル！🔸
# ★第1土曜日・ NAOBON BACHATA NIGHT
# ★4/6(土)7(日)フランスベッド・東京工場『ベッド・ソファセール！』
# ★4/6(土)7(日)カリモク家具鶴見アウトレット『理由(ワケ)ありフェア！』
# Agen Poker Online Android
# CoderDojo日進 子供向けプログラミング道場　2019/04/27
# 第9回コーダー道場名護（会場：ヒューマンキャンパス高等学校・名護本校）
# 第8回コーダー道場名護（会場：名護市マルチメディア館）
# BlockChain on the Cloud
# 第125回オープンソースサロン
# Glodiaもくもく会 #9
# (2019/4/20PM)第71回オープンCAE勉強会@関西
# データサイエンス勉強会 第5回
# ALGYAN4周年　IoT祭り2019『IoTとAIとセキュリティ』大講演会＆豪華ノベルティ抽選会！
# 第16回 #hiro_it（4/14開催）
# Python for Finance読書会#7~ 第7章前半(旧fin-py読書会)
# 新しい量子化学―電子構造の理論入門〈上〉輪講その12
# OpenCensus meetup vol.1
# 3D CADを使いこなそう勉強会
# 第16回4月ゆるもく合宿
# アジャイルコーチング読書会 第4回(外苑前)
# 第12回CAE勉強会&相談会
# 第2回CoderDojo小机
# 【メンター、見学受付専用】第1回CoderDojo日吉
# BPLL #32
# AI・IoTを活用したい人のためのIPネットワーク入門
# もくもく執筆会☆出張版 REV.20 @ 神田神保町 〜技術系同人誌／商業誌・発表資料・ブログ〜
# 第15回-Nomikai KYOTO ゲーム業界交流会
# ScratchDojo 原　…N002
# ScratchDojo 原　…N001
# 第8回 CoderDojo厚木
# 第39回CoderDojo浜松
# CoderDojo伊那 #001
# 第86回 ProofCafe
# CoderDojo天白-N045
# CoderDojo天白-N044
# 2019/4/6 CoderDojo港北ニュータウン第4回@横浜センター南駅
# Flutterもくもく自習室 in スタディプラス #2
# IBM Cloud Community Summit 2019.04 打ち合わせ #10
# IBM Cloud Community Summit 2019.04 打ち合わせ #9
# IBM Cloud Community Summit 2019.04 打ち合わせ #8
# IBM Cloud Community Summit 2019.04 打ち合わせ #7
# OSS Gate東京ミートアップ for Red Data Tools in Speee
# CoderDojo日進 子供向けプログラミング道場　2019/04/13
# ehime.rb（愛媛の地域 Ruby・Rails コミュニティ）
# Open Source UN-Conference 2019 Kawagoe 当日スタッフ集合
# 第6回CoderDojoあざみ野(横浜青葉)
# プリッカソン #7 (プリリズ/プリパラ/プリチャン)
# E2F 組込みエンジニアフォーラム 第9回交流会
# 【無料】第２回リスクマネジメントセミナー【恵比寿】
# AI開発カリキュラム『LAD』開講説明会
# プログラミングLT 2019
# 一般社団法人PyCon JP運営会議 #29
# 第22回 CoderDojo長津田
# AI実践入門！NVIDIA Jetson TX2×Azure GPU生体験ハンズオン@大阪TEQS
# IoT入門セミナー！センスウェイLoRaWANハンズオン@ひろしまCamps
# IWDD (vol.150) / アイーナ816部屋 14:00〜
# スプラウト.rb 第５８回

# %% [markdown]
# 少し乱暴だけど、平均値でも… *ホワッツ！？*

# %%
sum_of_limit = 0
limit_exists = 0

for cr in class_rooms:
    if cr.limit != 0:
        print(f'limit: {cr.limit},  title: {cr.title}')
        limit_exists += 1
        sum_of_limit += cr.limit

avg_limit = sum_of_limit / limit_exists
avg_limit
# Out:
# limit: 5,  title: 4/30 テコンドー練習会 (体験歓迎) ～新しい自分に出会い、自分の可能性を見つけよう～ 【東京・下北沢】
# limit: 120,  title: 【4/30パルフェ閉館ラストイベント/全館シェア】寒軍AZITOプレゼンツ！ファイナル祭り！！【ありがとうございました】
# limit: 10,  title: 楽園会エンデューロマッドネス体験 in タイ
# limit: 10,  title: 2019/04/29 全日本カラオケバトル2020GP 第10回mini予選 兵庫県神戸(カラオケ大会/ボーカルコンテスト)
# limit: 10,  title: 2019/04/29 全日本カラオケバトル2020GP 第9回mini予選 大阪府大阪(カラオケ大会/ボーカルコンテスト)
# limit: 3,  title: 【初心者限定】Unity１日集中講座〜少人数クラスの１日講習（応用編）
# limit: 5,  title: 4/28 テコンドー練習会 (体験歓迎) ～新しい自分に出会い、自分の可能性を見つけよう～ 【東京・下北沢】
# limit: 10,  title: 2019/4/28 全日本カラオケバトル2020GP 第8回mini予選 愛知県名古屋(カラオケ大会/ボーカルコンテスト)
# limit: 30,  title: ガンオンイベント２０１９ in LFS池袋
# limit: 3,  title: 【初心者限定】Unity１日集中講座〜少人数クラスの１日講習（基礎編）
# limit: 10,  title: 2019/4/28 全日本カラオケバトル2020GP 第7回mini予選 静岡県浜松(カラオケ大会/ボーカルコンテスト)
# limit: 15,  title: 【4/27(土曜日)】第二回English人狼パーティ
# limit: 12,  title: 4月27日(土) 第1回 初心者人狼ゲーム会
# limit: 20,  title: 練習会 #33
# limit: 10,  title: 2019/04/27 全日本カラオケバトル2020GP 第6回mini予選 神奈川県青葉台(カラオケ大会/ボーカルコンテスト)
# limit: 3,  title: 女性のフィロソフィー＆心理本の読書会４／２７
# limit: 30,  title: 第14回名古屋ＳＦ読書会　山田正紀『宝石泥棒』
# limit: 4,  title: なんでもハッカソン・ゴールデンウィーク@関東地方
# limit: 10,  title: 2019/04/27 全日本カラオケバトル2020GP 第5回mini予選 八王子コートダジュール(カラオケ大会/ボーカルコンテスト)
# limit: 30,  title: ニド系オフ1904（ポケモン+カラオケ+64+ゆびふるトナメ）
# limit: 60,  title: 残り３名★4/26(金)【６０名】恋活・友作・婚活！梅田個室居酒屋貸切！花金メガコンパパーティイベント(*・∀・)豪華10品コース料理！≪おものみ関西・飲み会・交流・人脈・オフ会・婚活・出会い・街コン・大阪・友つく・異業種交流会≫
# limit: 100,  title: 女性が主役の異業種交流会開催！！
# limit: 10,  title: 年収300万円あれば出来る、マンション経営！※参加者全員にマンション経営DVD無料プレゼント！
# limit: 10,  title: 【告知のみ】Wiresharkによる無線LANパケット解析セミナ【お手数ですがお申込ご参加は弊社HPよりお願いします】
# limit: 3,  title: 【初心者限定】Unityで作るVR講座〜Oculus Goの基本を学ぶ
# limit: 10,  title: 【告知のみ】Wiresharkによるパケットキャプチャとトレンド分析応用【お手数ですがお申込ご参加は弊社HPよりお願いします】
# limit: 8,  title: 4/25 池袋・実践読書会 ～イケジツ読書会～ [朝活] 本を読んで実行しよう! 【東京都】
# limit: 20,  title: 【実務で使える機械学習講座】経験豊富なデータサイエンティストが基礎から実務レベルまで教えます
# limit: 10,  title: 信頼できる不動産査定書の見極めセミナー
# limit: 12,  title: １ヶ月で社員が変わる！ 自ら行動し結果を出す Super Team を構築する意識改革プログラム 体験セミナー付説明会
# limit: 30,  title: 【2019年04月24日：東京開催】人工知能テクノロジーを実ビジネスに取入れるには？ Vol.55 (日本IBM)
# limit: 15,  title: 【告知のみ】Wiresharkによる パケットキャプチャと トレンド分析入門【お手数ですがお申込ご参加は弊社HPよりお願いします】
# limit: 5,  title: あなたが、あらゆる目標へ達成できる人になる 「科学的コーチング」セミナー
# limit: 5,  title: 4/23 テコンドー練習会 (体験歓迎) ～新しい自分に出会い、自分の可能性を見つけよう～ 【東京・下北沢】
# limit: 30,  title: 守谷ビジネス交流会
# limit: 30,  title: エキテン&JWPPコラボセミナー（名古屋） / 明日から使える 店舗集客のための ウェブマーケティング
# limit: 10,  title: 生命保険営業が知っておくべき「老後と相続対策」の勉強会
# limit: 30,  title: 【4月23日開催】 楽天・ヤフーショッピング　モール・自社サイトで売れるための店舗分析セミナー
# limit: 3,  title: 6月株主総会に向け「自動昇降式スピーチプロンプター活用セミナー」4月22日実施
# limit: 5,  title: 4/22 韓国語入門朝活 (新大塚/大塚) ～ハングル読めなくてOK～【東京・無料】
# limit: 5,  title: 4/21 テコンドー練習会 (体験歓迎) ～新しい自分に出会い、自分の可能性を見つけよう～ 【東京・下北沢】
# limit: 10,  title: 親が元気なうちに、子が考えるべき相続対策（後編）
# limit: 10,  title: 親が元気なうちに、子が考えるべき相続対策（前編）
# limit: 12,  title: 4月のプログラマーズカフェ 2019
# limit: 20,  title: 【大阪開催（1）】えっ！中高年は食事制限じゃダメなの？！枝光聖人の「らくらくダイエットセミナー」@高槻市駅　徒歩4分（心身健康倶楽部 高槻店）
# limit: 10,  title: 第２４回　現代思想読書会　『イマージュの肉　絵画と映画のあいだのメルロ＝ポンティ』その２
# limit: 200,  title: 4/20(土)２００名【恋活★婚活】Special Spring Pink PARTY in心斎橋「THE PINK」の招待状(*・∀・)<オールピンクで彩られ、高揚感を与える魅惑の空間、"THE PINK"にてラグジュアリーな交流を♪大阪No,1パーティイベント★モンスターエナジードリンク協賛★マジシャンブースあり★
# limit: 10,  title: 大仏くんの気ままにマネー講座
# limit: 20,  title: （無料）「人材測定コンサルタントⓇ」認定講座説明会【東京】～日本初！人事評価・採用担当者向けの専門資格がついに登場！～
# limit: 17,  title: 【イコラーオフ会のご案内】
# limit: 32,  title: 4月20日(土)ポケモンgoトレーナーバトル立川大会＆交流会
# limit: 3,  title: 関西美術館制覇クラブ ☆クリスチャン・ボルタンスキーを観に行こう！
# limit: 20,  title: 【定員２０名】マキシマム ザ ホルモン　カラオケオフ会
# limit: 20,  title: ITエンジニア学生ぴよぴよ会＠うべ
# limit: 45,  title: 【4/20(土)】第60回　立川ゲームパーティ【人狼もボドゲも楽しんじゃおう】
# limit: 20,  title: 年収300万円あれば出来る、マンション経営！※参加者全員にマンション経営DVD無料プレゼント！
# limit: 36,  title: 高円寺ボドゲ1000種会【vol.10 2019年04月回】
# limit: 50,  title: ★4/20(土)21(日)フランスベッド・新宿アイランド『ベッド＆ソファお買得セール』
# limit: 60,  title: 残り３名名★4/19(金)【６０名】恋活・友作・婚活！梅田個室居酒屋貸切！花金メガコンパパーティイベント(*・∀・)豪華10品コース料理！≪おものみ関西・飲み会・交流・人脈・オフ会・婚活・出会い・街コン・大阪・友つく・異業種交流会≫
# limit: 20,  title: 【Facebookのデータサイエンティスト】が基礎から実務レベルまで教える統計＋R講座
# limit: 100,  title: 女性が主役の異業種交流会開催！！
# limit: 80,  title: InfoTalk#124 「ITIL® 4登場　ーITサービスマネジメントの新次元ー」
# limit: 3,  title: 【初心者限定】Unity１日集中講座〜少人数クラスの１日講習（応用編）
# limit: 5,  title: 苦労もやる気も要らない、楽しみながら行動が続く「成功する人の習慣」セミナー
# limit: 50,  title: 第76回FreeBSD勉強会 最新bhyveを知ろう！
# limit: 30,  title: ４月１８日（木）　異業種交流会 in 茅場町（デビュー割）
# limit: 10,  title: もう確定申告・決算で後悔しない！領収書整理会
# limit: 3,  title: 【初心者限定】Unity１日集中講座〜少人数クラスの１日講習（基礎編）
# limit: 8,  title: 4/18 池袋・実践読書会 ～イケジツ読書会～ [朝活] 本を読んで実行しよう! 【東京都】
# limit: 20,  title: （無料）「人材測定コンサルタントⓇ」認定講座説明会【東京】～日本初！人事評価・採用担当者向けの専門資格がついに登場！～
# limit: 10,  title: 4月度「未病を改善する試食会」有機ワイン白赤付き 参加費2,000円（税込）
# limit: 16,  title: 【4/17開催】★★近鉄奈良での看護・介護お仕事相談会のご案内★★
# limit: 30,  title: Ateam Design MeetUp_Vol.05 「組織におけるデザイナの働き方/コミュニケーション」
# limit: 5,  title: 4/16 テコンドー練習会 (体験歓迎) ～新しい自分に出会い、自分の可能性を見つけよう～ 【東京・下北沢】
# limit: 5,  title: 勝手にどんどん叶っていく 無意識が達成させてくれる「目標の置き方」セミナー
# limit: 12,  title: サロン地域NO1売上店長育成セミナー
# limit: 5,  title: 【4月5日、15日開催】HSP向け勉強会（お茶会）の開催のお知らせ
# limit: 5,  title: ついに開催！パパが伝える！！親勉(おやべん）体験会のお知らせ
# limit: 15,  title: 4月14日(日) 第24回 初心者向けのゆるーい上野ボードゲーム会
# limit: 60,  title: 4/14(日)【６０名★居酒屋】恋活・友作・婚活！なんば居酒屋貸切！メガコンパパーティイベント(*・∀・)豪華10品コース料理！席替え実施で全員とお話し★
# limit: 5,  title: 4/14 テコンドー練習会 (体験歓迎) ～新しい自分に出会い、自分の可能性を見つけよう～ 【東京・下北沢】
# limit: 30,  title: 【4/14(日)14時～現5名】デザイナー、エンジニア、イラスト関連のクリエイター交流会（吉祥寺ver.）
# limit: 18,  title: 2019年度 場の医学公開セミナー 誰でも100歳以上生きられる 第一回
# limit: 9,  title: ヘビーメイン #100
# limit: 15,  title: <梅田>1曲覚えて5月のイベントステージに参加しよう！ 【初心者向けダンス】ボリウッドダンス体験型
# limit: 6,  title: 東京IT勉強会 4月14日（日）・午後@市ヶ谷
# limit: 20,  title: 【横浜開催（2）】えっ！中高年は食事制限じゃダメなの？！枝光聖人の「らくらくダイエットセミナー」@元町・中華街駅　徒歩1分（心身健康倶楽部 横浜元町店）
# limit: 40,  title: ♠️ 昼/夕/夜 ❤ 4/14(日)新大塚ゲーム交流会！ 🎲️
# limit: 20,  title: 年収300万円あれば出来る、マンション経営！※参加者全員にマンション経営DVD無料プレゼント！
# limit: 10,  title: レイフレ20前夜祭
# limit: 15,  title: 2019年04月13日（土）『自叙伝 ジャン=リュック・ピカード』読書会
# limit: 120,  title: 平野憲一氏による株式セミナー in 大阪 「今後の株式相場見通しと有望銘柄のご紹介　～抜けるか日経平均2万4000円 日本株の力を分析～」
# limit: 50,  title: 【4/13(土)@渋谷】OPTPiX SpriteStudio ユーザーミーティング【＋Personal ＋α！】
# limit: 40,  title: 【初心者大歓迎】2019/4/13 人狼会【軽食・スイーツ付】
# limit: 48,  title: 【将来しくじらないための3時間】
# limit: 1,  title: [泉佐野市主催]  ブロックチェーンアイデアソン 4/13
# limit: 18,  title: インデザインで正規表現
# limit: 5,  title: 社会保険労務士受験講座　厚生年金保険法・国民年金法　無料体験講義　足立区　　　　　４月１３日（土）開講
# limit: 60,  title: 現在５０名★4/12(金)【６０名】恋活・友作・婚活！梅田個室居酒屋貸切！花金メガコンパパーティイベント(*・∀・)豪華10品コース料理！≪おものみ関西・飲み会・交流・人脈・オフ会・婚活・出会い・街コン・大阪・友つく・異業種交流会≫
# limit: 10,  title: 「損せずに不動産を買いたい」方は必見！かしこく家を買う方法がわかるセミナー
# limit: 20,  title: チャリティイベント☆田町の兄のせんべろ占い☆in田町 主催：フロカレ 協力:森永製菓株式会社
# limit: 5,  title: １ヶ月で現実化し始め、一生涯利益を生み続ける「脳と心を加速する技術」基礎セミナー編
# limit: 30,  title: 【2019年04月12日：東京開催】働き方改革推進コンソーシアム ワークショップ2019東京 Vol.1
# limit: 30,  title: 【2019年04月12日：東京開催】働き方改革推進コンソーシアム ワークショップ2019東京 Vol.1
# limit: 50,  title: 【ヒカ☆ラボ】【Ginco Engineer Meetup】ブロックチェーンエンジニアが語る！FinTechクラウドインフラ最前線
# limit: 8,  title: 【東京】１ヶ月で社員が変わる！ 自ら行動し結果を出す Super Team を構築する意識改革プログラム 体験セミナー付説明会
# limit: 20,  title: （無料）「人材測定コンサルタントⓇ」認定講座説明会【東京】～日本初！人事評価・採用担当者向けの専門資格がついに登場！～
# limit: 8,  title: 【無料セミナー】非効率な営業管理から卒業！明日からできるクラウド型営業管理ツール（CRM)の導入 2019年4月11日(木) 16:00 -
# limit: 50,  title: 人工知能の導入を考えている方のための人工知能セミナー
# limit: 8,  title: 4/11 池袋・実践読書会 ～イケジツ読書会～ [朝活] 本を読んで実行しよう! 【東京都】
# limit: 20,  title: 究極のヒットコンテンツの「作り方」 「伝え方」「続け方」 を学び、 時代変化に勝ち抜く『アンビバレント・ビジネス経営塾』
# limit: 5,  title: 変化の激しい未来も対応できる、AI時代に必要な「次世代型リーダーシップ」セミナー
# limit: 10,  title: 4月度「未病を改善する試食会」有機ワイン白赤付き 参加費2,000円（税込）
# limit: 5,  title: ≪仙台開催≫4/10（水）目指せＩＴ業界セミナー
# limit: 10000,  title: Get the best packers and movers in India
# limit: 5,  title: ついに開催！パパが伝える！！親勉(おやべん）体験会のお知らせ
# limit: 30,  title: 【4/9(火)in品川】スマートフォンゲーム開発エンジニア向け技術交流会！～Unityを使ったテクスチャチューニングと海外展開の開発事例を紹介～
# limit: 5,  title: 4/9 テコンドー練習会 (体験歓迎) ～新しい自分に出会い、自分の可能性を見つけよう～ 【東京・下北沢】
# limit: 300,  title: 安田純平氏講演会「紛争地のジャーナリズム」＠東大駒場
# limit: 5,  title: アガり症でも実力を発揮でき、本番で練習以上の結果も出せる「メダリスト式イメージトレーニング」セミナー
# limit: 4,  title: 社会保険労務士受験講座　厚生年金保険法・国民年金法　無料体験講義　足立区　　　　４月８日（月）開講
# limit: 25,  title: 4/8（月）≪女性限定≫ITエンジニア交流会～あなたのライフスタイルに合わせた働き方をしませんか？～
# limit: 5,  title: 社会保険労務士受験講座　厚生年金保険法・国民年金法　無料体験講義　足立区　　　　　４月８日（月）開講
# limit: 30,  title: 【4月8日開催】業界初!セルフ脱毛メニュー導入による売上200%アッ
# limit: 5,  title: 4/8 韓国語入門朝活 (新大塚/大塚) ～ハングル読めなくてOK～【東京・無料】
# limit: 25,  title: いたのくまんぼう先生　aka 和尚が関西にやってくる！！の会
# limit: 5,  title: 4/7 テコンドー練習会 (体験歓迎) ～新しい自分に出会い、自分の可能性を見つけよう～ 【東京・下北沢】
# limit: 8,  title: よくわかる相続税対策　第二部：強力な節税策
# limit: 32,  title: ポケモンカード 新歓会
# limit: 8,  title: よくわかる相続税対策　第一部：安全確実な節税策
# limit: 40,  title: 「爆誕！悪党同盟」プレリリースパーティ！
# limit: 15,  title: <神戸>1曲覚えて5月のイベントステージに参加しよう！ 【初心者向けダンス】ボリウッドダンス体験型☆親子参加歓迎
# limit: 20,  title: 年収300万円あれば出来る、マンション経営！※参加者全員にマンション経営DVD無料プレゼント！
# limit: 15,  title: 4/7 爆誕！悪党同盟プレリリースパーティ！　HS炉端北海道　第二十一夜
# limit: 30,  title: 2019/4/07（日）全日本カラオケバトル2020GP 第４回予選 東京都高田馬場(カラオケ大会/ボーカルコンテスト)
# limit: 7,  title: Processingで学ぶ90分のArt × Programming 無料体験授業！
# limit: 20,  title: 練習会 #32
# limit: 40,  title: 爆誕！悪党同盟プレリリースパーティーin名古屋　交流会
# limit: 20,  title: 【資格説明会:大阪開催】人材測定コンサルタント®　～日本初！人事評価・採用担当者向けの専門資格！当説明会受講で認定講座受講料が20%オフ！～
# limit: 3,  title: 女性のフィロソフィー＆心理本の読書会４／６
# limit: 5,  title: 4/6（土）目指せスタートアップ企業セミナー≪参加無料≫
# limit: 5,  title: 4/6（土）【学生限定】就職・進路に悩んでいるあなたへ！ＩＴスタートアップ企業インターン体験(Fintechアプリ開発体験)セミナー≪無料≫
# limit: 40,  title: 爆誕！悪党同盟プレリリースパーティーin名古屋
# limit: 60,  title: 制作物から学ぶ！ 共感力を生むデザインとブランディング
# limit: 15,  title: 気象予報士資格講座(教育給付金指定講座)　　#天気予報　#講座　#気象予報士　#お天気　#国家資格　#気象　#教育
# limit: 20,  title: 【最新副業情報】こっそり月30万円稼ぐ！会社員、主婦の為のカメラ転売入門講座
# limit: 3,  title: 放送業の情報整理術～初回は聞き方から学ぶ「人前での話し方 基礎講座」ことばの時間
# limit: 300,  title: 4/6(土)300名お花見ＢＢＱ★大阪イベント飲み会★関西でNo,1規模！TVで２回放送された関西１巨大お花見ＢＢＱパーティの招待状(*・∀・)ﾉ関西テレビと読売テレビで放送された３００名お花見街コン婚活オフ会♪
# limit: 15000,  title: 2019荒木比奈生誕記念 比奈Pだらけのカラオケ大会
# limit: 7,  title: マイキャラ大戦SPRING「キラッと！マイキャラ☆ツアーズ」パート　映像出演エントリーページ
# limit: 18,  title: マイキャラ大戦SPRING「大シアターマイキャラまつり！」パート　映像出演エントリーページ
# limit: 34,  title: アイカツ！カーニバル！７／プリティパレード前日祭「マイキャラ大戦SPRING」AIM YOUR THE RIBBON
# limit: 35,  title: 悪の花見会2019
# limit: 20,  title: 年収300万円あれば出来る、マンション経営！※参加者全員にマンション経営DVD無料プレゼント！
# limit: 8,  title: ロボホン オフ会in名古屋。あ、再発見のTABI
# limit: 15,  title: 4/6 [渋谷] カフェ英会話 ～ワンコインで英語を楽しく話そう!!～ 【東京】
# limit: 60,  title: 現在５１名★4/5(金)【６０名】恋活・友作・婚活！梅田個室居酒屋貸切！花金メガコンパパーティイベント(*・∀・)豪華10品コース料理！≪おものみ関西・飲み会・交流・人脈・オフ会・婚活・出会い・街コン・大阪・友つく・異業種交流会≫
# limit: 100,  title: 女性が主役の異業種交流会開催！！
# limit: 10,  title: 年収300万円あれば出来る、マンション経営！※参加者全員にマンション経営DVD無料プレゼント！
# limit: 20,  title: これからマツヤマ～松山のこれからの問題と解決策を探るイベント～
# limit: 5,  title: 【4月5日、15日開催】HSP向け勉強会（お茶会）の開催のお知らせ
# limit: 100,  title: 映画「祈り～サムシンググレートとの対話」&白鳥監督講演&A-sha（山根麻衣） Meditative Concert
# limit: 5,  title: ついに開催！パパが伝える！！親勉(おやべん）体験会のお知らせ
# limit: 20,  title: イマラボ vol.12- CPA20%減でCVが250%UP！効果最大化【Google No.1が教える海外向けリスティング広告】
# limit: 30,  title: ４月４日（木）　異業種交流会 in 茅場町（デビュー割）
# limit: 10,  title: もう確定申告・決算で後悔しない！領収書整理会
# limit: 8,  title: 4/4 池袋・実践読書会 ～イケジツ読書会～ [朝活] 本を読んで実行しよう! 【東京都】
# limit: 20,  title: 現5名【4/3(水)19:30～】異業種×クリエイター交流会（吉祥寺）
# limit: 555555,  title: 4月3日(水曜)19:00～ #ナイス街 @新宿BE-WAVE
# limit: 18,  title: 株式セミナー「立花月報(4月号)から探る活躍期待銘柄」
# limit: 20,  title: 現代のマーケターにおくる！フレームワークから抜け出しアプリのユーザー体験を向上させるために必須な2つの目線 　〜品質管理という目線、CX(顧客体験)という目線〜
# limit: 18,  title: 株式セミナー「立花月報(4月号)から探る活躍期待銘柄」
# limit: 5,  title: 4/2 テコンドー練習会 (体験歓迎) ～新しい自分に出会い、自分の可能性を見つけよう～ 【東京・下北沢】
# limit: 20,  title: 2019年度オープン「新入社員Java+AI研修」ご案内
# limit: 20,  title: 外国人技能実習生教育担当向け「日本語能力試験eラーニング」導入セミナー
# limit: 5,  title: ついに開催！パパが伝える！！親勉(おやべん）体験会のお知らせ
# limit: 8,  title: 定例モクモク勉強会
# limit: 18,  title: 「第11回　Progate もくもく会」
# limit: 20,  title: 【3Dグラフィクス】シェーダーの魅力ってなんだろう！？【皆で雑談！】【サポーターズCoLab勉強会】
# limit: 6,  title: コンピューティングの基礎と処理の高速化入門 #1
# limit: 5,  title: 【初参加者向け】【少人数制】AI・機械学習と数学・プログラミングの学び方
# limit: 28,  title: CoderDojo 赤羽 #12
# limit: 14,  title: 第1回CoderDojo瑞穂マイクラカップ2019
# limit: 20,  title: ガチ議論 完全に理解するオブジェクト指向デザインパターン Composite 容器と中身の同一視編
# limit: 15,  title: [もくもく会共催] ノンコーディングで簡単にAlexaスキルを作ろうハンズオン(Voiceflow)
# limit: 3,  title: 超初心者のためのセキュリティレベリング会
# limit: 30,  title: Chainer Compiler のソースコードをグダグダ語る会
# limit: 27,  title: 九州インフラ交流勉強会(Kixs) Vol.009
# limit: 100,  title: International Women's Day
# limit: 12,  title: 【渋谷開催】CoLabもくもく会 vol.12【サポーターズ】
# limit: 6,  title: 【Little Engineer Hobby】もくもく会（4月その1）
# limit: 50,  title: C++ MIX #3
# limit: 20,  title: 【神戸】re:cap Alexa Day 2019 & Newcomers day
# limit: 80,  title: Data Analyst Meetup Tokyo vol.9
# limit: 46,  title: Global AI Nights Osaka
# limit: 85,  title: Global AI Nights Tokyo
# limit: 15,  title: 1日でInstagram風SNSアプリ（Rails）を作りながらプログラミングを学ぶ
# limit: 46,  title: #JBUG (東京#9) 春の新ネタ プロジェクトマネジメント
# limit: 1,  title: 新規ビジネス企画をHackする勉強会
# limit: 8,  title: Railsを用いてWebアプリケーションを作ろう！ #10
# limit: 20,  title: 初心者向けのディープラーニング講座【サポーターズCoLab勉強会】
# limit: 15,  title: 赤坂 Masonite Python 勉強会
# limit: 12,  title: Docker+Python+Django　WEB開発ハンズオン
# limit: 220,  title: [再演] 外国人との英語での働き方講座 (講師：ロッシェルさん, ちょまど, 他)
# limit: 20,  title: 技術同人誌を書こう【サポーターズCoLab勉強会】
# limit: 20,  title: 技術同人誌を書こう【サポーターズCoLab勉強会】
# limit: 20,  title: Unagi.py 勉強会16枚目～Pythonでアルゴリズムの基本、他～
# limit: 100,  title: #ProLabo(プロラボ)渋谷もくもく会（#駆け出しエンジニア or 初心者歓迎web系)#4
# limit: 8,  title: 超入門・サーバー構築勉強会 #037 in 横浜
# limit: 20,  title: try! Swift報告会 + Swift 5勉強会【iPhone Dev Sapporo番外編】
# limit: 20,  title: MINI Hardening Project #3.2@メルカリ
# limit: 10,  title: DjangoCongress JP 2019 4月作業日
# limit: 20,  title: Webデザイン・Web制作に関する勉強会 #5
# limit: 14,  title: DevRel/Beginners #4
# limit: 32,  title: Ansibleもくもく会 （サーバ編）2019.04 in 甲府！
# limit: 50,  title: PWA Night vol.3 ～PWAのミライや活用方法をみんなで考えよう～
# limit: 40,  title: 表参道.rb #45
# limit: 140,  title: Global Azure Bootcamp 2019@Tokyo
# limit: 12,  title: 第14回 CoderDojo Nada(灘)(深江会場)【メンター募集】
# limit: 16,  title: 第14回 CoderDojo Nada(灘)（深江会場）【忍者募集】
# limit: 67,  title: PyLadies Tokyo Meetup #40 Python入学式
# limit: 10,  title: かごもく #19 シングルサインオン!
# limit: 50,  title: 『Vue.js/PWA/JavaScript…新&定番なんでもあり』表参道Web勉強会 Vol.2
# limit: 40,  title: Inside IT #2
# limit: 8,  title: 【4/4（木）】『Deep Learning』輪読会#11
# limit: 18,  title: マスターしちゃう Docker＆AWS ECSハンズオン
# limit: 18,  title: 知りたいを解決！ゼロから始めるAI講座
# limit: 11,  title: akiba.ex#01：Elixirもくもく会
# limit: 29,  title: お花見！オープンデータソン in 京都
# limit: 3,  title: Pythonによるスクレイピング入門
# limit: 26,  title: 微分幾何勉強会 ∇_6
# limit: 3,  title: Pythonで学ぶ時系列データ解析入門
# limit: 3,  title: Python機械学習入門
# limit: 208,  title: PyData.Tokyo Meetup #19 SysML
# limit: 6,  title: 【参加無料】雑談CAFE 第10弾 #41 【少人数制】
# limit: 20,  title: 熊本アジャイル勉強会 #4
# limit: 25,  title: Zeroichiハッカソン Lev.1 ~(初心者向け)~
# limit: 49,  title: 群馬高専 IT勉強会#2
# limit: 50,  title: アクセシビリティキャンプ東京 2019 － GAAD発起人と振り返る 「CSUN 2019」
# limit: 20,  title: 「陽春 桜川 演奏会」
# limit: 150,  title: Japan OSS Promotion Forum 2019
# limit: 20,  title: Firebaseハンズオン- Webクラウドアルバム編 -【MarkingCloud】
# limit: 60,  title: 職場のダイバーシティーとアクセシビリティー技術トレンド
# limit: 91,  title: Apache Kafka Meetup Japan #6 @Yahoo! JAPAN
# limit: 17,  title: 量子コンピュータハッカソン by Team AI 4/14(日)
# limit: 15,  title: データ前処理研究会 by Team AI 4/12(金)
# limit: 17,  title: 機械学習論文輪読­­会(NIPS他) by Team AI 4/10(水)
# limit: 15,  title: 延期・4月29日【ブロックチェーンエンジニアが教える】PyTorch・kaggle勉強会
# limit: 15,  title: プログラミング勉強部屋　4月9日（ほぼ毎週開催）
# limit: 15,  title: 女性限定♡デザイナーのもくもく会 in いずきゃん渋谷！
# limit: 15,  title: プログラミング勉強部屋　4月2日（ほぼ毎週開催）
# limit: 20,  title: Dappsに興味がある人向け「Blockstackを触ってみよう！」
# limit: 20,  title: あなたの知らないキーボードの世界【サポーターズ勉強会】
# limit: 20,  title: スペシャリストとして組織をつくる、というキャリア【サポーターズCoLab勉強会】
# limit: 20,  title: アプリを最速で構築するための強い味方、Amplifyに入門してみませんか？【サポーターズ勉強会】
# limit: 60,  title: いまさら聞けないネットワーク基礎！【サポーターズCoLab勉強会】
# limit: 20,  title: AWS サーバーレスアーキテクチャでつくるSlack ChatOps【サポーターズCoLab勉強会】
# limit: 44,  title: 【交流会/女性限定】エンジニア "女子会" ミートアップ #2【meetup】
# limit: 15,  title: 【4/16（火）】Firebase 勉強会 in 大阪 × 沖縄
# limit: 30,  title: 【4/9(火)in品川】Unityを使ったテクスチャチューニングと海外展開の開発事例を紹介
# limit: 16,  title: 【参加無料】gumi TECH Drinkup #6 - Elixir -
# limit: 170,  title: xR Tech Tokyo #15 @ メルカリ
# limit: 25,  title: ビール片手にLT大会 vol.2 (at 大名WeWork)
# limit: 25,  title: Singularity Workshop
# limit: 7,  title: 大岡山で もくもく #9
# limit: 8,  title: 第12回CoderDojo瑞穂
# limit: 48,  title: 【Hedge #3】失敗LT祭！ 〜俺の話を聞いてくれ〜
# limit: 55,  title: IBM TEC-J Presents 「知性を問う」勉強会第二弾
# limit: 33,  title: AteamDesignMeetUp_Vol.05 組織におけるデザイナの働き方/コミュニケーション
# limit: 8,  title: AR Fukuoka：8thWallWebで始めるWebAR ~好評につき再々開催！~
# limit: 20,  title: 【なごスタ】第40回効果が上がるWebサイトのコツを一挙公開！！
# limit: 15,  title: CentOS7を堅牢化しよう！（したい）
# limit: 11,  title: 第11回CoderDojo瑞穂
# limit: 20,  title: フロントエンドBBQ - 2019 春のJIN
# limit: 7,  title: 【6名限定】Vue.js & Nuxt.jsで脱jQueryを目指す1ヶ月少人数講習
# limit: 68,  title: Scrapbox SQUARE TOKYO #2 ～開発現場の活用会議～
# limit: 43,  title: 【神戸】GCPUG KOBE #5 【GCP】～はじめてのGCP～
# limit: 8,  title: 『ベイズ統計モデリング―R,JAGS,Stanによるチュートリアル―』読書会 #16
# limit: 53,  title: 分析基盤トーク DAFT #2
# limit: 56,  title: 【発表枠〆】Mix Leap LT #16 - LT会　初心者の館「フリーテーマ」
# limit: 20,  title: 4/12開催 SORACOM UG 宮城 初心者向けSORACOMワークショップ (もくもく会)
# limit: 18,  title: 【未経験者歓迎】【初心者向け】Kaggleの事例を学ぼう！（モデルを作る前の予習） #2
# limit: 35,  title: ZOZO RESEARCH Meetup in KITAKYUSHU #4
# limit: 50,  title: 比較でわかる！OracleCloud 〜AWSと比べてみよう〜
# limit: 136,  title: JANOG43.5 Interim Meeting
# limit: 20,  title: フリーランス交流の場！お酒を飲みながらゆるーく情報交換しましょう
# limit: 174,  title: No-Code JP 第0回
# limit: 11,  title: JBUG (広島#2 mini開催) Backlogを使うと何がいいの？初級編
# limit: 14,  title: 【python高速化】Faster Python Meet up LT会#1
# limit: 9,  title: インフラエンジニアの為の運用自動化入門
# limit: 9,  title: 構成管理自動化の為のKc Sonar入門セミナー
# limit: 30,  title: 「音声の未来を語る〜メディア論編〜」松浦シゲキさん、久保田大海さん×Voicy緒方
# limit: 20,  title: 「ラズパイとNode-REDでロボット(TJBot zero)を体験しよう！ 」
# limit: 69,  title: 【技術書典6】サークル主LT
# limit: 34,  title: 初心者歓迎！SPA開発現場あるある〜ぶっちゃけトーク〜
# limit: 70,  title: 『失敗から学ぶ RDBの正しい歩き方』発刊記念！そーだいさんから直接学ぶ会
# limit: 50,  title: セキュリティマイスター道場(SecDojo) ~春場所~
# limit: 25,  title: 音 x 機械学習はどこまで実現できているか？ - 最新理論とユースケース -
# limit: 15,  title: WEBエンジニア MeetUp＠札幌 #3
# limit: 4,  title: 【初心者向け】RPA勉強会＆相談会
# limit: 132,  title: 銀座Rails#8 @リンクアンドモチベーション
# limit: 200,  title: 国際規格SQuaREに基づくソフトウェア品質の測定評価と認証セミナー (2019年4月19日)
# limit: 3,  title: 【東京開催】AI活用ユーザー事例の紹介
# limit: 5,  title: 【メンター募集】第15回 CoderDojoみのお 2019/4/14(日)
# limit: 9,  title: 第15回 CoderDojoみのお（箕面）2019/4/14(日)
# limit: 40,  title: CommunitySummitTokyo #3
# limit: 9,  title: IoT寺子屋：深層学習の数学勉強会(1)_演習分厚版_0428
# limit: 38,  title: Visual Studio 2019 Launch Event in Fukuoka
# limit: 12,  title: 新潟 Web アプリ 勉強会(FE/BE) Vol. 1.1
# limit: 12,  title: 量子コンピューティング勉強会（実践編） #1
# limit: 10,  title: BMXUGハンズオン「LINEでお絵描きメッセージを送ってみよう♪」
# limit: 220,  title: IBM Cloud Community Summit 2019.04
# limit: 4,  title: PyData.Fukui  AI機械学習コラボでコラボ
# limit: 42,  title: 第３回【ファミリーテックIoTLT】家庭で実践！IoT縛りの勉強会＠ヴァル研究所
# limit: 10,  title: 第四陣 信玄パイ「機械学習を業務で利用するのに必要なこと」
# limit: 90,  title: Blockchain GIG #2
# limit: 15,  title: 次世代 Tokyo DG を考える会
# limit: 50,  title: 第35回 Machine Learning 15minutes!
# limit: 30,  title: ChatBot Community Meetup #01
# limit: 3,  title: Pythonデータ分析入門
# limit: 3,  title: 【tensorflowで学ぶ】ディープラーニング実装入門
# limit: 3,  title: 【初心者歓迎】Python入門講座
# limit: 3,  title: PythonによるRNN・LSTM入門
# limit: 40,  title: 1000 speakers conference in English 71st, Apr 23
# limit: 19,  title: Pythonもくもく自習室 #19 @ Rettyオフィス
# limit: 42,  title: Data Gateway Talk vol.1
# limit: 10,  title: #ProLabo(プロラボ)渋谷もくもく会（ノンコーディングで簡単にAlexaスキル作成ハンズオン）
# limit: 10,  title: Voicy's もくもく会 〜ノンコーディングで簡単にAlexaスキルを作ろうハンズオン〜
# limit: 100,  title: Agileware Drinkup at RubyKaigi 2019
# limit: 18,  title: VAE; Auto-Encoding Variational Bayes｜ 論文輪読会 #21
# limit: 15,  title: PythonでWebアプリを作ろう@会津若松 [女性対象/男女コーチ] 2019.04
# limit: 12,  title: 【東京体験版】他では絶対教えてくれない！常識に惑わされない！ユーザー視点のUIデザイン
# limit: 20,  title: 【AI】第1回 初学者向け ビジネスへのAI活用勉強会 in 名古屋
# limit: 15,  title: 平成最後のはんなりPython #16  ディスカッション会
# limit: 20,  title: 【AI】第1回 初学者向け ビジネスへのAI活用勉強会 in 名古屋
# limit: 11,  title: 【東京4月開催】04：直感的で快適なWEB環境を作る｢スマホ用UIデザイン｣
# limit: 7,  title: 【東京4月開催】03：ユーザーの視点に寄り添う「わかりやすいUIデザインのツボ」
# limit: 20,  title: 【AI】第8回 初学者向け ビジネスへのAI活用勉強会 in 名古屋
# limit: 33,  title: 第29回北海道情報セキュリティ勉強会
# limit: 20,  title: 【AI】第3回 【統計・情報科学専攻】学生向け ビジネスへのAI適用勉強会 in 名古屋
# limit: 10,  title: 【AI】第1回  【統計・情報科学専攻】学生向け ビジネスへのAI適用勉強会 in 名古屋
# limit: 9,  title: PyData.Fukui 　PythonでAIましょう
# limit: 35,  title: 韓国におけるマーケティング戦略を語る 〜エウレカ×LIFE PEPPER〜
# limit: 66,  title: 【無料ワークショップ@大阪】機械学習を成功させるためのデータ前処理と特徴量エンジニアリング（再演）
# limit: 26,  title: 【4/6】Generative Art With JavaScript【ハンズオン/初心者歓迎】
# limit: 30,  title: Global AI Nights Fukui
# limit: 10,  title: デザインわくわく会 #1
# limit: 30,  title: 「コンテキストの理解と実践」UXワークショップ：【第50回】
# limit: 10,  title: ティール組織 - 新しい働き方のスタイル - 読書会 第6回
# limit: 50,  title: 【4/24】水曜ワトソンカフェvol.19「3年間、ガチな現場のチャットボットとAssistant」
# limit: 12,  title: 認定スクラムマスター資格の更新をモブワークでやろうの会
# limit: 105,  title: RejectKaigi2019 東京会場
# limit: 20,  title: 【AI】第6回 初学者向け ビジネスへのAI活用勉強会 in 名古屋
# limit: 20,  title: 【AI】第5回 初学者向け ビジネスへのAI活用勉強会 in 名古屋
# limit: 10,  title: 熊ゆに Unityもくもく会　2019/4/6（土）
# limit: 51,  title: RubyKaigi 2019 After Hack by Fukuoka.rb!! (#132)
# limit: 30,  title: あるあるLT〜サーバーサイドエンジニア〜 Vol.2
# limit: 35,  title: RejectKaigi 2019 福岡会場 (a.k.a. Fukuoka.rb #131)
# limit: 8,  title: MIDIとMQTTを使ってリモート演奏する仕組みを作ってみよう
# limit: 50,  title: Creator Lounge vol.1 - お悩み解決ラウンジ
# limit: 95,  title: エンジニアの未来を考えるMeetup「驚くほど簡単なAI開発」
# limit: 20,  title: Docker Workshop in Kyoto #03
# limit: 11,  title: 【初心者向け】HTML/CSS/Java Script/GAS/Python総復習！初参加も大歓迎
# limit: 50,  title: Hash Tech Meeting #3 【OFC 2019 報告会】
# limit: 50,  title: 【満席御礼】第1回 サブスタンスワークフロー会
# limit: 70,  title: Repro Tech #7 Practical AI Supported by NAVITIME
# limit: 130,  title: Cogbot 勉強会 Special ★ LINE から話せる楽しいチャットボットを作ろう！
# limit: 3,  title: R言語データ分析入門
# limit: 3,  title: Pythonによる勾配ブースティング【入門編】
# limit: 25,  title: 業務システムデザイン勉強会
# limit: 25,  title: HTML5再入門講座
# limit: 10,  title: C++20を相談しながら調べる会
# limit: 5,  title: G Suiteを磨きたい！使い倒したい！みんなでナレッジをシェアしましょう
# limit: 75,  title: EC-CUBE東京ユーザグループ開発者向け勉強会4月
# limit: 8,  title: 麻布十番もくもく会（フルスタックなCTOに質問可能）
# limit: 50,  title: 【CEO監修】プログラミング未経験から月50万稼げるエンジニアになる方法
# limit: 50,  title: 【非エンジニア向け】Freelance Engineer Conference
# limit: 30,  title: ポケラボオリジナルの組織で創り上げる『SINoALICE -シノアリス-』アート発注・制作の裏側
# limit: 25,  title: 2019 アジャイル事業部 新年度のご挨拶
# limit: 20,  title: 【4/5(金) 19:00-現在11名 】クリエイター&エンジニア交流会【新宿】
# limit: 40,  title: ブロックチェーンのビジネス利用入門
# limit: 5,  title: 【大阪開催】実例で知るAI/ディープラーニング活用最前線
# limit: 5,  title: 【東京開催】実例で知るAI/ディープラーニング活用最前線
# limit: 2,  title: 【Raspberry Pi + AI + IoT】人工知能を使ったリアルタイム物体検出
# limit: 8,  title: Azure Functions と キューで構築するNoOpsスケーラブルバッチ処理基盤
# limit: 10,  title: 仮想空間のビジネス活用
# limit: 15,  title: プログラミング・エラーなんかコワくない??
# limit: 100,  title: ID-based Security イニシアティブ　第5回全体ミーティング
# limit: 50,  title: 【福岡】CircleCI ユーザーコミュニティミートアップ #1
# limit: 14,  title: Firebase ハンズオン in 愛媛
# limit: 100,  title: Houdini 17.5 東京セミナー
# limit: 45,  title: 建設・不動産×IT Meetup　～レガシーな業界を変えるテクノロジーの最前線～
# limit: 15,  title: ■U-29■フリーランス？会社員？悩める若手エンジニアの会
# limit: 20,  title: Amazon EC2 F1インスタンス入門ワークショップ(4月開催分)
# limit: 5,  title: 【店舗をお持ちの企業限定】ローカル検索を最適化
# limit: 43,  title: 【初！広島開催！】RPA勉強＆LT会！RPALT 広島 vol.01
# limit: 80,  title: 第3回データベース比較セミナー
# limit: 20,  title: テストもぐもぐ会　～2019 春の陣～
# limit: 7,  title: Unityゆるゆる勉強会#3
# limit: 56,  title: Otemachi.swift #03
# limit: 45,  title: DevRel Meetup in Tokyo #40 〜オウンドメディア成功の秘訣〜
# limit: 32,  title: 【CoderDojo生駒】：子ども向けプログラミング道場（No.34）
# limit: 35,  title: 上越TechMeetup #3
# limit: 10,  title: 4/21子どもの無料プログラミングサークル【第1回CoderDojo溝口】(川崎,初心者歓迎)
# limit: 103,  title: 【増枠】RPA勉強＆LT会！RPALT 大阪 vol.03
# limit: 10,  title: 4/17（水）デザイン×呼び方 -「見た目」の話を抜け出そう
# limit: 12,  title: beststagemoku #04 DjangoからVue(Nuxt)もくもく会
# limit: 10,  title: Introducing EventStorming読書会@西新宿#3
# limit: 30,  title: Oct Drink up at RubyKaigi 2019 in Fukuoka
# limit: 30,  title: Cloud Native Okayama #01
# limit: 40,  title: ProDevelopers GameJam #1
# limit: 50,  title: SMETA  FREELANCE NIGHT #1 〜フリーランス与信問題について語らナイト！〜
# limit: 48,  title: 【Launch 記念】Visual Studio 2019 を試してみる会
# limit: 10,  title: (若手)もくもく会＠静岡
# limit: 70,  title: Mercari GDC 2019 報告会
# limit: 35,  title: #ふくばねてす node-1
# limit: 45,  title: 【増枠】GYOMU Hackers Night vol.13 おすすめのSaaS教えます
# limit: 10,  title: 第1回CoderDojo日吉
# limit: 18,  title: Python Boot Camp in 福井
# limit: 8,  title: （第31回SOIL水曜セミナー）はじめようARCore
# limit: 100,  title: Azure DevOps Tokyo, Japan 4th answer
# limit: 40,  title: 【CTOmeetup】kubernetes（k8s）導入とその後
# limit: 70,  title: Satellite Hack #5
# limit: 3,  title: 【京都開催】AI活用ユーザー事例の紹介
# limit: 3,  title: 【名古屋開催】AI活用ユーザー事例の紹介
# limit: 40,  title: 【マッチング特集】アドフラウドとアプリ内マーケティングからみるアプリマーケティング最前線！
# limit: 10,  title: AI業界エンジニア向け　最短・最速でスキルアップする方法セミナー 4/9(火）
# limit: 35,  title: Chatwork Café 東京 Vol.4「Chatworkで働き方改革＆LT会！」
# limit: 10,  title: AI業界のプリセールス職・セールスコンサルタントになる方法セミナー 4/2(火）
# limit: 20,  title: 【AI】第1回 初学者向け ビジネスへのAI活用勉強会 in 名古屋
# limit: 13,  title: LINE Things触ってみようハンズオン
# limit: 15,  title: Sansan Software Architecture Meetup Kyoto
# limit: 55,  title: MySQL Technology Cafe #3
# limit: 13,  title: ブランドを理解し自分ブランドを見つけるワークショップ
# limit: 22,  title: 4月28日【初心者向け】LoomのSDKを活用しDappsを作成する
# limit: 10,  title: 大人の数学リベンジ！第7限「ユークリッド原論 第1回」Euclid's Elements
# limit: 5,  title: Automation Anywhere RPA体験セミナー＠銀座オフィス
# limit: 25,  title: 【eLV勉強会】 ICTを支える「考え方」シリーズ：S00 ICTにおける学術分野統合学習の必然性
# limit: 15,  title: Webクリエイターのための勉強会 vol.1
# limit: 57,  title: VoiceUIライトニングトーク！/ VUILT vol.8 @アイリッジ
# limit: 6,  title: @大阪淀屋橋開催　第14回 文系のための「統計超入門セミナー」 ～目で見てわかるビジネス統計学
# limit: 15,  title: Women Techmakers Kyushu vol.7 - もくもく会 -
# limit: 3,  title: OSSのプロジェクト管理「Redmine」ベースに必要機能を包括する「Easy Redmine」とは
# limit: 3,  title: 経済産業省「DXレポート」の解説と、「2025年の崖」の克服
# limit: 50,  title: ROS Japan UG #29 ROS2講習会
# limit: 23,  title: ぎのわん勉強会 #8 春のプログラミング言語まつり
# limit: 20,  title: 【東京：高円寺】テスト駆動飲み会 -Test Driven Drinking-【4/01】
# limit: 9,  title: [学生無料]未経験からのPythonプログラミング入門6回目-ディープラーニング編　札幌校
# limit: 15,  title: Nefrock勉強会in大岡山「宇宙アイディアソン」
# limit: 10,  title: Rustもくもく会@八丁堀　２
# limit: 10,  title: Code for Oita シビックハックナイト #49
# limit: 100,  title: Nutanix Meetup #38 ～どんと来いHCI初心者～
# limit: 1004,  title: cluster.unity #1
# limit: 33,  title: SORACOM Drinkup #1 - SORACOM Lagoon
# limit: 30,  title: DevRel/Community #2
# limit: 6,  title: 純粋関数型データ構造読書会 第23回
# limit: 195,  title: Kubernetes Meetup Tokyo #18
# limit: 20,  title: 【デモ】iPadで AI:人工知能・ML:機械学習を体験
# limit: 50,  title: 実践者向けディープラーニング勉強会　第二回
# limit: 23,  title: オトナのキャッシュレス勉強会(JP_Stripes 熊本 #1)
# limit: 15,  title: 最終回 初心者向け Ruby on Rails 勉強会 in 門前仲町
# limit: 15,  title: 第12回 初心者向け Ruby on Rails 勉強会 in 門前仲町
# limit: 41,  title: PORT Firebase x Stripe
# limit: 15,  title: iOSアプリの仕組み・UIViewController
# limit: 16,  title: Azureもくもく会@新宿 No.30
# limit: 15,  title: 【初心者向け】Laravel（PHPフレームワーク）入門②
# limit: 12,  title: [秋葉原] 第6回 はじめてのディープラーニングLT会（発表・LT大歓迎！）
# limit: 6,  title: Pythonのもくもく会とボランティア　#42
# limit: 6,  title: Pythonのもくもく会とボランティア　#41
# limit: 28,  title: Mobile Act Kyoto #1
# limit: 8,  title: 【東京】はじめてのRPA～ハンズオンセミナー＠銀座4/12開催
# limit: 8,  title: 【東京】はじめてのRPA～ハンズオンセミナー＠銀座4/23開催
# limit: 120,  title: IIJmio meeting 23 大阪会場
# limit: 12,  title: マグロを堪能する会 in Tokyo #03
# limit: 8,  title: ガツン！IT部（第四回）
# limit: 10,  title: IoT寺子屋：深層学習の数学勉強会(1)_演習分厚版_0407
# limit: 20,  title: 4/20 午前の部 Artで学ぶプログラミング はじめてクラス in 本郷三丁目
# limit: 20,  title: ブロックチェーンでビジネスチャンスをつかむ！第３回 - 仮想通貨周辺・金融
# limit: 9,  title: 酔いどれ設計ナイト2019
# limit: 30,  title: 集まれ！Web系やきうLT大会
# limit: 4,  title: CoderDojo枚方　第25回子ども向けプログラミングワークショップ
# limit: 20,  title: 【新大阪】MotionBoardマイスターになろう！大阪 #3
# limit: 5,  title: 【上級者も歓迎】ハンズオンで学ぶ実践的ベイズ統計モデリング【発展編】
# limit: 15,  title: Tokyo Quantopian User Group Vol.07 コンテストに応募しよう！
# limit: 7,  title: 第39回 平日夜から五反田もくもく会（駆け出しエンジニア or 初心者　非エンジニア歓迎
# limit: 3,  title: 自然言語処理を体系的に学べる講座【全4回】
# limit: 21,  title: 【シューマイ】もくもく花見会
# limit: 30,  title: 第三十二回 Azureもくもく会 @ 品川
# limit: 68,  title: Emscripten & WebAssembly night !! #7
# limit: 20,  title: ゆるゆるもくもく会 特別編 - お花見タイカイ2019 -
# limit: 20,  title: 『サブスクリプションアプリ』のマーケティング戦略
# limit: 105,  title: #ssmjp 2019/04
# limit: 30,  title: 現5名【4/14(日)14時～】デザイナー、WEB、イラスト、エンジニア関連のクリエイター交流会
# limit: 15,  title: 【初心者向け】Laravel（PHPフレームワーク）入門
# limit: 8,  title: 第１２８回 三鷹ハードウェアエンジニアカフェ
# limit: 23,  title: im@sparqlハンズオン
# limit: 6,  title: WordPress, Adobe Illustrator/Photoshop：初心者向けフリー勉強会
# limit: 20,  title: 日本Androidの会浜松支部 第93回ミーティング
# limit: 6,  title: 第３回 CoderDojo 六ツ野
# limit: 15,  title: Nagoya.Swift+ 4月度勉強会
# limit: 10,  title: SBCamp. CMS をつかってみよう WordPressハンズオン！
# limit: 10,  title: 第16回 子どもためのプログラミング道場 - CoderDojo 立川
# limit: 45,  title: 濱せっく 出張版 #6
# limit: 20,  title: 【4/5(金) 19:00- 】クリエイター&エンジニア交流会【新宿】
# limit: 16,  title: Sphinx+翻訳 Hack-a-thon 2019.04
# limit: 12,  title: Shonan.pyもくもく会 #13
# limit: 25,  title: DeFi Meetup #2
# limit: 10,  title: 進捗確認会(4)
# limit: 10,  title: 【宇都宮】プログラミングもくもく会 #1
# limit: 10,  title: 低レベル勉強会2019年4月
# limit: 1100,  title: #14  WP ZoomUP （仮題）アクセシビリティ
# limit: 9,  title: 第25回 CoderDojo 新羽
# limit: 10,  title: 第7回 CoderDojo保土ヶ谷
# limit: 20,  title: VSCode の深イイ話 ~おすすめsettingとか、拡張機能の作り方とか...~
# limit: 150,  title: Mix Leap Study #40 - Spring BootベースのDDDサンプル徹底解説！
# limit: 15,  title: Craft もくもく会 #3
# limit: 20,  title: 4/6 Artで学ぶProgramming【FLAP&PLAY】 はじめてクラス in吉祥寺
# limit: 14,  title: 実践Scala入門読書会 with モブプログラミング 2019/4
# limit: 6,  title: 4月12日　アニメ作成ワークショップ　in　横浜バンガロー
# limit: 16,  title: IoT もくもく会 KOIL vol.30
# limit: 13,  title: Shinjukuもくもくプログラミング #42
# limit: 20,  title: 【AIジョブカレ勉強会】数式と実装から復習するツリーアルゴリズム2
# limit: 8,  title: 4/21 子どもプログラミングサークル CoderDojo 鴨居 vol.07
# limit: 5,  title: 鎌倉Pythonもくもく会 #5
# limit: 10,  title: Android相談会 vol.1
# limit: 9,  title: 個人でWEBサービス作ってる人であつまる「もくもく会」
# limit: 29,  title: LINE Developer Community : 第 2 回 ボット自慢 LT 大会
# limit: 6,  title: やまぐちウェブまわり勉強会 #3 もくもく会
# limit: 40,  title: HackerzLab.博多 Vol20
# limit: 45,  title: RubyKaigi 2019 前夜祭 - Ippudo Party!! -
# limit: 55,  title: 第51回【フリースタイル】PORTもくもく会【学生歓迎！】
# limit: 15,  title: Rust Book 勉強会 #7
# limit: 50,  title: CorpTech Lounge #1
# limit: 10,  title: プログラミング道場 CoderDojo甲斐竜王 #9
# limit: 24,  title: 第10回CoderDojo静岡
# limit: 16,  title: MikanLT #4
# limit: 120,  title: Women Techmakers Tokyo Dinner Party 2019
# limit: 6,  title: ソフトウェア開発もくもく会　#5
# limit: 6,  title: 第2回 HTTP/3 研究会
# limit: 20,  title: WTDC Meeting #01
# limit: 10,  title: 【熊本】DataVizualizationもくもく会
# limit: 10,  title: Cocoa.swift 2019-04 （macOS/iOSアプリケーション開発勉強会）
# limit: 15,  title: Code and Response Day Numazu
# limit: 90,  title: 【初心者向け】ソフトウェアテスト・品質勉強会 Ver3.4【いまさら聞けないテスト・品質の基礎】
# limit: 10,  title: Rancher k3s もくもく勉強会 #02
# limit: 10,  title: Meguro.LYAHFGG #2
# limit: 10,  title: スタートアップ向け人事労務セミナー
# limit: 25,  title: Mobile Act NAGOYA #15
# limit: 10,  title: 【ハンズオン】WebGLで動く3DブラウザゲームをPlayCanvasで簡単に作っちゃおう
# limit: 80,  title: ブロックチェーンMeet Up in OSAKA 第1回「データ経済は民主化できるか？」
# limit: 10,  title: サウナdeもくもく会 in スカイスパYOKOHAMA
# limit: 15,  title: 【4月11日福岡開催】ＡＩも見た目が９割！？ 〜画像認識ＡＩで遊んでみよう〜
# limit: 10,  title: 【4/18 新橋】効果抜群！アニメーションで作るPR動画！
# limit: 6,  title: 【4/16 藤沢】効果抜群！アニメーションで作るPR動画！
# limit: 15,  title: 【4月18日開催】ＡＩも見た目が９割！？ 〜画像認識ＡＩで遊んでみよう〜
# limit: 15,  title: ラズパイ初心者の会 vol.6 ～GLORIAを聞きながらラズパイじゃなくてWebAPIをイジる～
# limit: 155,  title: DIST.26 「Webサービスの個性を支えるデザイン」
# limit: 24,  title: 体を動かそう！クリエイター卓球部 #9
# limit: 20,  title: Perl入学式 in東京 春開講 第1回 〜環境構築編〜
# limit: 60,  title: PWAハンズオン
# limit: 10,  title: ものづくりの『今』を知る
# limit: 80,  title: ECサイト成功の鍵を握る秘訣を伝授！サイト制作から集客・購入率UPのメソッド公開
# limit: 17,  title: JAWS-UG アーキテクチャ専門支部 議論会
# limit: 85,  title: BtoBスタートアップのブランディングイベント#01
# limit: 250,  title: IIJmio meeting 23 東京会場
# limit: 80,  title: [機械学習/DL/TDA]ReNom User Group (RNUG) #11
# limit: 16,  title: Drupal Meetup Tokyo #32 - April 2019
# limit: 24,  title: 【寿司懇親会付き】企業で活用されるAI技術 #7
# limit: 43,  title: VoiceWorld Z Meetup vol.4  こころの声・感情を 知って使って元気になろう！
# limit: 20,  title: ブロックチェーンでビジネスチャンスをつかむ！第２回 - ビットコイン・仮想通貨の基礎知識
# limit: 20,  title: ブロックチェーンでビジネスチャンスをつかむ！第１回 - ブロックチェーンの技術概観
# limit: 20,  title: ブロックチェーンでビジネスチャンスをつかむ！第４回 - 非金融・トークンエコノミー
# limit: 20,  title: 2019年 SPRING「WEB TOUCH MEETING」懇親会
# limit: 6,  title: 寺子屋 at CoderDojo 下北沢
# limit: 6,  title: 体験会 at CoderDojo 下北沢
# limit: 6,  title: 寺子屋 at CoderDojo 下北沢
# limit: 20,  title: UXを踏まえた UIガイドライン作成の心得(第8回)：ワークショップ
# limit: 30,  title: 【第6回】ビジネス・UXに役立つビジュアル化ワークショップ：基礎
# limit: 20,  title: Android＆iOS もくもく会 in eureka #8
# limit: 20,  title: .NETのエンタープライズアプリケーションアーキテクチャ読書会 Vol.18
# limit: 44,  title: 第22回 セキュリティ共有勉強会（テーマ:インシデント対応）
# limit: 45,  title: RubyKaigi 2019 コード懇親会
# limit: 2,  title: 【導入検討企業限定】SIer不要、自社でRPAを導入・活用するためには？
# limit: 5,  title: Hacker's GATE もくもく会 #24
# limit: 20,  title: イイラボ 秋葉原もくもく会 in コワーキングスペースRampart #04
# limit: 40,  title: アプリマーケティング最前線！アドフラウド対策とアプリ内マーケティングによる新規ユーザ獲得から定着まで
# limit: 10,  title: 【大阪・梅田】エンジニアもくもく勉強会4月 ＠ RAKUS
# limit: 20,  title: 長野版IoT縛りの勉強会 IoTLT長野 vol.2
# limit: 4,  title: 【大阪】はじめてのRPA ~ ハンズオンセミナー@WeWorkなんばスカイオ 4/5開催
# limit: 7,  title: 体験最終回！Processingで学ぶArt × Programming 90分無料体験講座！
# limit: 9,  title: IoTを体感出来るハンズオン【無料】
# limit: 60,  title: 緊急開催！[LINE チャネル対応記念]開発ツール不要で作れるお手軽LINE ボット体験セミナー
# limit: 20,  title: 大阪Pythonの会 #20
# limit: 8,  title: 基礎から応用やトレンドまで学ぶ量子コンピューティング入門セミナー #2
# limit: 45,  title: Web Creators MeetUp 新卒・若手登壇ビアバッシュLT会 #10
# limit: 15,  title: 第15回 Python勉強会@仙台
# limit: 15,  title: PHP.Sendai#16
# limit: 15,  title: IOSTech Hack The 1st - IOST ハッカソン
# limit: 4,  title: 現役社員と半日で学ぶ、開発ワークショップ！「JavaScriptでテトリスを作ろう！」の会
# limit: 18,  title: Pythonもくもく会 in 名古屋 #3
# limit: 11,  title: 【第3回目】プログラミング名古屋もくもく会
# limit: 15,  title: 【大阪・梅田】WEB系言語もくもく会＋交流
# limit: 40,  title: 『実用Common Lisp』読書会(29)
# limit: 8,  title: 【メンター募集】第2回 CoderDojoとよなか 2019/04/07(Sun)
# limit: 10,  title: 第2回 CoderDojoとよなか（豊中）2019/04/07(Sun)
# limit: 35,  title: Drupal Meetup 羽田 #19
# limit: 30,  title: 三重で働く！ITエンジニアのためのUIJターン企業説明会
# limit: 50,  title: Salesforce女子部 Tokyo #28 〜Salesforce管理者アプリ構築のヒント〜
# limit: 8,  title: 【初参加歓迎】Webアプリ開発塾 もくもく勉強会★今週のテーマはPuppeteer
# limit: 8,  title: 【初参加歓迎】Webアプリ開発塾 もくもく勉強会★今週のテーマはTypeScript
# limit: 8,  title: 【初参加歓迎】Webアプリ開発塾 もくもく勉強会★今週のテーマはReact Hooks
# limit: 5,  title: 【無料】ゼロからはじめるPython入門講座（テックジム・オープン講座）
# limit: 5,  title: 【無料】ゼロからはじめるPython入門講座（テックジム・オープン講座）
# limit: 5,  title: 【無料】ゼロからはじめるPython入門講座（テックジム・オープン講座）
# limit: 5,  title: 【無料】ゼロからはじめるPython入門講座（テックジム・オープン講座）
# limit: 20,  title: International IT/AI Meetup - Networking Party 4/3水
# limit: 20,  title: お客様事例から学ぶ『マーケティングオートメーション×Salesforce活用セミナー』
# limit: 20,  title: 日本Androidの会 OSAWG 方針相談会合　一般の方も参加可能です。
# limit: 10,  title: 第26回横浜Go読書会
# limit: 20,  title: 『ゲームアプリ2.0』成長を加速させるためのデータ活用最前線
# limit: 40,  title: Goもくもく会（ごもくかい）#14
# limit: 20,  title: Meguro.vim #15
# limit: 20,  title: JAZUG札幌支部（きたあず） 第22回勉強会
# limit: 50,  title: 業務改善職勉強会 Vol.01
# limit: 60,  title: 【渋谷朝活】もくもく会 @la billage
# limit: 60,  title: 【渋谷朝活】もくもく会 @la billage
# limit: 92,  title: Cloud Native Tokyo #01
# limit: 60,  title: 【渋谷朝活】もくもく会 @la billage
# limit: 60,  title: 【渋谷朝活】もくもく会 @la billage
# limit: 5,  title: Hacker's GATE もくもく会 #23
# limit: 63,  title: ファウンダーが語る「toC × Big Market の最前線」 #10XTALK
# limit: 8,  title: 第17回 CoderDojo 福岡
# limit: 7,  title: Alexa KoBuilder Challenge in Alexa Day 2019 登壇者募集!
# limit: 8,  title: 第7回　Clean Architecture輪読会
# limit: 10,  title: Agile459運営ミーティング(オンライン) 2019 #3
# limit: 40,  title: 第3回アラサー技術者交流会（テーマ：デザイン思考）
# limit: 100,  title: 2019 SPRING「WEB TOUCH MEETING」
# limit: 53,  title: ARカメラを使ったプロモーション事例の紹介と最近のSNSマーケティング動向
# limit: 187,  title: Tokyo HoloLens ミートアップ vol.14
# limit: 20,  title: UniFa Developer's MeetUp＆LT会 #1
# limit: 10,  title: Rancher k3s もくもく勉強会 札幌 #01
# limit: 57,  title: Meguro.es # 20 @ Drecom
# limit: 15,  title: ＜無料RPAセミナー＞ 最新事例に学ぶ！RPAの活用方法
# limit: 30,  title: AI×スマートメーターデータの活用
# limit: 20,  title: Global Azure Bootcamp 2019@Sendai
# limit: 11,  title: オープンネットワーキングによるIT自動化セミナー
# limit: 30,  title: High Performance I/O ミートアップ！
# limit: 60,  title: 売上アップに繋げるソーシャルメディアマーケティング【TTT.14】
# limit: 8,  title: OnTimeをさわりつくそう会　第十八回
# limit: 45,  title: ゲームアセット向けプロシージャルツール紹介セミナー　4月　東京
# limit: 15,  title: 第6回 Clean Architecture 読書会
# limit: 87,  title: iOS Test Night #10
# limit: 50,  title: いま押さえておくべきJavaScriptの最新機能とは？
# limit: 6,  title: 【初心者・初学者歓迎】恵比寿で学ぶJavaScript学習会 初めて〜学び直したい人など
# limit: 30,  title: Global Graph Celebration Day Kanazawa (金沢)
# limit: 25,  title: みんなで情シス！第4回
# limit: 123,  title: PR TIMES Drinkup at RubyKaigi 2019
# limit: 6,  title: (会場変更)Pythonのもくもく会とボランティア　#40
# limit: 6,  title: (会場変更)Pythonのもくもく会とボランティア　#39
# limit: 45,  title: 量子コンピューターについて語ろうLT大会＆懇親会（2019年4月）
# limit: 20,  title: 現5名【4/3(水)19:30～】異業種×クリエイター交流会 in 吉祥寺
# limit: 5,  title: 【初心者歓迎】プログラミング相談所【毎月開催 もくもく作業でもOK】
# limit: 5,  title: 【初心者歓迎】プログラミング相談所【毎月開催 もくもく作業でもOK】
# limit: 100,  title: Mobile Act OSAKA #9
# limit: 20,  title: お茶の水ロボットクラブ：2019/4
# limit: 20,  title: もくもく会 with トライデントワークス in 宇都宮 #2
# limit: 10,  title: Vue.jsのサーバーレスアーキテクチャ /メディアサイト制作を進めるために知っておきたいこと
# limit: 28,  title: GCPUG Kochi  #WEBサイトを実際にGCPで作ってみよう！
# limit: 11,  title: 多摩地区ノンジャンルもくもく会「たまもく」#2 at SEEDPLACE
# limit: 15,  title: bmxug.tokyo もくもく会#9 Code Patterns
# limit: 120,  title: AWS .NET Developer User Group 勉強会 #1
# limit: 40,  title: fukuoka.R #13
# limit: 55,  title: Global Azure Bootcamp 2019@Sapporo
# limit: 10,  title: Ruby on rails もくもく＆もぐもぐ会 @浜町. #11
# limit: 45,  title: [Meet Up] What is Google Cloud Platform ?
# limit: 100,  title: Rakuten Commerce QA Night#1
# limit: 15,  title: 第22回 たけともそん in 高円寺
# limit: 5,  title: エンジニア向けの「ウェブ開発勉強会（HTMLから脆弱性対策まで）」＠北九州開催
# limit: 12,  title: (平成最後の！) サイボウズ バグハンター合宿 2019
# limit: 10,  title: Nerima.rb #1
# limit: 65,  title: ファシリテーション デザイン講座
# limit: 44,  title: 【第8回】フロントエンド× ビアバッシュ初心者勉強会 酒がナイト in 銀座
# limit: 5,  title: “アーキテクチャとファシリテーション”ミニ解説&対話の会
# limit: 20,  title: Visual Studio 2019 Launch Event Sendai
# limit: 12,  title: Toyama.rb #39 もくもく会
# limit: 12,  title: リアルVtuberが語るフロントエンド開発入門セミナー #2
# limit: 108,  title: M5Stackユーザーミーティング vol.4
# limit: 6,  title: @大阪淀屋橋開催　第15回 文系のための「統計超入門セミナー」 ～目で見てわかるビジネス統計学
# limit: 22,  title: 4月21日【初心者向け】ERC20独自トークンを検証環境（Ropsten）にデプロイする（WebBe
# limit: 70,  title: Open Source UN-Conference 2019 Kawagoe
# limit: 21,  title: TypeScript 勉強会
# limit: 16,  title: はじめてのGo言語教室
# limit: 30,  title: ポートフォリオセッション
# limit: 20,  title: イイラボ 秋葉原もくもく会 in コワーキングスペースRampart #05
# limit: 20,  title: イイラボ 秋葉原もくもく会 in コワーキングスペースRampart #03
# limit: 6,  title: Processing勉強会 #25
# limit: 50,  title: 【NEM9】VUIがつくる未来
# limit: 20,  title: NEM9 懇親会
# limit: 20,  title: Global Graph Celebration Day Fukuoka (福岡)
# limit: 30,  title: 【TECH×GAME COLLEGE#17】スマホ向け HTML5ゲームのすべて
# limit: 10,  title: 上越TechMeetup #3 懇親会
# limit: 11,  title: CoderDojo師勝
# limit: 20,  title: 【初心者大歓迎】たった4時間でWebサイトを開発！無料プログラミング体験会
# limit: 20,  title: 【初心者大歓迎】たった4時間でゲームを開発！無料プログラミング体験会
# limit: 20,  title: 【初心者大歓迎】たった4時間でWebサイトを開発！無料プログラミング体験会
# limit: 9,  title: Laravel LT会 with もくもく #2
# limit: 5,  title: RubyKaigi2019_Classi Scholarship Sponsor
# limit: 34,  title: NaITE#31　「テストレベル定義について考える」
# limit: 30,  title: SpringBootでマイクロサービスを作ってKubernetesにデプロイしてみる【実践編】
# limit: 10,  title: クリエイター・デザイナー勉強会（Webデザイン、DTP、HTMLウェブコーディング）
# limit: 10,  title: クリエイター・デザイナー勉強会（Webデザイン、DTP、HTMLウェブコーディング）
# limit: 10,  title: Hackers:桑名（プログラミング勉強会・もくもく会）
# limit: 10,  title: Hackers:桑名（プログラミング勉強会・もくもく会）
# limit: 10,  title: 【女性限定】月刊フィントーク その24
# limit: 22,  title: 4月14日【初心者向け】BlockchainをGolangで実装する(WebBench)
# limit: 15,  title: 【初心者歓迎】ゆるふぁい#16 - Delphi のゆる～い集まり
# limit: 12,  title: 無料で！かんたんにディープラーニングが学べる　体験コース
# limit: 48,  title: 【福岡】ゆるっとIT vol.10「ソフトウェアテストの話を聞こう」
# limit: 24,  title: Angularで始めるモダンWeb開発セミナー
# limit: 30,  title: ハシラス・オープンデイ #11 (JapanVR Fest. Special)
# limit: 30,  title: SpringBootでマイクロサービスを作ってKubernetesにデプロイしてみる【実践編】
# limit: 6,  title: 第18回　機械学習超入門
# limit: 30,  title: Power Query 秘密特訓「虎の穴」 #3
# limit: 6,  title: 第17回　機械学習超入門
# limit: 6,  title: @新橋回　第2回 文系のための「統計超入門セミナー」 ～目で見てわかるビジネス統計学～
# limit: 73,  title: 【初！福岡開催！】RPA勉強＆LT会！RPALT 福岡 vol.01
# limit: 8,  title: 第211回 文系のための「統計超入門セミナー」 ～目で見てわかるビジネス統計学～
# limit: 8,  title: 第212回 文系のための「統計超入門セミナー」 ～目で見てわかるビジネス統計学～
# limit: 8,  title: 第210回 文系のための「統計超入門セミナー」 ～目で見てわかるビジネス統計学～
# limit: 8,  title: 第209回 文系のための「統計超入門セミナー」 ～目で見てわかるビジネス統計学～
# limit: 6,  title: ＠新橋回　第2回 データセンス超入門セミナー ～苦手な数字を扱うために～
# limit: 6,  title: 第67回 データセンス超入門セミナー ～苦手な数字を扱うために～
# limit: 6,  title: 第66回 データセンス超入門セミナー ～苦手な数字を扱うために～
# limit: 6,  title: 第65回 データセンス超入門セミナー ～苦手な数字を扱うために～
# limit: 30,  title: Nagoya.php #15
# limit: 50,  title: Cloud Native Sapporo #02
# limit: 13,  title: つくばPythonもくもく会(tsukuba.py) No.5
# limit: 30,  title: 【無料4/12】インサイドセールス支援ツール「みやすい解析」で興味層への訴求に最適な営業リストの形成
# limit: 30,  title: やさしく学ぶ「BtoBウェブ担当者のためのGoogle アナリティクス活用戦略」
# limit: 117,  title: GCPUG Okinawa!#7 午前「GKEハンズオン」午後「GCPと課題解決と意思決定」
# limit: 60,  title: 座駆動LT大会20190413
# limit: 31,  title: Salesforce Saturday 日本橋#02
# limit: 10,  title: 【東京】ドローン × ミートアップ
# limit: 17,  title: 帰り道もくもく会＋ＩＴエンジニアとお話し会　#13
# limit: 20,  title: 出張 kintone Café 浜松 Vol.17 @袋井
# limit: 42,  title: Data Pipeline Casual Talk Vol.2
# limit: 10,  title: 4/5（金）デザイン x コンセプトづくり〜デザインをつくる前に考える"構想"
# limit: 5,  title: 【大阪】はじめてのRPA ~ ハンズオンセミナー@WeWorkなんばスカイオ 4/12開催
# limit: 60,  title: 【4月6日14:00開催】制作物から学ぶ！共感力を生むデザインとブランディング
# limit: 9,  title: Robotics勉強会 in Osaka 2019 Spring
# limit: 25,  title: v-sapporo MeetUp #1
# limit: 5,  title: Python3ではじめるシステムトレード入門　第24回連続セミナー人工知能入門１　午前の部
# limit: 5,  title: Python3ではじめるシステムトレード入門　第24回連続セミナー 人工知能入門２ 午後の部
# limit: 10,  title: 岡山IT座談会#8
# limit: 50,  title: 現代のマーケターにおくる！フレームワークから抜け出しアプリのユーザー体験向上のために必須な2つの目線
# limit: 4,  title: 京都！街歩き！マッピングパーティ：第7回 天橋立、成相寺
# limit: 18,  title: 渋茶駒玉川エンジニアLT会 #3
# limit: 12,  title: パターン認識と機械学習(下) by Christopher M. Bishop 輪読会 #11
# limit: 44,  title: スクラムチームが「自己組織化」するには？(仮)
# limit: 135,  title: 総関西サイバーセキュリティＬＴ大会（第14回）
# limit: 40,  title: HoudiniAid #01
# limit: 45,  title: Umeda.go 2019 Spring
# limit: 65,  title: Global Azure Bootcamp 2019@Osaka
# limit: 18,  title: #21_メイプルもくもく会
# limit: 18,  title: #20_メイプルもくもく会
# limit: 30,  title: Tokyo Agile Community (TACO) #1 ようこそ!
# limit: 23,  title: 【第13回】フリーなITもくもく会＠ギーク
# limit: 8,  title: 第28回 CoderDojo 嘉手納
# limit: 35,  title: 4AI #2 - 機械学習(基礎 & 自然言語処理)
# limit: 20,  title: 岐阜デザイン勉強会＃1　｢デザインを勉強する方法｣
# limit: 24,  title: 第25回 CoderDojo Owari
# limit: 9,  title: 第４回CoderDojo博多
# limit: 15,  title: 絶対に手ブレさせない撮影術を学ぶ　ジンバルを使ったカメラワーク講座
# limit: 14,  title: SalesforceSaturday 池袋 #05
# limit: 10,  title: 同ソもくもく会 in 富山 ＃１
# limit: 5,  title: 第5回：Angular もくもく会@グンマー
# limit: 10,  title: 対応付けて学ぶデータサイエンスと戦略・マーケティング勉強会 #4
# limit: 10,  title: [京都] テクテクテック #8 サーバ監視や負荷テストどうやってるの？
# limit: 30,  title: Salesforce Saturday 日本橋#02 懇親会
# limit: 15,  title: 第48回 iOS馬場 #ios_baba
# limit: 39,  title: #VRSionUp! #3 「LavalVirtual2019公式報告会&VTuber番組技術特集」
# limit: 20,  title: DTPerのスクリプトもくもく会スピンオフ
# limit: 20,  title: マーケティングオートメーション導入の成功と失敗のポイント
# limit: 90,  title: Visual Studio 2019 Launch Event in Tokyo.
# limit: 10,  title: Python Boot Camp in 福井 懇親会
# limit: 20,  title: 本郷言語処理勉強会 #3
# limit: 50,  title: 日本PMO協会 2019年Spring 特別セミナー
# limit: 113,  title: Roppongi.unity #2 in メルカリ@六本木ヒルズ
# limit: 26,  title: #エンジニア銭湯
# limit: 17,  title: 帰り道もくもく会＋ＩＴエンジニアとお話し会　#12
# limit: 6,  title: 実習編 JavaScriptで学ぶ プログラミング入門丸一日コース 4月27日（祝日）@c
# limit: 18,  title: 第10回関西Lispユーザ会
# limit: 25,  title: 第75回オープンCAE勉強会＠関東（流体など）【大崎】
# limit: 6,  title: 那覇もくもく会 #05
# limit: 10,  title: 同ソもくもく会 ＃11
# limit: 5,  title: 初心者からの3DCGデザイン・モデリング【Blender入門講習会】
# limit: 12,  title: 【拡大版】サーバー構築ハンズオン in 大阪 #102
# limit: 50,  title: 4月19日（金）　IT交流会　渋谷 【50名規模】
# limit: 13,  title: はじめての英語プレゼン #8
# limit: 15,  title: Python Boot Camp in 和歌山 懇親会
# limit: 26,  title: Python Boot Camp in 和歌山
# limit: 8,  title: 名古屋データ分析もくもく会#8
# limit: 160,  title: 技術書典6　非公式アフター(4/14)
# limit: 45,  title: 【eLV】ITコンサルタントへの第一歩シリーズ　～セルフブランディング戦略～
# limit: 15,  title: 豊田市IT勉強会　4月　もくもく会
# limit: 12,  title: 【さいたま・上尾】仕組から学ぶWordPress入門講座
# limit: 12,  title: 【さいたま・上尾】仕組から学ぶWordPress入門講座
# limit: 12,  title: 【さいたま・上尾】仕組から学ぶWordPress入門講座
# limit: 10,  title: #13 第6回 DRF勉強会 (全6回)
# limit: 267,  title: 高専キャンプ in 讃岐
# limit: 40,  title: OWASP 北信越ミーティング 　19年４月度
# limit: 15,  title: Cloud Native Sapporo #02 懇親会
# limit: 20,  title: 情シス in 新潟＃1 @Prototype Cafe
# limit: 200,  title: みんなのPython勉強会#44
# limit: 10,  title: ゼロからまなぶ統計学(Python編)
# limit: 55,  title: ゲームで強化学習（と組合せ最適化）がんばる会５
# limit: 55,  title: 量子ゲートで量子アニーリングをプログラミングする
# limit: 55,  title: 量子コンピュータで量子化学を全般的に見返す
# limit: 51,  title: 衛星画像の地表面の物体認識や二値分類機
# limit: 20,  title: 2019年度オープン「新入社員Java+AI研修」
# limit: 50,  title: 第４回 関西日曜数学 友の会
# 739.3227771010962

# %% [markdown]
# どうもエンタメ系のイベントが 10000↑ （最大 55555 人）なんてアホみたいな物を拾ってる。
# 流石にフィルタだフィルタ。
# 2000 人超えたらもう IT 関係無いとみなそう。

# %%
sum_of_limit = 0
limit_exists = 0

for cr in class_rooms:
    if cr.limit != 0 and cr.limit < 2000:
        limit_exists += 1
        sum_of_limit += cr.limit

avg_limit = sum_of_limit / limit_exists
avg_limit
# Out:
# 32.30929095354523

# %% [markdown]
# OK 割と常識的になった。
# では改めて募集人数に対する申し込み人数を計算してみる。

# %%
cr_list = []
for cr in class_rooms:
    limit_num = cr.limit if cr.limit > 0 else avg_limit
    cr_list.append([cr.title, float(limit_num), int(cr.joins)])

cr_df = DataFrame(data=cr_list, columns=['title', 'limit', 'joins'])

cr_df['score'] = cr_df['joins'] / cr_df['limit']
cr_df.sort_values(by='score', ascending=False).head(50)
# Out:
#                                                  title       limit  joins  \
# 359  ALGYAN4周年　IoT祭り2019『IoTとAIとセキュリティ』大講演会＆豪華ノベルティ...   32.309291    261
# 655      現役社員と半日で学ぶ、開発ワークショップ！「JavaScriptでテトリスを作ろう！」の会    4.000000     16
# 554                                        濱せっく 出張版 #6   45.000000    157
# 730    Vue.jsのサーバーレスアーキテクチャ /メディアサイト制作を進めるために知っておきたいこと   10.000000     30
# 475                             LINE Things触ってみようハンズオン   13.000000     32
# 715                       いま押さえておくべきJavaScriptの最新機能とは？   50.000000    104
# 861                                           #エンジニア銭湯   26.000000     53
# 744                                       Nerima.rb #1   10.000000     20
# 788    SpringBootでマイクロサービスを作ってKubernetesにデプロイしてみる【実践編】   30.000000     58
# 336                            CommunitySummitTokyo #3   40.000000     75
# 395                    MIDIとMQTTを使ってリモート演奏する仕組みを作ってみよう    8.000000     15
# 742            エンジニア向けの「ウェブ開発勉強会（HTMLから脆弱性対策まで）」＠北九州開催    5.000000      9
# 855          Visual Studio 2019 Launch Event in Tokyo.   90.000000    160
# 271         Apache Kafka Meetup Japan #6 @Yahoo! JAPAN   91.000000    153
# 716       【初心者・初学者歓迎】恵比寿で学ぶJavaScript学習会 初めて〜学び直したい人など    6.000000     10
# 636                     第22回 セキュリティ共有勉強会（テーマ:インシデント対応）   44.000000     69
# 895                                衛星画像の地表面の物体認識や二値分類機   51.000000     79
# 892                            ゲームで強化学習（と組合せ最適化）がんばる会５   55.000000     82
# 482  【eLV勉強会】 ICTを支える「考え方」シリーズ：S00 ICTにおける学術分野統合学習の必然性   25.000000     37
# 230                    Docker+Python+Django　WEB開発ハンズオン   12.000000     17
# 880             【eLV】ITコンサルタントへの第一歩シリーズ　～セルフブランディング戦略～   45.000000     63
# 553                第16回 子どもためのプログラミング道場 - CoderDojo 立川   10.000000     14
# 600                            Rancher k3s もくもく勉強会 #02   10.000000     14
# 220                             Global AI Nights Tokyo   85.000000    118
# 484              VoiceUIライトニングトーク！/ VUILT vol.8 @アイリッジ   57.000000     79
# 704                            Meguro.es # 20 @ Drecom   57.000000     78
# 408                                      業務システムデザイン勉強会   25.000000     34
# 756                                     TypeScript 勉強会   21.000000     27
# 834                                      #20_メイプルもくもく会   18.000000     23
# 740                        Rakuten Commerce QA Night#1  100.000000    127
# 149                               「爆誕！悪党同盟」プレリリースパーティ！   40.000000     50
# 785                 【福岡】ゆるっとIT vol.10「ソフトウェアテストの話を聞こう」   48.000000     59
# 219                             Global AI Nights Osaka   46.000000     56
# 615                                           PWAハンズオン   60.000000     72
# 849                [京都] テクテクテック #8 サーバ監視や負荷テストどうやってるの？   10.000000     12
# 893                           量子ゲートで量子アニーリングをプログラミングする   55.000000     66
# 470            AI業界エンジニア向け　最短・最速でスキルアップする方法セミナー 4/9(火）   10.000000     12
# 255                            akiba.ex#01：Elixirもくもく会   11.000000     13
# 580       LINE Developer Community : 第 2 回 ボット自慢 LT 大会   29.000000     34
# 110                                        インデザインで正規表現   18.000000     21
# 612                       DIST.26 「Webサービスの個性を支えるデザイン」  155.000000    178
# 868  AI実践入門！NVIDIA Jetson TX2×Azure GPU生体験ハンズオン@大阪TEQS   32.309291     37
# 317             【python高速化】Faster Python Meet up LT会#1   14.000000     16
# 599   【初心者向け】ソフトウェアテスト・品質勉強会 Ver3.4【いまさら聞けないテスト・品質の基礎】   90.000000    102
# 718                                        みんなで情シス！第4回   25.000000     28
# 212                          九州インフラ交流勉強会(Kixs) Vol.009   27.000000     30
# 894                              量子コンピュータで量子化学を全般的に見返す   55.000000     61
# 669   Salesforce女子部 Tokyo #28 〜Salesforce管理者アプリ構築のヒント〜   50.000000     55
# 810                         Salesforce Saturday 日本橋#02   31.000000     34
# 58                      4月20日(土)ポケモンgoトレーナーバトル立川大会＆交流会   32.000000     35
#
#         score
# 359  8.078172
# 655  4.000000
# 554  3.488889
# 730  3.000000
# 475  2.461538
# 715  2.080000
# 861  2.038462
# 744  2.000000
# 788  1.933333
# 336  1.875000
# 395  1.875000
# 742  1.800000
# 855  1.777778
# 271  1.681319
# 716  1.666667
# 636  1.568182
# 895  1.549020
# 892  1.490909
# 482  1.480000
# 230  1.416667
# 880  1.400000
# 553  1.400000
# 600  1.400000
# 220  1.388235
# 484  1.385965
# 704  1.368421
# 408  1.360000
# 756  1.285714
# 834  1.277778
# 740  1.270000
# 149  1.250000
# 785  1.229167
# 219  1.217391
# 615  1.200000
# 849  1.200000
# 893  1.200000
# 470  1.200000
# 255  1.181818
# 580  1.172414
# 110  1.166667
# 612  1.148387
# 868  1.145181
# 317  1.142857
# 599  1.133333
# 718  1.120000
# 212  1.111111
# 894  1.109091
# 669  1.100000
# 810  1.096774
# 58   1.093750

# %% [markdown]
# 先頭の奴はなんとも言えないけど、それ以外はわりかし妥当な数字が見えてるように感じる。
#
# * 入門 or ハンズオンが高い人気
# * JavaScript 系で新しい路線のものはまだまだ人気（サーバレス/新機能など）。
#   言語としての変化が激しいから、この辺も理解できそう。
# * このリスト内では、JavaScript, Python, テスト の関係の単語の出現率がたかそう。
#   Python は脇にに置いといて、JavaScript/テスト 周りは、人気があるのに講座が不足気味と言えそう。
#
# 個人的に気になったのが「量子」。
# これ二つだけシレッといるのだけど全体的にはどのくらい出現してるのか
#
# あーうん気のせいだった

# %%
cond = cr_df.title.str.contains('量子')
cr_df[cond]
# Out:
#                                    title      limit  joins     score
# 272     量子コンピュータハッカソン by Team AI 4/14(日)  17.000000      6  0.352941
# 340               量子コンピューティング勉強会（実践編） #1  12.000000      5  0.416667
# 387           新しい量子化学―電子構造の理論入門〈上〉輪講その12  32.309291      4  0.123803
# 650  基礎から応用やトレンドまで学ぶ量子コンピューティング入門セミナー #2   8.000000      4  0.500000
# 723    量子コンピューターについて語ろうLT大会＆懇親会（2019年4月）  45.000000     34  0.755556
# 893             量子ゲートで量子アニーリングをプログラミングする  55.000000     66  1.200000
# 894                量子コンピュータで量子化学を全般的に見返す  55.000000     61  1.109091
