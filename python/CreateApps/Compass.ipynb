# %% [markdown]
# ## Compass から勉強会名と参加率を拾ってみる
#
# まず何がしたかったかというと、勉強会のタイトルを形態素解析して、その募集人数と参加者（＋参加待ち）の統計とったら、勉強会界隈のトレンドが追いやすくなるんじゃね？と思ったのが始まり。
# で、その為の第一歩として、Compass から勉強会情報を拾ってくる処理をまずは考えた。
#
# ### まずは requests でAPIを叩いてみる
#
# COMPASS は [API仕様](https://connpass.com/about/api/) が公開されているので、そこから拾ってみる。

# %%
import requests

# %% [markdown]
# パラメータ組み立てて

# %%
compass_rest_api = 'https://connpass.com/api/v1/event/'
params = {"ym":"201904", "count":100, "order":3,"start":1}  # 4 月、100 件（max）、着信順、先頭から

query = '&'.join([f'{key}={params[key]}' for key in params.keys()])

# %% [markdown]
# 投げてみる。

# %%
r_get = requests.get(compass_rest_api + '?' + query)

# %%
r_get.status_code
# Out:
# 200

# %%
r_get.json()
# Out:
# {'results_returned': 100,
#  'events': [{'event_url': 'https://supporterz-seminar.connpass.com/event/125251/',
#    'event_type': 'advertisement',
#    'owner_nickname': 'HiroakiKaede',
#    'series': {'url': 'https://supporterz-seminar.connpass.com/',
#     'id': 3032,
#     'title': 'サポーターズCoLab'},
#    'updated_at': '2019-03-23T14:05:50+09:00',
#    'lat': '35.657336100000',
#    'started_at': '2019-04-01T19:30:00+09:00',
#    'hash_tag': 'spzcolab',
#    'title': '初心者向けのディープラーニング講座【サポーターズCoLab勉強会】',
#    'event_id': 125251,
#    'lon': '139.699492800000',
#    'waiting': 0,
#    'limit': 20,
#    'owner_id': 104832,
#    'owner_display_name': 'HiroakiKaede',
#    'description': '<h1>イベント申込方法</h1>\n<p><a href="https://supporterzcolab.com/event/789/" rel="nofollow"><img src="https://supporterzcolab.com/static/img/event/btn_apply_event_on_connpass_event_detail.png"></a></p>\n<p><img src="https://pages.supporterz.jp/rs/590-VZT-927/images/%E8%B6%85%E5%88%9D%E5%BF%83%E8%80%85.png" width="200px"></p>\n<p>※知識なしでもOK</p>\n<h1>イベント概要</h1>\n<p>ディープラーニングで使われる数学、機械学習、画像認識などについて基本的な講義を行います。現在、講義資料を作成しているので、参加者の皆様から積極的なフィードバックや質問をいただけたらと思っております。よろしくお願いいたします。</p>\n<h3>こんな話をします</h3>\n<ul>\n<li>\n<p>基本的な数学の説明</p>\n</li>\n<li>\n<p>基本的な機械学習の説明</p>\n</li>\n<li>\n<p>基本的なディープラーニングの説明</p>\n</li>\n<li>\n<p>基本的な畳み込みニューラルネットワークの説明</p>\n</li>\n<li>\n<p>基本的な回帰型ニューラルネットワークの説明</p>\n</li>\n<li>\n<p>基本的な強化学習の説明</p>\n</li>\n</ul>\n<p>時間に限りがあるので、一部省略すると思います。</p>\n<h3>こんな方にオススメ</h3>\n<ul>\n<li>\n<p>ディープラーニングについて関心を持っているが何もしていない方</p>\n</li>\n<li>\n<p>ディープラーニングの資格に興味がある方</p>\n</li>\n<li>\n<p>講義内容が未熟で洗練されていなくても許せる方</p>\n</li>\n</ul>\n<h3>当日の詳細</h3>\n<ul>\n<li>\n<p>日時\u30002019年4月1日（月）19:30-21:00（19:00開場）</p>\n</li>\n<li>\n<p>場所\u3000<a href="https://goo.gl/h6U6hP" rel="nofollow">渋谷スクエアA 11F</a>（渋谷駅徒歩3分）</p>\n</li>\n<li>\n<p>参加費\u3000無料（交流会含む）</p>\n</li>\n</ul>\n<p>※20時以降来場の際はエントランスが閉まっており入館出来ませんので、到着しましたら090-1799-4545にお電話ください。</p>\n<h3>タイムスケジュール</h3>\n<ul>\n<li>\n<p>ガイダンス （10分）</p>\n</li>\n<li>\n<p>講義（60分）</p>\n</li>\n<li>\n<p>質疑応答（10分）</p>\n</li>\n<li>\n<p>懇親会（10分）</p>\n</li>\n</ul>\n<h3>参加資格</h3>\n<ul>\n<li>\n<p>エンジニア職志望の学生の方（学年不問）</p>\n</li>\n<li>\n<p>20代 or 2010年卒以下の社会人エンジニアの方</p>\n</li>\n</ul>\n<h1>講師紹介</h1>\n<p>【渡邊直樹】</p>\n<p>大学で物理を学んだあと、IBMでソフトウェア開発を行い、その後はスタートアップを立ち上げ、ディープラーニングを使ったアパレル写真の認識や検品業務の自動化を行ってきました。趣味は語学と競プロと読書とアクアリウムとサ活です。</p>\n<h1>特別抽選会を開催しています</h1>\n<p>勉強会後にサトアズグッズやオリジナルCOMPセットなどが当たる特別抽選会を開催しています。</p>\n<p>抽選は公式LINE@上で行なっております。</p>\n<p>おすすめ勉強会情報や特別なキャンペーン情報など、エンジニアの方にお得なコンテンツを発信しています！</p>\n<p>ぜひ事前に友だち登録をしてお越しください。</p>\n<p>▼LINE@の友だち登録は<a href="https://line.me/R/ti/p/%40omd2804q" rel="nofollow">こちら</a>もしくは下記のQRコードから！</p>\n<p><a href="https://line.me/R/ti/p/%40omd2804q" rel="nofollow"><img src="https://pages.supporterz.jp/rs/590-VZT-927/images/%E5%91%8A%E7%9F%A5%E7%94%BB%E5%83%8F%E3%82%A4%E3%83%A1%E3%83%BC%E3%82%B7%E3%82%992018%3A09%3A07.png" width="500px"></a></p>\n<p>※抽選会は予告なく中止になる場合もございますので、予めご了承ください。</p>\n<h1>サポーターズCoLabについて</h1>\n<p>CoLab（コラボ）は、仲間と共に（Co）、楽しみながら成長できる研究室（Lab）のような存在を目指しています。</p>\n<p>若手エンジニア向けの技術勉強会やミートアップをオリジナルコンテンツでほぼ毎日開催しており、</p>\n<p>同世代エンジニアの仕事、スキル、キャリア、悩みを知り、交流することで仲間を増やすことができます。</p>\n<p>（勉強会の講師は、サポーターズCoLabユーザーの有志が務めています）</p>\n<p>そんな仲間たちと、新たな技術を学ぶ、もの創りを始める、新しいチームにジョインする。</p>\n<p>様々な形で、キャリアを考え、動き出すきっかけを提供していきます。</p>\n<p>※connpassのシステム協力のもと、キャリア支援会社<a href="https://corp.supporterz.jp/" rel="nofollow">サポーターズ</a>が運営しています。</p>\n<p>※就活生向け：交通費がもらえる日本唯一の就活サービス「<a href="https://supporterz.jp/" rel="nofollow">サポーターズ</a>」</p>\n<h2>開催予定のイベント</h2>\n<h3>スペシャルイベント</h3>\n<p><a href="https://supporterzcolab.com/event/731/" rel="nofollow"><img src="https://img.supporterzcolab.com/thumbs/d7/0a/d70a02d6155a335c18daf2e706529916.png" width="300px"></a> \n <a href="https://supporterzcolab.com/event/746/" rel="nofollow"><img src="https://img.supporterzcolab.com/thumbs/ea/bd/eabd7ca7004bf6e1e3507ddd8f798abd.png" width="300px"></a> \n <a href="https://supporterzcolab.com/event/734/" rel="nofollow"><img src="https://img.supporterzcolab.com/thumbs/15/07/15076f0e4f50d713d0216ac760a4d4e7.png" width="300px"></a> </p>\n<ul>\n<li>\n<p>3/30（土）<a href="https://supporterzcolab.com/event/731/" rel="nofollow">【まつもとゆきひろ氏\u3000特別講演】20代エンジニアのためのプログラマー勉強法</a></p>\n</li>\n<li>\n<p>3/29（金）<a href="https://supporterzcolab.com/event/746/" rel="nofollow">19卒エンジニア限定ミートアップ</a></p>\n</li>\n<li>\n<p>4/12（金）<a href="https://supporterzcolab.com/event/734/" rel="nofollow">エンジニア "女子会" ミートアップ #2</a></p>\n</li>\n</ul>\n<h3>スペシャルキャンペーン</h3>\n<p><a href="https://supporterzcolab.com/event/788/" rel="nofollow"><img src="https://img.supporterzcolab.com/thumbs/9b/97/9b97eb33ad374b1cafa9f443f139218e.png" width="300px"></a> \n <a href="https://s ...
#    'address': '東京都渋谷区道玄坂1-9-5',
#    'catch': 'ディープラーニング基本講座',
#    'accepted': 0,
#    'ended_at': '2019-04-01T21:00:00+09:00',
#    'place': '渋谷スクエアA 11F'},
#   {'event_url': 'https://supporterz-seminar.connpass.com/event/125246/',
#    'event_type': 'advertisement',
#    'owner_nickname': 'HiroakiKaede',
#    'series': {'url': 'https://supporterz-seminar.connpass.com/',
#     'id': 3032,
#     'title': 'サポーターズCoLab'},
#    'updated_at': '2019-03-23T13:18:46+09:00',
#    'lat': '35.657336100000',
#    'started_at': '2019-04-15T19:30:00+09:00',
#    'hash_tag': 'spzcolab',
#    'title': '技術同人誌を書こう【サポーターズCoLab勉強会】',
#    'event_id': 125246,
#    'lon': '139.699492800000',
#    'waiting': 0,
#    'limit': 20,
#    'owner_id': 104832,
#    'owner_display_name': 'HiroakiKaede',
#    'description': '<h1>イベント申込方法</h1>\n<p><a href="https://supporterzcolab.com/event/790/" rel="nofollow"><img src="https://supporterzcolab.com/static/img/event/btn_apply_event_on_connpass_event_detail.png"></a></p>\n<p><img src="https://pages.supporterz.jp/rs/590-VZT-927/images/%E8%B6%85%E5%88%9D%E5%BF%83%E8%80%85.png" width="200px"></p>\n<p>※知識なしでもOK</p>\n<h1>イベント概要</h1>\n<p>技術同人誌を書きませんか?あなたの持つ技術、ノウハウ、知識、そういったものを同人誌にアウトプットしましょう。</p>\n<p>技術同人誌の執筆にはメリットがたくさんあります。アウトプットの規模がちょうどよい、知識の体系化に役立つ、など。</p>\n<p>アウトプットのハードルを越える方法、超えた先にある世界をお見せします。</p>\n<h3>こんな話をします</h3>\n<ul>\n<li>\n<p>技術同人誌とは</p>\n</li>\n<li>\n<p>技術同人誌執筆のメリット</p>\n<ul>\n<li>\n<p>自分の棚卸ができる</p>\n</li>\n<li>\n<p>アウトプットの規模がちょうどよい</p>\n</li>\n<li>\n<p>企画・執筆・組版・頒布、全部自分で体験可能</p>\n</li>\n</ul>\n</li>\n<li>\n<p>合同誌寄稿から始めよう</p>\n<ul>\n<li>\n<p>合同誌のメリット</p>\n</li>\n<li>\n<p>合同誌の実際</p>\n</li>\n</ul>\n</li>\n</ul>\n<h3>こんな方にオススメ</h3>\n<ul>\n<li>\n<p>アウトプットしたい方(特にしたいけれど方法がわからない方)</p>\n</li>\n<li>\n<p>本業に飽きた方</p>\n</li>\n<li>\n<p>技術同人誌を知らなかった方</p>\n</li>\n</ul>\n<h3>当日の詳細</h3>\n<ul>\n<li>\n<p>日時\u30002019年4月15日（月）19:30-21:00（19:00開場）</p>\n</li>\n<li>\n<p>場所\u3000<a href="https://goo.gl/h6U6hP" rel="nofollow">渋谷スクエアA 11F</a>（渋谷駅徒歩3分）</p>\n</li>\n<li>\n<p>参加費\u3000無料（交流会含む）</p>\n</li>\n</ul>\n<p>※20時以降来場の際はエントランスが閉まっており入館出来ませんので、到着しましたら090-1799-4545にお電話ください。</p>\n<h3>タイムスケジュール</h3>\n<ul>\n<li>\n<p>ガイダンス （10分）</p>\n</li>\n<li>\n<p>講義（60分）</p>\n</li>\n<li>\n<p>質疑応答（10分）</p>\n</li>\n<li>\n<p>懇親会（10分）</p>\n</li>\n</ul>\n<h3>参加資格</h3>\n<ul>\n<li>\n<p>エンジニア職志望の学生の方（学年不問）</p>\n</li>\n<li>\n<p>20代 or 2010年卒以下の社会人エンジニアの方</p>\n</li>\n</ul>\n<h1>講師紹介</h1>\n<p>【おやかた】</p>\n<p>2008年ごろから同人誌執筆を開始、これまでに20冊ほど発行。</p>\n<p>2017年発行の「技術同人誌を書こう」が商業化、同人版合わせて累計1500部以上。\n技術同人誌</p>\n<h1>特別抽選会を開催しています</h1>\n<p>勉強会後にサトアズグッズやオリジナルCOMPセットなどが当たる特別抽選会を開催しています。</p>\n<p>抽選は公式LINE@上で行なっております。</p>\n<p>おすすめ勉強会情報や特別なキャンペーン情報など、エンジニアの方にお得なコンテンツを発信しています！</p>\n<p>ぜひ事前に友だち登録をしてお越しください。</p>\n<p>▼LINE@の友だち登録は<a href="https://line.me/R/ti/p/%40omd2804q" rel="nofollow">こちら</a>もしくは下記のQRコードから！</p>\n<p><a href="https://line.me/R/ti/p/%40omd2804q" rel="nofollow"><img src="https://pages.supporterz.jp/rs/590-VZT-927/images/%E5%91%8A%E7%9F%A5%E7%94%BB%E5%83%8F%E3%82%A4%E3%83%A1%E3%83%BC%E3%82%B7%E3%82%992018%3A09%3A07.png" width="500px"></a></p>\n<p>※抽選会は予告なく中止になる場合もございますので、予めご了承ください。</p>\n<h1>サポーターズCoLabについて</h1>\n<p>CoLab（コラボ）は、仲間と共に（Co）、楽しみながら成長できる研究室（Lab）のような存在を目指しています。</p>\n<p>若手エンジニア向けの技術勉強会やミートアップをオリジナルコンテンツでほぼ毎日開催しており、</p>\n<p>同世代エンジニアの仕事、スキル、キャリア、悩みを知り、交流することで仲間を増やすことができます。</p>\n<p>（勉強会の講師は、サポーターズCoLabユーザーの有志が務めています）</p>\n<p>そんな仲間たちと、新たな技術を学ぶ、もの創りを始める、新しいチームにジョインする。</p>\n<p>様々な形で、キャリアを考え、動き出すきっかけを提供していきます。</p>\n<p>※connpassのシステム協力のもと、キャリア支援会社<a href="https://corp.supporterz.jp/" rel="nofollow">サポーターズ</a>が運営しています。</p>\n<p>※就活生向け：交通費がもらえる日本唯一の就活サービス「<a href="https://supporterz.jp/" rel="nofollow">サポーターズ</a>」</p>\n<h2>開催予定のイベント</h2>\n<h3>スペシャルイベント</h3>\n<p><a href="https://supporterzcolab.com/event/731/" rel="nofollow"><img src="https://img.supporterzcolab.com/thumbs/d7/0a/d70a02d6155a335c18daf2e706529916.png" width="300px"></a> \n <a href="https://supporterzcolab.com/event/746/" rel="nofollow"><img src="https://img.supporterzcolab.com/thumbs/ea/bd/eabd7ca7004bf6e1e3507ddd8f798abd.png" width="300px"></a> \n <a href="https://supporterzcolab.com/event/734/" rel="nofollow"><img src="https://img.supporterzcolab.com/thumbs/15/07/15076f0e4f50d713d0216ac760a4d4e7.png" width="300px"></a> </p>\n<ul>\n<li>\n<p>3/30（土）<a href="https://supporterzcolab.com/event/731/" rel="nofollow">【まつもとゆきひろ氏\u3000特別講演】20代エンジニアのためのプログラマー勉強法</a></p>\n</li>\n<li>\n<p>3/29（金）<a href="https://supporterzcolab.com/event/746/" rel="nofollow">19卒エンジニア限定ミートアップ</a></p>\n</li>\n<li>\n<p>4/12（金）<a href="https://supporterzcolab.com/event/734/" rel="nofollow">エンジニア "女子会" ミートアップ #2</a></p>\n</li>\n</ul>\n<h3>スペシャルキャンペーン</h3>\n<p><a href="https://supporterzcolab.com/event/788/" rel="nofollow"><img src="https://img.supporterzcolab.com/thumbs/9b/97/9b97eb33ad374b1cafa9f443f139218e. ...
#    'address': '東京都渋谷区道玄坂1-9-5',
#    'catch': 'アウトプットのススメ',
#    'accepted': 0,
#    'ended_at': '2019-04-15T21:00:00+09:00',
#    'place': '渋谷スクエアA 11F'},
#   {'event_url': 'https://supporterz-seminar.connpass.com/event/125245/',
#    'event_type': 'advertisement',
#    'owner_nickname': 'HiroakiKaede',
#    'series': {'url': 'https://supporterz-seminar.connpass.com/',
#     'id': 3032,
#     'title': 'サポーターズCoLab'},
#    'updated_at': '2019-03-23T13:18:43+09:00',
#    'lat': '35.657336100000',
#    'started_at': '2019-04-15T19:30:00+09:00',
#    'hash_tag': 'spzcolab',
#    'title': '技術同人誌を書こう【サポーターズCoLab勉強会】',
#    'event_id': 125245,
#    'lon': '139.699492800000',
#    'waiting': 0,
#    'limit': 20,
#    'owner_id': 104832,
#    'owner_display_name': 'HiroakiKaede',
#    'description': '<h1>イベント申込方法</h1>\n<p><a href="https://supporterzcolab.com/event/790/" rel="nofollow"><img src="https://supporterzcolab.com/static/img/event/btn_apply_event_on_connpass_event_detail.png"></a></p>\n<p><img src="https://pages.supporterz.jp/rs/590-VZT-927/images/%E8%B6%85%E5%88%9D%E5%BF%83%E8%80%85.png" width="200px"></p>\n<p>※知識なしでもOK</p>\n<h1>イベント概要</h1>\n<p>技術同人誌を書きませんか?あなたの持つ技術、ノウハウ、知識、そういったものを同人誌にアウトプットしましょう。</p>\n<p>技術同人誌の執筆にはメリットがたくさんあります。アウトプットの規模がちょうどよい、知識の体系化に役立つ、など。</p>\n<p>アウトプットのハードルを越える方法、超えた先にある世界をお見せします。</p>\n<h3>こんな話をします</h3>\n<ul>\n<li>\n<p>技術同人誌とは</p>\n</li>\n<li>\n<p>技術同人誌執筆のメリット</p>\n<ul>\n<li>\n<p>自分の棚卸ができる</p>\n</li>\n<li>\n<p>アウトプットの規模がちょうどよい</p>\n</li>\n<li>\n<p>企画・執筆・組版・頒布、全部自分で体験可能</p>\n</li>\n</ul>\n</li>\n<li>\n<p>合同誌寄稿から始めよう</p>\n<ul>\n<li>\n<p>合同誌のメリット</p>\n</li>\n<li>\n<p>合同誌の実際</p>\n</li>\n</ul>\n</li>\n</ul>\n<h3>こんな方にオススメ</h3>\n<ul>\n<li>\n<p>アウトプットしたい方(特にしたいけれど方法がわからない方)</p>\n</li>\n<li>\n<p>本業に飽きた方</p>\n</li>\n<li>\n<p>技術同人誌を知らなかった方</p>\n</li>\n</ul>\n<h3>当日の詳細</h3>\n<ul>\n<li>\n<p>日時\u30002019年4月15日（月）19:30-21:00（19:00開場）</p>\n</li>\n<li>\n<p>場所\u3000<a href="https://goo.gl/h6U6hP" rel="nofollow">渋谷スクエアA 11F</a>（渋谷駅徒歩3分）</p>\n</li>\n<li>\n<p>参加費\u3000無料（交流会含む）</p>\n</li>\n</ul>\n<p>※20時以降来場の際はエントランスが閉まっており入館出来ませんので、到着しましたら090-1799-4545にお電話ください。</p>\n<h3>タイムスケジュール</h3>\n<ul>\n<li>\n<p>ガイダンス （10分）</p>\n</li>\n<li>\n<p>講義（60分）</p>\n</li>\n<li>\n<p>質疑応答（10分）</p>\n</li>\n<li>\n<p>懇親会（10分）</p>\n</li>\n</ul>\n<h3>参加資格</h3>\n<ul>\n<li>\n<p>エンジニア職志望の学生の方（学年不問）</p>\n</li>\n<li>\n<p>20代 or 2010年卒以下の社会人エンジニアの方</p>\n</li>\n</ul>\n<h1>講師紹介</h1>\n<p>【おやかた】</p>\n<p>2008年ごろから同人誌執筆を開始、これまでに20冊ほど発行。</p>\n<p>2017年発行の「技術同人誌を書こう」が商業化、同人版合わせて累計1500部以上。\n技術同人誌</p>\n<h1>特別抽選会を開催しています</h1>\n<p>勉強会後にサトアズグッズやオリジナルCOMPセットなどが当たる特別抽選会を開催しています。</p>\n<p>抽選は公式LINE@上で行なっております。</p>\n<p>おすすめ勉強会情報や特別なキャンペーン情報など、エンジニアの方にお得なコンテンツを発信しています！</p>\n<p>ぜひ事前に友だち登録をしてお越しください。</p>\n<p>▼LINE@の友だち登録は<a href="https://line.me/R/ti/p/%40omd2804q" rel="nofollow">こちら</a>もしくは下記のQRコードから！</p>\n<p><a href="https://line.me/R/ti/p/%40omd2804q" rel="nofollow"><img src="https://pages.supporterz.jp/rs/590-VZT-927/images/%E5%91%8A%E7%9F%A5%E7%94%BB%E5%83%8F%E3%82%A4%E3%83%A1%E3%83%BC%E3%82%B7%E3%82%992018%3A09%3A07.png" width="500px"></a></p>\n<p>※抽選会は予告なく中止になる場合もございますので、予めご了承ください。</p>\n<h1>サポーターズCoLabについて</h1>\n<p>CoLab（コラボ）は、仲間と共に（Co）、楽しみながら成長できる研究室（Lab）のような存在を目指しています。</p>\n<p>若手エンジニア向けの技術勉強会やミートアップをオリジナルコンテンツでほぼ毎日開催しており、</p>\n<p>同世代エンジニアの仕事、スキル、キャリア、悩みを知り、交流することで仲間を増やすことができます。</p>\n<p>（勉強会の講師は、サポーターズCoLabユーザーの有志が務めています）</p>\n<p>そんな仲間たちと、新たな技術を学ぶ、もの創りを始める、新しいチームにジョインする。</p>\n<p>様々な形で、キャリアを考え、動き出すきっかけを提供していきます。</p>\n<p>※connpassのシステム協力のもと、キャリア支援会社<a href="https://corp.supporterz.jp/" rel="nofollow">サポーターズ</a>が運営しています。</p>\n<p>※就活生向け：交通費がもらえる日本唯一の就活サービス「<a href="https://supporterz.jp/" rel="nofollow">サポーターズ</a>」</p>\n<h2>開催予定のイベント</h2>\n<h3>スペシャルイベント</h3>\n<p><a href="https://supporterzcolab.com/event/731/" rel="nofollow"><img src="https://img.supporterzcolab.com/thumbs/d7/0a/d70a02d6155a335c18daf2e706529916.png" width="300px"></a> \n <a href="https://supporterzcolab.com/event/746/" rel="nofollow"><img src="https://img.supporterzcolab.com/thumbs/ea/bd/eabd7ca7004bf6e1e3507ddd8f798abd.png" width="300px"></a> \n <a href="https://supporterzcolab.com/event/734/" rel="nofollow"><img src="https://img.supporterzcolab.com/thumbs/15/07/15076f0e4f50d713d0216ac760a4d4e7.png" width="300px"></a> </p>\n<ul>\n<li>\n<p>3/30（土）<a href="https://supporterzcolab.com/event/731/" rel="nofollow">【まつもとゆきひろ氏\u3000特別講演】20代エンジニアのためのプログラマー勉強法</a></p>\n</li>\n<li>\n<p>3/29（金）<a href="https://supporterzcolab.com/event/746/" rel="nofollow">19卒エンジニア限定ミートアップ</a></p>\n</li>\n<li>\n<p>4/12（金）<a href="https://supporterzcolab.com/event/734/" rel="nofollow">エンジニア "女子会" ミートアップ #2</a></p>\n</li>\n</ul>\n<h3>スペシャルキャンペーン</h3>\n<p><a href="https://supporterzcolab.com/event/788/" rel="nofollow"><img src="https://img.supporterzcolab.com/thumbs/9b/97/9b97eb33ad374b1cafa9f443f139218e. ...
#    'address': '東京都渋谷区道玄坂1-9-5',
#    'catch': 'アウトプットのススメ',
#    'accepted': 0,
#    'ended_at': '2019-04-15T21:00:00+09:00',
#    'place': '渋谷スクエアA 11F'},
#   {'event_url': 'https://gdg-shinshu.connpass.com/event/125244/',
#    'event_type': 'participation',
#    'owner_nickname': 'kobayutapon',
#    'series': {'url': 'https://gdg-shinshu.connpass.com/',
#     'id': 1401,
#     'title': 'GDG信州'},
#    'updated_at': '2019-03-23T13:07:09+09:00',
#    'lat': '36.112047700000',
#    'started_at': '2019-04-13T17:30:00+09:00',
#    'hash_tag': '',
#    'title': '定例モクモク勉強会',
#    'event_id': 125244,
#    'lon': '137.952760300000',
#    'waiting': 0,
#    'limit': 5,
#    'owner_id': 53252,
#    'owner_display_name': 'kobayutapon',
#    'description': '<p>GDG信州\u3000定例勉強会を開催します。</p>\n<p>今回のテーマはGoogle Edge TPUとIoT デバイスの作り方講座です。</p>\n<p>発表の後、もくもく会＆相談会を行います。</p>\n<h1>スケジュール</h1>\n<table>\n<thead>\n<tr>\n<th align="left">time</th>\n<th align="left">contents</th>\n</tr>\n</thead>\n<tbody>\n<tr>\n<td align="left">17:30</td>\n<td align="left">開場</td>\n</tr>\n<tr>\n<td align="left">17:45 - 17:50</td>\n<td align="left">Introduction</td>\n</tr>\n<tr>\n<td align="left">1750 - 18:20</td>\n<td align="left">Google Edge TPU</td>\n</tr>\n<tr>\n<td align="left">18:20-18:50</td>\n<td align="left">IoTデバイスの作り方</td>\n</tr>\n<tr>\n<td align="left">18:50-20:30</td>\n<td align="left">もくもく会＆相談会</td>\n</tr>\n</tbody>\n</table>\n<h1>注意事項</h1>\n<p>・無線 LAN が利用可能です。電源はありますが融通しあいながら使いください。<br>\n・会場は禁煙です。</p>\n<p>会場使用料がかかりますので、一人２００円ほどカンパをお願いします。</p>',
#    'address': '長野県塩尻市大門一番町１２−２',
#    'catch': '今回はEdge TPUとIoTデバイスの作り方をやります',
#    'accepted': 0,
#    'ended_at': '2019-04-13T20:30:00+09:00',
#    'place': 'えんぱーく204会議室'},
#   {'event_url': 'https://svkb.connpass.com/event/120472/',
#    'event_type': 'participation',
#    'owner_nickname': 'peacezepp',
#    'series': {'url': 'https://svkb.connpass.com/',
#     'id': 1613,
#     'title': '超入門・サーバー構築勉強会'},
#    'updated_at': '2019-03-23T13:04:27+09:00',
#    'lat': '35.378819400000',
#    'started_at': '2019-04-20T13:00:00+09:00',
#    'hash_tag': '超入門・サーバー構築勉強会',
#    'title': '超入門・サーバー構築勉強会 #037 in 横浜',
#    'event_id': 120472,
#    'lon': '139.623049700000',
#    'waiting': 0,
#    'limit': 8,
#    'owner_id': 17185,
#    'owner_display_name': 'peacezepp',
#    'description': '<p><font size="+1">\nこのたび、<strong><a href="http://usg.mydns.jp/" rel="nofollow">MyDNS.JPユーザー会</a></strong>では<br>\n<strong>「超入門・サーバー構築勉強会」</strong> を<br>\n<b><a href="http://usg.mydns.jp/?p=1306" rel="nofollow">横浜市・MyDNS.JPユーザー会専用会議室<br>\n（JR京浜東北根岸線・新杉田駅より徒歩約12分）</a>にて開催します。<br>\n<br>\n\u3000※こちらで駐車場（無料）をご用意しております。<br>\n\u3000\u3000お車でお越しになる方は予約制となっておりますので、<br>\n\u3000\u3000お申込み後に<a href="http://usg.mydns.jp/?page_id=193" rel="nofollow">こちらから</a>予約のご連絡をください。<br>\n</b></font>\n<br>\n<font size="+1">\nこの勉強会は  物理マシンからのLinuxサーバー構築ではなく、<br>\n<a href="https://px.a8.net/svt/ejp?a8mat=2NIH7W+AGVFH6+50+4YOM2Q" rel="nofollow">「ConoHa VPS」（仮想専用サーバー）</a>\n<img src="https://www19.a8.net/0.gif?a8mat=2NIH7W+AGVFH6+50+4YOM2Q" alt="" width="1" height="1">を使って、LAMP(Linux/Apache/MariaDB/PHP) + バーチャルホスト設定 + CMSサーバー(WordPress)をSSHでリモート構築していく<strong>Linux入門者向け勉強会です。</strong><br>\n<br>\nディストリビューションはCentOS7です。<br>\n</font>\n<br>\n<font size="+1">\n勉強会では最初に<br>\n<strong>Linuxの基本</strong>（ディレクトリ構造、ファイル属性、リダイレクションなど）や<br>\n<strong>「vi操作」</strong>および<strong>「SSH接続」</strong>など勉強していきます。<br>\n</font>\n<br>\n<font size="+1">\nそのあとにサーバー構築の実習に入りますが、<br>\nこちらでサーバー構築の内容を実演しますので、<br>\nそれを見ながら<strong>ご自身のVPSに対し、サーバー構築実習</strong>していきます。<br>\n<br>\n実習範囲はCentOSの各設定確認から<strong>WEBサーバー立上げ</strong>、<br>\n<strong>ドメインによるアクセス</strong>、そして<strong>バーチャルホストの設定</strong>。<br>\n<br>\nそしてWEBテンプレートをインストールして、<br>\nこのようなサンプルページを公開します。<br>\n<a href="http://usg.mydns.jp/sample/" rel="nofollow">http://usg.mydns.jp/sample/</a> <br>\n<br>\nさらに、<strong>LAMP構築</strong>まで実習し、<br>\n最後に<strong>CMSサーバー（WordPress）</strong>をインストールし、<br>\nバーチャルホストで、<strong>別のURLに公開</strong>します。<br>\n<br>\nこれらの実習により、<br>\n実際のWEBサーバー運用一歩手前までサーバー構築していきます。<br>\n<br>\nLinux・WEBサーバー構築に、最低限必要な部分の勉強と<br>\nハンズオンスタイルによる<strong>「より実践的な実習」</strong>になりますので、<br>\n独学で学習するより\u3000はるかに早く確実に習得できるでしょう。<br>\n</font>\n<br>\n<font size="+1">\n<strong>特にviについては不慣れな方が多数いらっしゃいましたので<br>\nそれなりにみっちり説明します！</strong><br>\n</font>\n<br>\n<font size="+1">\nまた、進捗が良く時間に余裕が見込める場合、<br>\n<strong>SSH公開鍵認証方式</strong>も実習してみたいと思います！</font><br>\n<br>\n<font size="+1">\n入門者向け内容となっておりますので、<strong>Linux初心者の方</strong>や<br>\n<strong>そもそもVPSって何？\u3000vi（エディター）全く自信ありません！！\u3000</strong><br>\nと言った方などが対象となっておりますので、<br>\nどうぞお気軽にご参加ください。<br>\n<br>\n</font>\n<font size="+1">\nなお、Linuxの基本的な部分は少し解っていて、もっと突っ込んで勉強されたい方は<br>\n<a href="https://svrkcho.connpass.com/" rel="nofollow">【拡大版】サーバー構築ハンズオン</a>をご検討ください。</font><br></p>\n<p><br></p>\n<h2>＊＊＊用意する物＊＊＊</h2>\n<p><font size="+1">\n・ConoHaアカウント<br>\n<a href="https://px.a8.net/svt/ejp?a8mat=2NIH7W+AGVFH6+50+4YOECX" rel="nofollow">\n<img src="https://www26.a8.net/svt/bgt?aid=160425644633&amp;wid=002&amp;eno=01&amp;mid=s00000000018030011000&amp;mc=1" alt="" width="728" height="90"></a>\n<img src="https://www16.a8.net/0.gif?a8mat=2NIH7W+AGVFH6+50+4YOECX" alt="" width="1" height="1">\n<br>\n\u3000教材はConoHaのVPSを利用します。<br>\n<br>\n\u3000ConoHaアカウントは<strong>新規登録</strong>を条件に、<br>\n\u30001,000円分が利用可能となる<strong>クーポン付アカウント</strong>をご紹介しますので、<br>\n\u3000それを教材としてご利用ください。<br>\n<br>\n\u3000こちらをご参考していただき、<br>\n\u3000事前に、こ確認くださるようお願いします。<br>\n\u3000<a href="http://usg.mydns.jp/?p=593" rel="nofollow">http://usg.mydns.jp/?p=593</a>\n\u3000<br>\n<br>\n\u3000まれに「クーポンが付与されない」と言った事象がございますが、<br>\n\u3000この場合、ConoHaへお問い合わせくださるようお願いします。<br>\n\u3000<a href="https://help.conoha.jp/app/ask/?_ga=1.131819593.79876541.1443440015" rel="nofollow">ConoHaお問い合わせ先</a><br>\n<br>\n\u30001000円クーポンがどうしても付与されない場合、<br>\n\u3000別途有料でVPSをお申込みください。\u3000<br>\n<a href="https://px.a8.net/svt/ejp?a8mat=2NIH7W+AGVFH6+50+4Z49CH" rel="nofollow">\n<img src="https://www27.a8.net/svt/bgt?aid=160425644633&amp;wid=002&amp;eno=01&amp;mid=s00000000018030085000&amp;mc=1" alt="" width="728" height="90"></a>\n<img src="https://www14.a8.net/0.gif?a8mat=2NIH7W+AGVFH6+50+4Z49CH" alt="" width="1" height="1">\n\u3000<a href="https://px.a8.net/svt/ejp?a8mat=2NIH7W+AGVFH6+50+4YM976" rel="nofollow">『ConoHa VPS』【約1円/時間】</a>\n<img src="https://www18.a8.net/0.gif?a8mat=2NIH7W+AGVF ...
#    'address': '横浜市金沢区富岡東1-5-20',
#    'catch': 'VPS リモート構築ハンズオンセミナー ～WordPress構築～',
#    'accepted': 0,
#    'ended_at': '2019-04-20T18:00:00+09:00',
#    'place': 'MyDNS.JPユーザー会専用会議室(新杉田)'},
#   {'event_url': 'https://devsap.connpass.com/event/125243/',
#    'event_type': 'participation',
#    'owner_nickname': 'frnk',
#    'series': {'url': 'https://devsap.connpass.com/',
#     'id': 2043,
#     'title': 'iPhone Dev Sapporo'},
#    'updated_at': '2019-03-23T12:58:42+09:00',
#    'lat': '43.064306900000',
#    'started_at': '2019-04-05T19:00:00+09:00',
#    'hash_tag': 'devsap',
#    'title': 'try! Swift報告会 + Swift 5勉強会【iPhone Dev Sapporo番外編】',
#    'event_id': 125243,
#    'lon': '141.363281200000',
#    'waiting': 0,
#    'limit': 20,
#    'owner_id': 20018,
#    'owner_display_name': 'frnk',
#    'description': '<h2>概要</h2>\n<p>札幌圏のiOSアプリ開発者コミュニティ、iPhone Dev Sapporo主催の勉強会（の番外編）です。<br>\n3/21〜3/23におこなわれたtry! Swift Conferenceの報告会と、正式リリース間近のSwift 5についての勉強会です。</p>\n<table>\n<thead>\n<tr>\n<th>時間</th>\n<th>内容</th>\n<th>発表者</th>\n</tr>\n</thead>\n<tbody>\n<tr>\n<td>19:00 - 19:30</td>\n<td>try! Swift報告会</td>\n<td>@yusuga_</td>\n</tr>\n<tr>\n<td>19:30 - 20:30</td>\n<td>Swift 5勉強会</td>\n<td>@notoroid</td>\n</tr>\n</tbody>\n</table>',
#    'address': '札幌市中央区北1条東4丁目1番地1',
#    'catch': '札幌圏のiOSアプリ開発者コミュニティ、iPhone Dev Sapporo主催の勉強会です。',
#    'accepted': 3,
#    'ended_at': '2019-04-05T20:30:00+09:00',
#    'place': '株式会社インフィニットループ会議室（サッポロファクトリー1条館3F）'},
#   {'event_url': 'https://minihardening.connpass.com/event/125090/',
#    'event_type': 'participation',
#    'owner_nickname': 'delphinz',
#    'series': {'url': 'https://minihardening.connpass.com/',
#     'id': 1213,
#     'title': 'MINI Hardening Project'},
#    'updated_at': '2019-03-23T12:11:28+09:00',
#    'lat': '35.660462100000',
#    'started_at': '2019-04-21T10:30:00+09:00',
#    'hash_tag': 'minihardening',
#    'title': 'MINI Hardening Project #3.2@メルカリ',
#    'event_id': 125090,
#    'lon': '139.729278600000',
#    'waiting': 0,
#    'limit': 20,
#    'owner_id': 36165,
#    'owner_display_name': 'マサヒロ',
#    'description': '<p><b>＜イベント概要＞</b><br>\n・セキュアなハードニングをカジュアルに競技形式で学ぶ勉強会です<br>\n・<a href="https://wasforum.jp/hardening-project/" rel="nofollow">Hardening Project</a> と実施概要など連携した上で開催します<br>\n・競技を通じて気付きを得てもらうためのイベントです  </p>\n<p><b>＜競技概要＞</b><br>\n・当日は複数名（4名程度）を1チームとし、競技に取り組んで頂きます<br>\n・こちらが用意した環境にログインし、出来る限りサービスを継続しながらセキュアな環境を構築してください<br>\n・システム構成やシナリオに関しては当日説明します<br>\n・競技は3時間を予定しており、競技環境に対する攻撃も発生します<br>\n・対応いただいた結果は報告シートに記入頂きます。<br>\n・競技終了後に解説を行いますが、レビューした結果もフィードバック致します。  </p>\n<p><b>＜開催概要＞</b><br>\n日程：<b>2019年4月21日(日) 10:30 受付開始 / 12:00 競技スタート / 17:00 終了</b><br>\n会場：株式会社メルカリ 六本木ヒルズ森タワー 18F<br>\n最寄り駅：東京メトロ「六本木駅」、徒歩約5分</p>\n<p><b>＜会場注意点＞</b><br>\n・入館手続きに氏名が必要となりますので、申込時のアンケートへ正確に記載をお願いします。<br>\n・競技環境へ接続するPCは各自でご持参ください。  <br>\n・競技環境への接続するにはSSH接続やリモートデスクトップクライアントが必要となります。<br>\n・電源ポートに限りがありますので電源タップを持参していただきますようお願いします。<br>\n・大型のディスプレイやプリンター、ネットワーク機器等は原則持込不可です。<br>\n・競技スタートは12時ですが食事の用意はありませんので、食べておくか会場へ持参ください（ゴミは持ち帰ってください）<br>\n・途中退出が原則できませんのでご注意ください。  </p>\n<p><b>＜申し込み注意点＞</b><br>\n・参加費用は無料です。<br>\n・運営スタッフより競技内容に関するアドバイス等は行いません。チームで事前準備いただくことを推奨いたします。<br>\n・チーム編成時に<b><u>同じチームのメンバーにメールアドレスが共有</u></b>されますのでご了承ください。<br>\n・都合がつかなくなった場合には、迅速にキャンセルをお願いします。直前のキャンセルは迷惑がかかりますので、理由を添えて運営までご相談ください。<br>\n・ドタキャンや連絡なしの欠席は運営にも支障を来たしますので、今後のイベントへの参加をお断りする場合があります。<br>\n・チームでの参加を希望される方もメンバー全員登録いただき、チーム名とメンバーアカウントをConnpass上でお知らせください。(人数が多い場合、ご要望に添えず調整させていただく場合がございます)<br>\n・競技環境への接続方法は競技直前までにご案内致します。<br>\n・当日運営スタッフが記録のために写真撮影を行います。撮影した写真は公開されることがありますので予めご了承ください。(もし写真撮影NGであれば、当日確認しますのでお知らせください。)<br>\n・上記注意点すべてをご了承いただいた上で、申込みいただきますようお願いします。 </p>\n<p><b>＜タイムライン(概要)＞</b><br>\n10:30 会場受付開始<br>\n11:00 ハードニング競技説明開始<br>\n12:00 ハードニング競技スタート<br>\n15:00 ハードニング終了・休憩<br>\n15:30 特別講義：未定<br>\n16:00 競技の振り返り・解説<br>\n16:30 片付け<br>\n17:00 懇親会  </p>\n<p><b>＜関連リンク＞</b><br>\n・<a href="https://wasforum.jp" rel="nofollow">WASForum</a><br>\n・<a href="https://minih.wasforum.jp" rel="nofollow">MINI Hardening</a></p>',
#    'address': '東京都港区六本木6-10-1六本木ヒルズ森タワー',
#    'catch': '今回はメルカリさんで共催！',
#    'accepted': 0,
#    'ended_at': '2019-04-21T17:30:00+09:00',
#    'place': '株式会社メルカリ'},
#   {'event_url': 'https://django.connpass.com/event/125045/',
#    'event_type': 'participation',
#    'owner_nickname': 'hirokiky',
#    'series': {'url': 'https://django.connpass.com/',
#     'id': 254,
#     'title': 'djangoja'},
#    'updated_at': '2019-03-23T11:56:49+09:00',
#    'lat': '35.686402100000',
#    'started_at': '2019-04-18T19:00:00+09:00',
#    'hash_tag': '',
#    'title': 'DjangoCongress JP 2019 4月作業日',
#    'event_id': 125045,
#    'lon': '139.703513600000',
#    'waiting': 0,
#    'limit': 10,
#    'owner_id': 584,
#    'owner_display_name': 'hirokiky',
#    'description': '<h1>DjangoCon JP 2019 の作業日です</h1>\n<p>DjangoCon JP 2019のタスクなどをこなしたり、必要な話があればやってしまう場所です。\nとくに何かを提供したり、ミーティングというわけではないです。</p>\n<ul>\n<li>DjangoConJPについて: <a href="https://github.com/django-ja/DjangoConJP" rel="nofollow">https://github.com/django-ja/DjangoConJP</a></li>\n<li>DjangoCon JP 2019について: <a href="https://github.com/django-ja/DjangoConJP/tree/master/DjangoConJP2019" rel="nofollow">https://github.com/django-ja/DjangoConJP/tree/master/DjangoConJP2019</a></li>\n</ul>\n<p>参加自由です。\n途中参加も可能です。</p>\n<ul>\n<li>発注系の作業</li>\n<li>タスクの状態を確認する</li>\n</ul>\n<h2>会場</h2>\n<ul>\n<li>Wifi: あります</li>\n<li>電源: あります</li>\n<li>飲食: 可能です（キレイに使ってください）</li>\n</ul>\n<h3>入り方の注意</h3>\n<p>ビル4Fに上がって、左の奥のドアから入ってください。\nその奥の会議室に直接来てください（ノック要りません）</p>\n<p><strong>オフィススペースには入らないようにお願いします</strong></p>',
#    'address': ' 渋谷区千駄ヶ谷5-32-7(NOF南新宿ビル4F) ',
#    'catch': '',
#    'accepted': 2,
#    'ended_at': '2019-04-18T20:30:00+09:00',
#    'place': '株式会社ビープラウド'},
#   {'event_url': 'https://ansible-users.connpass.com/event/124686/',
#    'event_type': 'participation',
#    'owner_nickname': 'ian',
#    'series': {'url': 'https://ansible-users.connpass.com/',
#     'id': 782,
#     'title': 'Ansible ユーザー会'},
#    'updated_at': '2019-03-23T10:50:34+09:00',
#    'lat': '35.657252700000',
#    'started_at': '2019-04-20T10:00:00+09:00',
#    'hash_tag': 'ansiblejp',
#    'title': 'Ansibleもくもく会 （サーバ編）2019.04 in 甲府！',
#    'event_id': 124686,
#    'lon': '138.565079800000',
#    'waiting': 0,
#    'limit': 32,
#    'owner_id': 3,
#    'owner_display_name': 'Ian Lewis',
#    'description': '<h1>イベント概要</h1>\n<p>Ansible 及び Ansible Towerに関してもくもく勉強をしていく場になります。今回はGitHubに公開もされている、Ansible Tower含むハンズオンコンテンツ(日本語あります！)を活用しながらもくもくしてみましょう！今回はレッドハットのメンバー数名が支援いたします。また、何度かもくもく会でメンターに立候補してもらっている方も可能な方は参加していただけますので、ぜひともよろしくお願いいたします。</p>\n<p>ちなみに今までのメンター立候補者は以下の方々です。</p>\n<ul>\n<li>curry9999さん</li>\n<li>ritchey98さん</li>\n<li>yteraokaさん</li>\n<li>pocopocoさん</li>\n<li>akira6592さん</li>\n<li>chiyomikanさん</li>\n<li>kooshinさん</li>\n</ul>\n<h2>提供コンテンツ</h2>\n<p>当日は、Ansible及びAnsible Towerが使えるようにAWSの環境を提供いたします。</p>\n<ul>\n<li>\n<p><a href="https://github.com/network-automation/linklight/tree/master/exercises" rel="nofollow">ワークショップコンテンツ</a></p>\n</li>\n<li>\n<p><a href="https://github.com/h-kojima/ansible/tree/master/ansible-tower#ansible-tower%E3%81%AE%E6%A6%82%E8%A6%81" rel="nofollow">Ansible Tower利用ガイド</a></p>\n</li>\n</ul>\n<h2>当日のアジェンダ</h2>\n<ul>\n<li>9:45 - 10:00: 受付オープン</li>\n<li>10:00 - 10:10: オープニング</li>\n<li>10:10 - 10:50: Ansibleではじめるサーバー・ネットワークの自動化 by エーピーコミュニケーションズ 横地晃さん！</li>\n<li>10:50 - 11:30: もくもく開始</li>\n<li>11:30 - 12:30: お昼休憩</li>\n<li>12:30 - 14:00: もくもく継続</li>\n<li>14:00 - 14:15: 成果共有</li>\n<li>14:15 - 14:30: お片付け＆撤収</li>\n</ul>\n<h2>参加者の前提：</h2>\n<ul>\n<li>受講要件Linuxの基礎操作（vi エディタ、各種ファイルの操作）が可能であること</li>\n</ul>\n<h2>受講に必要なもの:</h2>\n<ul>\n<li>WiFi 接続可能なノートPCを持参してください。</li>\n<li>SSHクライアント（TeraTerm, Putty等）が利用可能なこと</li>\n<li>ブラウザ（Firefox, Chromeの最新版を推奨）が利用可能なこと</li>\n</ul>\n<h2>参加枠について</h2>\n<p>可能な限り片付け/撤収作業のヘルプをしていただけると助かりますm(<em> </em>)m\n直前キャンセルの方が多くなっております。キャンセルは繰り上がりの方向けに早めにお願いいたします。</p>\n<ul>\n<li>一般参加枠：抽選で選出します</li>\n<li>リモート参加枠：ウェブ会議サービスからしか参加できないかた</li>\n<li>ブログ枠：今回学んだ内容についてブログを書いていただける方</li>\n<li>成果共有LT枠：もくもく会の最後の成果共有で発表をしていただける方</li>\n<li>次回メンター立候補枠：次回メンターとしてサポートいただける方（質問ある方へのサポートなど）</li>\n<li>メンター枠：前回立候補頂いた方</li>\n</ul>\n<p><strong>☆ブログ枠、成果共有枠、次回メンター立候補枠で参加頂いた方にはノベルティをプレゼント致します☆</strong></p>\n<p>前回参加者の方で受講希望の方はConnpassでの受付外で対応いたします。mnakamur@redhat.com までご連絡ください。</p>\n<h3>リモート参加枠について</h3>\n<p>開催直前に参加者にウェブ会議参加用のURLを送付いたします。\n不具合などありましたら、mnakamur@redhat.com までご連絡ください。</p>\n<p>また、事前チェックは以下にアクセスいただき、ウェブ会議サービスへアクセスし、自分の声が返ってこれば正常に動いています。<a href="https://bluejeans.com/111/" rel="nofollow">事前チェックへのリンク</a></p>\n<h3>参加費</h3>\n<p>無料</p>\n<h2>主催</h2>\n<p>Ansibleユーザー会</p>\n<h2>サポート</h2>\n<p>レッドハット株式会社 （運営）</p>\n<p>株式会社アイティードゥ （会場＆お菓子）</p>\n<h2>会場</h2>\n<ul>\n<li>株式会社アイティードゥ 1階会議室</li>\n<li>住所: 〒400-0858 山梨県甲府市相生1-7-4 秋山ビル</li>\n<li>URL: <a href="http://itdo.jp/company/access/" rel="nofollow">http://itdo.jp/company/access/</a></li>\n</ul>\n<h3>入館について</h3>\n<p>当日は、 受付票をスマートフォン等でご提示ください。</p>\n<h3>注意事項</h3>\n<ul>\n<li>受付票に記載の本人のみが参加できます。 受付票をお持ちでない方は入場できません。</li>\n<li>無線LANは利用可能ですがつながりにくくなると予想されるので、テザリングをご利用ください。</li>\n<li>電源タップは数に限りがあります。</li>\n</ul>\n<h3>懇親会について</h3>\n<p>公式な懇親会は特に予定しておりませんが、有志の食事会（Ansible飯）はその場の雰囲気で実施します。</p>',
#    'address': '山梨県甲府市相生1-7-4 (秋山ビル)',
#    'catch': 'Ansible Engine / Ansible Tower を触ってみよう！',
#    'accepted': 1,
#    'ended_at': '2019-04-20T14:30:00+09:00',
#    'place': '株式会社アイティードゥ 1階会議室'},
#   {'event_url': 'https://omotesandorb.connpass.com/event/125126/',
#    'event_type': 'participation',
#    'owner_nickname': 'sinsoku',
#    'series': {'url': 'https://omotesandorb.connpass.com/',
#     'id': 1219,
#     'title': 'Omotesando.rb'},
#    'updated_at': '2019-03-23T10:29:07+09:00',
#    'lat': '35.662785300000',
#    'started_at': '2019-04-04T19:30:00+09:00',
#    'hash_tag': 'omotesandorb',
#    'title': '表参道.rb #45',
#    'event_id': 125126,
#    'lon': '139.709048100000',
#    'waiting': 0,
#    'limit': 40,
#    'owner_id': 254,
#    'owner_display_name': 'sinsoku',
#    'description': '<h1>内容</h1>\n<p>表参道.rb は表参道周辺のエンジニアが集まって Ruby の周辺技術に関する何かを行う地域Rubyistコミュニティです。<br>\n<em>毎月第一木曜日</em> に開催しています。最近はLTが多めです。</p>\n<h1>LT大会</h1>\n<ul>\n<li>今回はテーマ<strong>フリー</strong>です。Web開発に関係することならなんでもOKです。</li>\n<li>Rails developers meetup 2019の感想、RubyKaigi 2019 の予習ネタ大歓迎です。</li>\n<li>発表時間の制限はありませんが5〜10分程度の方が多いです。</li>\n<li>申し込みの際、可能であればLTのタイトルを教えていただけると幸いです。</li>\n</ul>\n<h1>懇親会</h1>\n<p>今回はSansan株式会社のご厚意によりケータリングとお酒とソフトドリンクが提供されるため、同会場にて懇親会を引き続き行います。\n※ 参加は任意です。</p>\n<h1>タイムスケジュール</h1>\n<table>\n<thead>\n<tr>\n<th>時間</th>\n<th>内容</th>\n</tr>\n</thead>\n<tbody>\n<tr>\n<td>19:00</td>\n<td>開場</td>\n</tr>\n<tr>\n<td>19:30</td>\n<td>開始</td>\n</tr>\n<tr>\n<td>22:30</td>\n<td>完全撤収予定</td>\n</tr>\n</tbody>\n</table>\n<h1>会場について</h1>\n<p><a href="http://jp.corp-sansan.com/" rel="nofollow">Sansan株式会社</a><br>\n東京都渋谷区神宮前5-52-2 青山オーバルビル 13F </p>\n<h2>最寄り駅</h2>\n<ul>\n<li>表参道駅 B1出口から徒歩6分</li>\n</ul>\n<h2>備考</h2>\n<ul>\n<li>WiFiはあります。</li>\n<li>電源は登壇者のみとなります。ご了承ください。</li>\n<li>イベントの様子を写真や動画で撮影させていただくことがございます。予めご了承ください。</li>\n</ul>\n<h2>運営用 Slack チャンネル</h2>\n<p><a href="https://omotesandorb.herokuapp.com/" rel="nofollow">https://omotesandorb.herokuapp.com/</a></p>\n<p>次回の開催内容など、Slack で話しています。<br>\n興味がある方はどなたでも参加可能です。</p>',
#    'address': '東京都渋谷区神宮前5-52-2 青山オーバルビル13F',
#    'catch': '',
#    'accepted': 10,
#    'ended_at': '2019-04-04T22:00:00+09:00',
#    'place': 'Sansan株式会社'},
#   {'event_url': 'https://coderdojo-nada.connpass.com/event/125231/',
#    'event_type': 'participation',
#    'owner_nickname': 'coderdojo-nada',
#    'series': {'url': 'https://coderdojo-nada.connpass.com/',
#     'id': 5067,
#     'title': 'CoderDojo Nada'},
#    'updated_at': '2019-03-23T09:34:54+09:00',
#    'lat': '34.722448800000',
#    'started_at': '2019-04-28T14:00:00+09:00',
#    'hash_tag': '',
#    'title': '第14回 CoderDojo Nada(灘)(深江会場)【メンター募集】',
#    'event_id': 125231,
#    'lon': '135.291650600000',
#    'waiting': 0,
#    'limit': 12,
#    'owner_id': 196577,
#    'owner_display_name': 'CoderDojo Nada',
#    'description': '<h1>応募していただく方へお願いしたいこと</h1>\n<ul>\n<li><strong>応募のあった忍者の希望するプログラミング言語をサポートできる方</strong>を募集します。  </li>\n<li><strong>いっしょに勉強していくという姿勢</strong>があれば、入門書に目をとおした程度の知識でも構いません。  </li>\n<li>メンターとして忍者を<strong>サポートできない方も見学者としての参加は可能</strong>です。  </li>\n<li><strong>他の参加者と情報共有</strong>してください。<br>\n  参加者同士で情報共有することで、楽しみをシェアしていきたいと思います。  </li>\n</ul>\n<h2>初めてメンターをされる方</h2>\n<p>初めてメンターをされる方は、いろいろ不安に思われることもあるかと思います。<br>\nそういう場合は、メンターとしてお申し込みされる前に、まずは <a href="https://goo.gl/forms/jzXi2CKhGRXovnMo1" rel="nofollow" title="ご質問・ご相談">ご質問・ご相談</a> ください。  </p>\n<p>CoderDojo Nada で初めてメンターをされる方は CoderDojo Nada で活動するメンターとして「CoderDojo Nada メンター同意書」に同意頂いた上で、メンバー登録をしてください。<br>\n登録はこちらの <a href="https://coderdojo-nada.github.io/consent.html" rel="nofollow" title="メンター登録フォーム">メンター同意書・登録フォーム</a> からお願いします。<br>\n今まで、一度もメンター経験のない方は、見学者としての参加をお願いすることがあります。  </p>\n<h1>CoderDojo Nada とは</h1>\n<p><a href="https://coderdojo-nada.connpass.com/" rel="nofollow" title="CoderDojo Nada グループページ">CoderDojo Nada グループページ</a> を参照してください</p>\n<h1>CoderDojo Nada でサポートするプログラミング言語</h1>\n<table>\n<thead>\n<tr>\n<th align="left">プログラミング言語</th>\n<th>サポート内容</th>\n</tr>\n</thead>\n<tbody>\n<tr>\n<td align="left">JavaScript</td>\n<td>Canvas、8x9Craft、enchant.js、その他、ゲーム、Webサイト作成など</td>\n</tr>\n<tr>\n<td align="left">Python</td>\n<td>Pygame、NumPy、AI(ディープラーニングの初歩)、その他、ゲーム作りなど</td>\n</tr>\n<tr>\n<td align="left">その他</td>\n<td>忍者の応募があったプログラミング言語</td>\n</tr>\n</tbody>\n</table>\n<ul>\n<li>その他の言語でも、忍者の応募があればメンターを受け付けます。  </li>\n<li><strong>サポートできる言語や内容を申し込みの際、アンケートにご記入ください</strong>。  </li>\n</ul>\n<h1>タイムスケジュール</h1>\n<table>\n<thead>\n<tr>\n<th>時間</th>\n<th>参加者</th>\n<th>予定</th>\n</tr>\n</thead>\n<tbody>\n<tr>\n<td>14:00 - 14:30</td>\n<td>忍者・メンター</td>\n<td>自己紹介・CoderDojoの説明</td>\n</tr>\n<tr>\n<td>14:30 - 16:30</td>\n<td>忍者・メンター</td>\n<td>プログラミング</td>\n</tr>\n<tr>\n<td>16:30 - 17:00</td>\n<td>忍者（メンター）</td>\n<td>発表（情報共有）</td>\n</tr>\n<tr>\n<td>17:00 - 17:10</td>\n<td>メンター・忍者（任意）</td>\n<td>休憩</td>\n</tr>\n<tr>\n<td>17:00 - 17:50</td>\n<td>メンター・忍者（任意）</td>\n<td>勉強会</td>\n</tr>\n<tr>\n<td>17:50 - 18:00</td>\n<td>メンター（任意）</td>\n<td>後片付け</td>\n</tr>\n</tbody>\n</table>\n<p>※勉強会の参加は任意です。<br>\n※勉強会は参加メンターが誰でも理解できるような内容にしたいと思います。<br>\n※勉強会は発表者を募集してます。（発表したい方は事前にご連絡ください）  <br>\n※発表が終わるのが17時半を超えた場合は勉強会は中止にします。  </p>\n<h1>参加方法</h1>\n<ul>\n<li>Connpass にユーザー登録をし、上の「このイベントに申し込む」から参加登録を行ってください。  </li>\n<li>facebookユーザ、twitterユーザと連携することもできます。  </li>\n<li>携帯電話・スマホでPCメールからのメール受信を拒否されている方は、メールが届きませんので解除をしてください。<br>\n(「@connpass.com」「@coderdojo.com」の2ドメイン)  </li>\n<li>参加希望者が定員を上回る場合は抽選とさせていただきます。  </li>\n<li><strong>参加希望者が定員に達しない場合でも、サポートできるプログラミング内容を希望する忍者がいなければ、参加できない場合があります。</strong>  </li>\n<li>メンターは中学生、高校生が担当する場合もあります。  </li>\n</ul>\n<h1>会場へのアクセス</h1>\n<p>右の「会場」の地図を参照してください。<br>\n阪神深江駅（南出口）徒歩１分（ローソンがあるビルの２階です。エレベータはありませんので、階段をご利用ください。）<br>\nなお、このビルには利用可能な駐車場はありません。（電車で来られることを推奨します）<br>\n当ビル店舗共用の自転車・バイク置場は、8:30から19:30まで利用可能です。  </p>\n<h1>必要な持物</h1>\n<ul>\n<li>無線LAN につなぐことができるノートパソコン(電源コードも忘れずに持参してください)<br>\n  最近3〜5年以内に発売された、Windows や Mac パソコン<br>\n  iPad などのタブレット、スマートホンだけでは参加できません。<br>\n  古すぎるパソコンでは学習できない場合がございます。<br>\n  パソコンの貸出は２台まで可能です。\n  Raspberry Piも貸出が可能です。  </li>\n<li>マウス（必要であれば）</li>\n<li>筆記用具（必要であれば）</li>\n<li>書籍（教える時に参考にしたい本、紹介したい本があれば）</li>\n<li>その他、各自が作業に必要だと思うもの</li>\n</ul>\n<h1>おことわり</h1>\n<p>CoderDojo 当日は、イベントの内容の写真・ビデオ撮影をさせていただきます。<br>\n撮影した内容は、Creative Commons ライセンスで再利用可能な状態で公開いたします。<br>\n参加者は原則、写真撮影・ビデオ撮影 OK という認識でおります。<br>\n<strong>もしも写真撮影・ビデオ撮影が不都合のある方は事前に申し出てください。</strong>  </p>\n<h2>CoderDojo Nada 参加者同意書への同意のお願い</h2>\n<p>CoderDojo Nada の参加者全員に「CoderDojo Nada 参加者同意書」に同意していただく必要があります。<br>\nCoder Dojo Nada に参加いただく際に守っていただくべきルール、条件などを記載しています。  </p>\n<h1>CoderDojo Nada 参加者同意書</h1>\n\n<p>私は、CoderDojo Nada に参加するにあたり、以下の点に同意します。  </p>\n<h3>CoderDojoについての理解</h3>\n\n<p>CoderDojoとは、子どもたち（CoderDojoでは忍者と呼びます）に「プログラミングを学ぶ場を提供するボランティア活動」であり、活動の中心は忍者であることを理解しています。<br>\n各地のCoderDojoは、CoderDojoの精神を共有していますが、それぞれ独自に運営されています。<br>\n従って本同意書は、CoderDojo Nada が独自に作成および採用しているものであることを理解しています。  </p>\n< ...
#    'address': '兵庫県神戸市東灘区深江本町3-9-1 深江駅前ビル201',
#    'catch': '中学生・高校生にJavaScript、Python、Cなどのサポートをお願いします',
#    'accepted': 0,
#    'ended_at': '2019-04-28T18:00:00+09:00',
#    'place': '深江会場（ニルキューブ）'},
#   {'event_url': 'https://unagi-py.connpass.com/event/125029/',
#    'event_type': 'participation',
#    'owner_nickname': 'Nakaishi_J',
#    'series': {'url': 'https://unagi-py.connpass.com/',
#     'id': 4880,
#     'title': 'Unagi.py'},
#    'updated_at': '2019-03-23T13:18:19+09:00',
#    'lat': '34.698402400000',
#    'started_at': '2019-04-06T13:30:00+09:00',
#    'hash_tag': '',
#    'title': 'Unagi.py 勉強会16枚目～Pythonでアルゴリズムの基本、他～',
#    'event_id': 125029,
#    'lon': '137.717421400000',
#    'waiting': 0,
#    'limit': 20,
#    'owner_id': 134587,
#    'owner_display_name': 'Nakaishi_J',
#    'description': '<h1><a href="https://unagi-py.connpass.com/" rel="nofollow">Unagi.py</a> 第16枚目:  さらば、平成。さらば、アルゴリズムが苦手な私。</h1>\n<p>今回は、Pythonに関する小ネタを出し合って勉強する会とします。</p>\n<p>...と言っても何もお題がないとネタに困るでしょうから、次をメインのお題とします。</p>\n<p><strong> ◆ お題: 試験に出る(!?)アルゴリズムをPythonで復習する </strong></p>\n<p>今年9月から、情報処理推進機構(IPA)の「情報処理技術者試験」のプログラム言語にPython言語が加わります。\n(代わりにCOBOLが消えるみたい(´・ω・｀)  なお今回の4/21の試験では旧仕様のままです。)</p>\n<p>ということで、、、基本的なアルゴリズムの問題をPythonで考えてみましょう。\n各自、自分が気になったアルゴリズムを紹介してください。本やWebの例を紹介してくれてもOKです。\nまた、「この問題がよく分からないから教えて！」、というのもアリです。</p>\n<p>※ 試験に関係なくアルゴリズムでもOKです。応用的なものとか、ゲームで使われるアルゴリズムとかも。  </p>\n<p><strong> ◆ その他の話題やLTも是非！ </strong></p>\n<p>上述のお題に関係なく、いろんな話題でしゃべっていただいて結構です。\n本やWeb記事を読んでみた感想とか、「○○が出来なくて困っている」みたいな質問も大歓迎です。\n時間は1分でも5分でも15分でもご自由に。</p>\n<p>しゃべる内容が決まっている方は、申込時のアンケートに記入してください。\nまたは当日に飛び入りでしゃべっていただいてもOKです。</p>\n<p>※ 内容は、都合により変わるかもしれません。<br>\n※ ゆる～い勉強会です。今回は進行ゆるめの会となりますので、ご承知ください。  </p>\n<h1>お品書き</h1>\n<h2>時間割</h2>\n<table>\n<thead>\n<tr>\n<th align="left">時間</th>\n<th align="left">内容</th>\n</tr>\n</thead>\n<tbody>\n<tr>\n<td align="left">13:05～</td>\n<td align="left">開場</td>\n</tr>\n<tr>\n<td align="left">13:30～</td>\n<td align="left">はじめに説明など</td>\n</tr>\n<tr>\n<td align="left">13:40～</td>\n<td align="left"><a href="http://Unagi.py" rel="nofollow">Unagi.py</a>(Pythonでアルゴリズム,他)</td>\n</tr>\n<tr>\n<td align="left">～</td>\n<td align="left">～</td>\n</tr>\n<tr>\n<td align="left">～ 16:00</td>\n<td align="left">自由時間</td>\n</tr>\n<tr>\n<td align="left">16:00～</td>\n<td align="left">機械学習浜名湖</td>\n</tr>\n<tr>\n<td align="left">～</td>\n<td align="left">～</td>\n</tr>\n<tr>\n<td align="left">18:30くらい</td>\n<td align="left">片付け ＆ 懇親会(ファミレス等へ)</td>\n</tr>\n</tbody>\n</table>\n<ul>\n<li>今回は「<a href="https://unagi-py.connpass.com/" rel="nofollow">Unagi.py</a>」と「<a href="https://ml-hamanako.connpass.com/event/" rel="nofollow">機械学習浜名湖</a>」で合同で行います。  </li>\n<li>前半は、Pythonが主な話題で、その後引き続き16:00くらいから機械学習寄りの話題となります。</li>\n<li>両方に参加する方が多いですが、片方だけの参加もOKです。 (途中退出などご自由に) </li>\n<li>機械学習の方の参加は、人数把握のため<a href="https://ml-hamanako.connpass.com/event/" rel="nofollow">こちらから</a>Connpassに参加登録をお願いします。</li>\n<li>今回は両方ともお気楽な感じで、ゆるーく勉強会を行っています。\n   自由時間が多めなので、話題提供や質問がありましたら大歓迎ですので是非どうぞ。</li>\n</ul>\n<h2>発表の内容(予定)</h2>\n<table>\n<thead>\n<tr>\n<th align="left">発表者</th>\n<th align="left">内容</th>\n</tr>\n</thead>\n<tbody>\n<tr>\n<td align="left">chuui</td>\n<td align="left">Pandasのデータ構造(TidyData)の<a href="https://becominghuman.ai/cheat-sheets-for-ai-neural-networks-machine-learning-deep-learning-big-data-678c51b4b463" rel="nofollow">チートシート</a>の紹介</td>\n</tr>\n<tr>\n<td align="left">内緒</td>\n<td align="left">動的計画法の解説(をしてくれるかも)</td>\n</tr>\n<tr>\n<td align="left">未定</td>\n<td align="left">(発表内容募集中です！)</td>\n</tr>\n</tbody>\n</table>\n<p>※ 内容は、発表者の都合により変わるかもしれません。  </p>\n\n\n<h1>当日・会場について</h1>\n<ul>\n<li>今回の場所は「県居協働センター(あがたいきょうどうせんたー)」です。 駅から徒歩20分ほどです。商工会議所の隣です。</li>\n<li>駐車場があります。一杯の場合はとなりの浜松商工会議所の駐車場(有料)も使ってください。\n   ( 1グループ6台までなので何度か参加している方は、なるべく有料側で調整。)</li>\n<li>部屋は2Fの「講座室」で「CoderDojo浜松」で予約しています。</li>\n<li>会場に無線LANはありません。電源はあります。</li>\n<li>勉強会の後は食事会をします。近くのファミレスなどで。当日に参加確認するのでこちらもぜひ。</li>\n</ul>\n\n\n\n\n\n\n<h1><a href="https://unagi-py.connpass.com/" rel="nofollow">Unagi.py</a>とは</h1>\n<p><a href="https://unagi-py.connpass.com/" rel="nofollow">Unagi.py</a> とは、Pythonを中心にIT関連技術を勉強するコミュニティーのことです。 主に浜名湖の周辺に生息しているIT技術者で構成されています。活動については月1回集まって勉強会をしています。勉強会の内容は、参加者の興味や意向によってその都度決まります。</p>\n<h3>トークや発表はいつでも募集中：</h3>\n<p><a href="https://unagi-py.connpass.com/" rel="nofollow">Unagi.py</a> では、LTとか発表したい方はいつでも大歓迎です！ \nPyに関係しなくてもIT関連の話題なら何でもOKです。お気軽に！</p>\n<h3>関連する予定</h3>\n<ul>\n<li>4/6(土) :  <a href="https://unagi-py.connpass.com/" rel="nofollow">Unagi.py</a> 16枚目 ＆ 機械学習浜名湖 (県居協働センター)</li>\n<li>4/7(日) : CoderDojo浜松(鴨江アートセンター) </li>\n<li>5/25(土):  <a href="https://unagi-py.connpass.com/" rel="nofollow">Unagi.py</a>  合同勉強会 in 藤枝市 (調整中)</li>\n</ul>\n<p>などなど。</p>',
#    'address': '浜松市中区東伊場二丁目7-2',
#    'catch': '基本情報処理試験Python採用記念、平成最後的Unagi.py且機械学習浜名湖勉強会 〜算法編〜',
#    'accepted': 5,
#    'ended_at': '2019-04-06T16:00:00+09:00',
#    'place': '浜松市県居協働センター'},
#   {'event_url': 'https://kagoben.connpass.com/event/125141/',
#    'event_type': 'participation',
#    'owner_nickname': 'masakura',
#    'series': {'url': 'https://kagoben.connpass.com/',
#     'id': 2586,
#     'title': 'かごべん'},
#    'updated_at': '2019-03-23T08:28:41+09:00',
#    'lat': '31.592460000000',
#    'started_at': '2019-04-20T13:00:00+09:00',
#    'hash_tag': '',
#    'title': 'かごもく #19 シングルサインオン!',
#    'event_id': 125141,
#    'lon': '130.558524000000',
#    'waiting': 0,
#    'limit': 10,
#    'owner_id': 30069,
#    'owner_display_name': 'Tomo Masakura',
#    'description': '<h1>かごもく #19 - シングルサインオン!</h1>\n<p>かごもくは、毎月一回テーマを一つ決めてそれに沿う形で開催される勉強会です。ここのところ、ネタっぽいものがおおかったですが、第 19 回目は実用性の高いシングルサインオンをテーマに扱います。</p>\n<p>自分たちのアプリにシングルサインオンや SNS 認証を組み込んでみたい方、仕組みを知りたい方、など。興味がある方はぜひ、発表を聞いて、自分で作ってみましょう!</p>\n<p>また、シングルサインオンを過去にされた方、苦労話を LT してみませんか? 大歓迎です!</p>\n<p>いつものように、途中参加・途中退席 OK なので、ぜひご参加ください。</p>\n<h2>スケジュール</h2>\n<table>\n<thead>\n<tr>\n<th>時刻</th>\n<th>内容</th>\n<th>発表者</th>\n<th>所属</th>\n</tr>\n</thead>\n<tbody>\n<tr>\n<td>12:45</td>\n<td>開場</td>\n<td></td>\n<td></td>\n</tr>\n<tr>\n<td>13:00 - 13:05</td>\n<td>ご案内</td>\n<td></td>\n<td></td>\n</tr>\n<tr>\n<td>13:05 - 13:35</td>\n<td>OpenID Connect 入門</td>\n<td>政倉 智</td>\n<td>codeArts 株式会社</td>\n</tr>\n<tr>\n<td>13:35 - 14:10</td>\n<td>SAML (仮)</td>\n<td>上釜 幸大</td>\n<td>株式会社現場サポート</td>\n</tr>\n<tr>\n<td>14:10 - 16:30</td>\n<td>もくもく</td>\n<td>各自</td>\n<td></td>\n</tr>\n<tr>\n<td>16:30 - 17:00</td>\n<td>LT</td>\n<td>希望者がいれば</td>\n<td></td>\n</tr>\n</tbody>\n</table>\n<ul>\n<li>発表時間は目安です</li>\n</ul>\n<h2>内容</h2>\n<h3>OpenID Connect 入門</h3>\n<p>発表者: 政倉 智 (codeArts 株式会社)</p>\n<p>OpenID Connect の要となるトークンの JWT の解説を中心に、ウェブアプリ・SPA・ネイティブアプリごとに OpenID Connect のフローがどのようになっているかを解説します。</p>\n<h3>SAML (仮)</h3>\n<p>発表者: 上釜 幸大 (株式会社現場サポート)</p>\n<p>調整中</p>\n<h2>ご準備</h2>\n<p>もくもくされたい方は以下のものをご準備ください。</p>\n<ul>\n<li>WiFi がつながるノートパソコン</li>\n</ul>\n<h2>ご注意事項</h2>\n<ul>\n<li>会場は TUKUDDO ですが、移転先となりますのでご注意ください</li>\n<li>会場には駐車場がございません</li>\n<li>ごみは各次お持帰りください</li>\n<li>参加費はドリップコーヒー一杯を含みます</li>\n<li>会場は WiFi が使えます</li>\n<li>今回も学生の参加費を無料にしてみました</li>\n</ul>\n<h2>かごもく</h2>\n<p>かごもくでは、勉強会のネタを募集しております。プログラミングだけでなく、サーバー運用や、デザインでもなんでも! 悩みが解決できるかどうかはわかりませんが、似たようなことをやっている人と話せるだけでも進歩です!</p>\n<p>興味があある方は<a href="https://docs.google.com/forms/d/e/1FAIpQLSefYenHL-UKOgNywb9EzRDxH21sj_n1tLOFqKAaWUUAjp4nkw/viewform" rel="nofollow">テーマ申し込みフォーム</a>からお申し込みください。</p>',
#    'address': '鹿児島県鹿児島市泉町1-8西ビル',
#    'catch': 'SAML とか OpenID Connect とか',
#    'accepted': 2,
#    'ended_at': '2019-04-20T17:00:00+09:00',
#    'place': 'TUKUDDO (移転先)'},
#   {'event_url': 'https://soleildatadojo.connpass.com/event/125226/',
#    'event_type': 'participation',
#    'owner_nickname': 'SOLEIL_DATA_DOJO',
#    'series': {'url': 'https://soleildatadojo.connpass.com/',
#     'id': 2625,
#     'title': 'SOLEIL DATA DOJO'},
#    'updated_at': '2019-03-23T00:59:30+09:00',
#    'lat': '34.695148700000',
#    'started_at': '2019-04-04T19:30:00+09:00',
#    'hash_tag': '',
#    'title': '【4/4（木）】『Deep Learning』輪読会#11',
#    'event_id': 125226,
#    'lon': '135.501701200000',
#    'waiting': 0,
#    'limit': 8,
#    'owner_id': 101558,
#    'owner_display_name': 'SOLEIL DATA DOJO',
#    'description': '<h1>P63『3.9.5 The Dirac Distribution and Empirical Distribution』からスタートします。</h1>\n<p><img src="https://www.dropbox.com/s/mpkcqfji6eq7x8u/solimage.jpg?raw=1" alt="solimage.jpg"></p>\n<h1>本勉強会の内容と目的</h1>\n<ul>\n<li>Ian Goodfellow, Yoshua Bengio, Aaron Courville 著の<a href="https://www.amazon.co.jp/Deep-Learning-Adaptive-Computation-Machine/dp/0262035618" rel="nofollow">『DeepLearning』</a>の英語原文を毎回輪読形式で読み進めて行きます。</li>\n<li>ディープラーニングの基礎についてじっくりと理解を深め、英語の原文を読みこなす力を身につけることを目的とします。</li>\n<li>テキストは、書籍を購入するか下記のウェブサイトを閲覧するなりしてご自身でご準備ください。\n\u3000<a href="http://www.deeplearningbook.org" rel="nofollow">http://www.deeplearningbook.org</a></li>\n</ul>\n<h1>対象者</h1>\n<ul>\n<li>ディープラーニングについてより理解を深めたい方</li>\n<li>ディープラーニングに関する英語の原文を読みこなしたい方</li>\n</ul>\n<p>※初心者・上級者、社会人・学生の別は問いません。</p>\n<h1>開催日時・参加費・定員</h1>\n<h2>開催日時（※日程変更の可能性があります）</h2>\n<p>第9回：2019年4月4日（木）19:30〜21:40</p>\n<p>※ 第一・第三木曜日を基本開催日としますが、祝祭日や他の貸切イベント等と重なる場合は変更の可能性があります。</p>\n<h2>参加費</h2>\n<p>900円（SOLのコワーキング利用料です。）</p>\n<h2>定員</h2>\n<p>8名（最低催行人数3名）</p>\n<h1>輪読会の進め方</h1>\n<ul>\n<li>お一人ずつ順番に１パラグラフごと翻訳していきます。</li>\n<li>全体で簡単に質問・意見交換タイムを設け、議論をしながら内容への理解を深めていきます。</li>\n<li>21時30分頃まで進めるところまで進みます。</li>\n<li>最後に次回の案内をして21時40分頃終わりにします。</li>\n</ul>\n<h2>『Deep Learning』の章構成</h2>\n<p>Table of Contents</p>\n<p>Acknowledgements</p>\n<p>Notation</p>\n<p>1 Introduction</p>\n<p>Part I: Applied Math and Machine Learning Basics</p>\n<p>2 Linear Algebra</p>\n<p>3 Probability and Information Theory</p>\n<p>4 Numerical Computation</p>\n<p>5 Machine Learning Basics</p>\n<p>Part II: Modern Practical Deep Networks</p>\n<p>6 Deep Feedforward Networks</p>\n<p>7 Regularization for Deep Learning</p>\n<p>8 Optimization for Training Deep Models</p>\n<p>9 Convolutional Networks</p>\n<p>10 Sequence Modeling: Recurrent and Recursive Nets</p>\n<p>11 Practical Methodology</p>\n<p>12 Applications</p>\n<p>Part III: Deep Learning Research</p>\n<p>13 Linear Factor Models</p>\n<p>14 Autoencoders</p>\n<p>15 Representation Learning</p>\n<p>16 Structured Probabilistic Models for Deep Learning</p>\n<p>17 Monte Carlo Methods</p>\n<p>18 Confronting the Partition Function</p>\n<p>19 Approximate Inference</p>\n<p>20 Deep Generative Models</p>\n<p>Bibliography</p>\n<p>Index</p>\n<h1>その他</h1>\n<p>ソレイユデータ道場については、公式HPやFacebookページをご参照ください。</p>\n<p>公式HP：<a href="http://www.soleildatadojo.com" rel="nofollow">http://www.soleildatadojo.com</a></p>\n<p>Facebookページ：<a href="https://www.facebook.com/soleildatadojo/" rel="nofollow">https://www.facebook.com/soleildatadojo/</a></p>\n<p><strong>一緒に教育コンテンツ制作・講師・ティーチングアシスタントをしてくださる仲間を大募集！</strong></p>\n<p>データ処理・可視化、機械学習・ディープラーニング、応用数学、クラウド、セキュリティ、IoTデバイスなど、ご自身の保有する知識・技術・ノウハウを教えて広く世の中に役立てたい、人に教えることを通じて自らも成長したいという方を大募集しています！</p>\n<p>ご興味がある方は、info@soleildatadojo.comまでお気軽にご連絡ください。</p>',
#    'address': '大阪市北区西天満2丁目5番3号（堂島深川3階）',
#    'catch': '『Deep Learning』を読み解き、基礎的な理解と英語の原文に当たるスタンスを身につける',
#    'accepted': 1,
#    'ended_at': '2019-04-04T21:40:00+09:00',
#    'place': 'Scribble Osaka Lab（SOL）'},
#   {'event_url': 'https://tec.connpass.com/event/123638/',
#    'event_type': 'participation',
#    'owner_nickname': 'RyutaKomori',
#    'series': {'url': 'https://tec.connpass.com/',
#     'id': 2325,
#     'title': 'ENGINEER STYLE TOKYO'},
#    'updated_at': '2019-03-23T00:56:23+09:00',
#    'lat': '35.660227600000',
#    'started_at': '2019-04-06T11:00:00+09:00',
#    'hash_tag': 'Docker',
#    'title': 'マスターしちゃう Docker＆AWS ECSハンズオン',
#    'event_id': 123638,
#    'lon': '139.707380900000',
#    'waiting': 0,
#    'limit': 18,
#    'owner_id': 43496,
#    'owner_display_name': '小森隆太',
# ...
#    'address': '東京都渋谷区千駄ヶ谷4-23-5 JPR千駄ヶ谷ビル2F',
#    'catch': 'RubyKaigi 2019 Official Pre Event',
#    'accepted': 5,
#    'ended_at': '2019-04-12T22:30:00+09:00',
#    'place': 'ピクシブ株式会社'},
#   {'event_url': 'https://fukuokarb.connpass.com/event/124966/',
#    'event_type': 'participation',
#    'owner_nickname': 'udzura',
#    'series': {'url': 'https://fukuokarb.connpass.com/',
#     'id': 2538,
#     'title': 'Fukuoka.rb'},
#    'updated_at': '2019-03-20T18:22:37+09:00',
#    'lat': '33.590149000000',
#    'started_at': '2019-04-12T19:00:00+09:00',
#    'hash_tag': 'rubykaigi',
#    'title': 'RejectKaigi 2019 福岡会場 (a.k.a. Fukuoka.rb #131)',
#    'event_id': 124966,
#    'lon': '130.396154800000',
#    'waiting': 0,
#    'limit': 35,
#    'owner_id': 1153,
#    'owner_display_name': 'うづら',
#    'description': '<p>RejectKaigi 2019 の福岡会場です！ <a href="https://pixiv.connpass.com/event/124727/" rel="nofollow">東京のピクシブオフィス</a> と相互中継して行います！</p>\n<p><strong>福岡参加の方はこちらに登録をお願いいたします！！</strong></p>\n<hr>\n<h2>RejectKaigi 2019とは？</h2>\n<ul>\n<li>RubyKaigi 2019のCFP提出者で、惜しくもAcceptの機会を逃された方（つまりRejectされた人）をメインに、ご登壇者としてRubyに関する発表をしていただくイベントです。</li>\n<li>このイベントは、より多くのRubyistに自身の取り組みや成果を発表できる機会を創出し、Rubyコミュニティの発展および5月開催のRubyKaigi 2019をさらに盛り上げることを目的とした【RubyKaigi 2019公式イベント】です。</li>\n</ul>\n<p>前回のイベントページ：<a href="https://speee.connpass.com/event/84915/" rel="nofollow">https://speee.connpass.com/event/84915/</a></p>\n<h2>スケジュール</h2>\n<p>現在調整中ですが、下記のようなコンテンツを用意しております。</p>\n<ul>\n<li>各20分枠のRubyに関する発表（東京、福岡相互中継！）</li>\n<li>松田明氏＆ RubyKaigi運営チームによるRubyKaigi 2019タイムテーブル徹底解説</li>\n</ul>\n<p>タイムテーブルができ次第更新いたします。 <a href="https://pixiv.connpass.com/event/124727/" rel="nofollow">東京会場の説明もあわせてご参照ください。</a></p>\n<h2>登壇者</h2>\n<p>現在募集中です。登壇希望の方は以下のフォームからお申込みください。Rubyに関する発表内容であれば、RubyKaigi本編のトークに申し込んだ方以外のお申込みいただけます。</p>\n<p><a href="https://goo.gl/forms/V2rJnL47vad4XDSg2" rel="nofollow">https://goo.gl/forms/V2rJnL47vad4XDSg2</a></p>\n<p><strong>福岡登壇希望の方は、必ず登壇希望地に福岡をご指定ください。</strong> また、通過者の方は本募集ページでの登録は不要です。</p>\n<h2>詳細</h2>\n<p>日時：2019年 4月12日(金) 19:30〜 (開場19:00〜)</p>\n<p>開催地：</p>\n<div class="codehilite"><pre><span></span>福岡会場：GMOペパボ株式会社 〒810-0001 福岡県福岡市中央区天神2丁目7番21号 天神プライム 7F\n東京会場：ピクシブ株式会社 〒151-0051 東京都渋谷区千駄ヶ谷4-23-5 JPR千駄ヶ谷ビル 2F\n</pre></div>\n\n\n<p>持ち物：本人確認のため、名刺2枚または何か本人とわかるものをご持参ください。</p>\n<p>備考： 東京会場から参加される場合は以下のconnpassから参加登録をお願いいたします。</p>\n<ul>\n<li><a href="https://pixiv.connpass.com/event/124727/" rel="nofollow">https://pixiv.connpass.com/event/124727/</a></li>\n</ul>\n<p>発表の時間を除く入退場自由です。参加費無料、懇親会あり。</p>\n<p>運営：Fukuoka.rb（会場提供: GMOペパボ株式会社）</p>\n<p>また、GMOペパボ株式会社の提供で、軽食とお酒・飲み物を用意する予定です。</p>\n<h2>その他</h2>\n<p>会場奥の会議室、倉庫など立ち入り禁止区域への立ち入りはご遠慮願います。</p>\n<p>また、知識の共有および、参加者同士の交流を目的としない参加はお断りしています。 参加目的が不適切だと判断される場合には、運営側で参加のキャンセルなどの対応をさせていただく場合がございます。</p>\n<p>「入り口がわからない」「場所がわからない」など、ございましたらペパボ関係者の @udzura に、Twitterまでご連絡ください。</p>',
#    'address': '福岡県福岡市中央区天神２−７−２１ (天神プライム 7F)',
#    'catch': '今年は現地でもRejectできます！',
#    'accepted': 6,
#    'ended_at': '2019-04-12T22:00:00+09:00',
#    'place': 'GMOペパボ 福岡支社 7F ペパステ'},
#   {'event_url': 'https://lounge.connpass.com/event/124432/',
#    'event_type': 'participation',
#    'owner_nickname': 'naru0504',
#    'series': {'url': 'https://lounge.connpass.com/',
#     'id': 7621,
#     'title': 'Creator Lounge'},
#    'updated_at': '2019-03-20T18:07:09+09:00',
#    'lat': '35.657959500000',
#    'started_at': '2019-04-05T19:00:00+09:00',
#    'hash_tag': 'クリエイターラウンジ',
#    'title': 'Creator Lounge vol.1 - お悩み解決ラウンジ',
#    'event_id': 124432,
#    'lon': '139.708928300000',
#    'waiting': 0,
#    'limit': 50,
#    'owner_id': 26187,
#    'owner_display_name': 'naru0504',
#    'description': '<h2>クリエイターラウンジってどんなイベント？</h2>\n<p>クリエイターラウンジは多様なクリエイターを『つなぐ』イベントです。\nクリエイターのチカラを発揮できる場を提供し、インサイトを追求してアップデートしていくことで、クリエイターが『つながり』を手に入れられる場の構築を目指しています。</p>\n<h2>vol.1『お悩み解決ラウンジ』ってなに？</h2>\n<p>初回のお悩み解決ラウンジは、『仮』のお題ではなく、実際の企業が抱えている『本当』にある課題を解決するイベントです。\n6社の企業ごとにブースを用意するので、参加者のみなさまにはその企業ブースごとに課題を聞いて定義して、ソリューションの共創に取り組んでもらいます。</p>\n<h3>参加企業とお悩み</h3>\n<p>今回、実際のお悩みを提供してくれるのは以下の6社です。</p>\n<table>\n<thead>\n<tr>\n<th>企業</th>\n<th>内容</th>\n</tr>\n</thead>\n<tbody>\n<tr>\n<td>株式会社 Atrae</td>\n<td>随時追記予定</td>\n</tr>\n<tr>\n<td>Studio Opt</td>\n<td>随時追記予定</td>\n</tr>\n<tr>\n<td>株式会社 TeslinQ</td>\n<td>随時追記予定</td>\n</tr>\n<tr>\n<td>株式会社 テクロコ</td>\n<td>随時追記予定</td>\n</tr>\n<tr>\n<td>株式会社 mixi</td>\n<td>随時追記予定</td>\n</tr>\n<tr>\n<td>株式会社 LIG</td>\n<td>随時追記予定</td>\n</tr>\n</tbody>\n</table>\n<h2>どんな人に向いているの</h2>\n<ul>\n<li>グラフィックデザイナー</li>\n<li>Webデザイナー</li>\n<li>UIデザイナー</li>\n<li>UXデザイナー</li>\n<li>モーションデザイナー</li>\n<li>3Dデザイナー</li>\n<li>エディトリアルデザイナー</li>\n<li>イラストレーター</li>\n<li>映像クリエイター</li>\n<li>サウンドクリエイター</li>\n<li>フロントエンドエンジニア</li>\n<li>クリエイティブディレクター</li>\n<li>アートディレクター</li>\n<li>コピーライター</li>\n<li>フォトグラファー</li>\n</ul>\n<h2>タイムスケジュール</h2>\n<table>\n<thead>\n<tr>\n<th>時間</th>\n<th>内容</th>\n</tr>\n</thead>\n<tbody>\n<tr>\n<td>19:00 - 19:30</td>\n<td>開場・受付</td>\n</tr>\n<tr>\n<td>19:30 - 19:45</td>\n<td>会場説明＆Kanpai＆企画説明・席替え</td>\n</tr>\n<tr>\n<td>19:45 - 20:05</td>\n<td>Round1</td>\n</tr>\n<tr>\n<td>20:05 - 20:10</td>\n<td>席替え</td>\n</tr>\n<tr>\n<td>20:10 - 20:30</td>\n<td>Round2</td>\n</tr>\n<tr>\n<td>20:30 - 20:40</td>\n<td>休憩・席替え</td>\n</tr>\n<tr>\n<td>20:40 - 21:00</td>\n<td>Round3</td>\n</tr>\n<tr>\n<td>21:00 - 21:25</td>\n<td>各テーブルより発表</td>\n</tr>\n<tr>\n<td>21:25 - 21:30</td>\n<td>アンケート回答</td>\n</tr>\n<tr>\n<td>21:30 - 22:30</td>\n<td>懇親会</td>\n</tr>\n</tbody>\n</table>',
#    'address': '東京都渋谷区東1-2-20 住友不動産渋谷ファーストタワー7F',
#    'catch': '',
#    'accepted': 0,
#    'ended_at': '2019-04-05T22:30:00+09:00',
#    'place': '株式会社ミクシィ'},
#   {'event_url': 'https://connpass.com/event/124986/',
#    'event_type': 'participation',
#    'owner_nickname': 'AsaToshi',
#    'series': None,
#    'updated_at': '2019-03-20T16:45:19+09:00',
#    'lat': None,
#    'started_at': '2019-04-06T14:00:00+09:00',
#    'hash_tag': '',
#    'title': '3D CADを使いこなそう勉強会',
#    'event_id': 124986,
#    'lon': None,
#    'waiting': 0,
#    'limit': None,
#    'owner_id': 302960,
#    'owner_display_name': 'AsaToshi',
#    'description': '<p>建設業界においては、一般的な2D活用スキルは当然で、iCON、CIMなどを始めとして\n3Dデータの活用が浸透してきています。\nしかしながら、まだまだこれを駆使する人材が豊富とは言えず、逆を言うと学ぶと差別化の\nチャンスともいえる状況です。\n一緒に学んで100人1000人に1人と言われる人材を目指しましょう。</p>',
#    'address': None,
#    'catch': '',
#    'accepted': 0,
#    'ended_at': '2019-04-06T16:00:00+09:00',
#    'place': None},
#   {'event_url': 'https://cogbot.connpass.com/event/124711/',
#    'event_type': 'participation',
#    'owner_nickname': 'dz_',
#    'series': {'url': 'https://cogbot.connpass.com/',
#     'id': 2843,
#     'title': 'Cogbot コミュニティ'},
#    'updated_at': '2019-03-20T16:09:31+09:00',
#    'lat': '35.688562400000',
#    'started_at': '2019-04-20T13:00:00+09:00',
#    'hash_tag': 'cogbot #LINE_API',
#    'title': 'Cogbot 勉強会 Special ★ LINE から話せる楽しいチャットボットを作ろう！',
#    'event_id': 124711,
#    'lon': '139.702591600000',
#    'waiting': 0,
#    'limit': 130,
#    'owner_id': 731,
#    'owner_display_name': 'dz_',
#    'description': '<h1>イベント概要</h1>\n<h2>LINE から会話できて、入力にちゃんと反応してくれるチャットボットを作ろう！</h2>\n<p>一方的な反応を返すだけでなく、チャットボットにちょっと複雑なことをさせたい場合、裏側でその仕組みを作りこむ必要があります。今回は、すぐにチャットボットを立ち上げられる Azure Bot Service や、人工知能を Web API で利用できる Cognitive Services を使って、LINE Messaging API で LINE から会話できるチャットボットを皆で開発しましょう！</p>\n<h2>チャットボット開発初めての人も、経験者も！</h2>\n<p><strong>■ チャットボット開発が初めての方</strong></p>\n<p>一緒に <strong>ハンズオン</strong> で基本的なチャットボットの作り方をマスターしちゃいましょう！</p>\n<p><strong> ■ 経験者の方</strong></p>\n<p>「こんなチャットボットがあるといいな」を形にする <strong>ミニハッカソン</strong> にご参加ください。<br>\n※今回は Bot Framework (Azure Bot Service), Cognitive Services を使っていただけると嬉しいです！</p>\n<p>「こんなチャットボットつくるよ★(またはつくったよ☆)」ということが決まっていて発表 OK な方は <strong>LT 枠</strong> でお申込みをお願いいたします。 </p>\n<h2>LINE &amp; Microsoft がバックアップ！</h2>\n<p>LINE &amp; Microsoft の中の人 が解説 ＆ ハンズオンとミニハッカソンをサポートします！(メンバー調整中)</p>\n<h1>開催概要</h1>\n<h2>場所、時間</h2>\n<table>\n<thead>\n<tr>\n<th align="left">項目</th>\n<th align="left">内容</th>\n</tr>\n</thead>\n<tbody>\n<tr>\n<td align="left">開催日</td>\n<td align="left">4/20 (土)</td>\n</tr>\n<tr>\n<td align="left">時間</td>\n<td align="left">12:30開場、13:00開始</td>\n</tr>\n<tr>\n<td align="left">会場</td>\n<td align="left">LINE株式会社</td>\n</tr>\n</tbody>\n</table>\n<h2>タイムテーブル</h2>\n<table>\n<thead>\n<tr>\n<th align="left">時間</th>\n<th align="left">内容</th>\n<th align="left"></th>\n</tr>\n</thead>\n<tbody>\n<tr>\n<td align="left">12:30 - 13:00</td>\n<td align="left">受付</td>\n<td align="left"></td>\n</tr>\n<tr>\n<td align="left">13:00</td>\n<td align="left">今日のハンズオン &amp; ミニハッカソン で使うテクノロジー説明</td>\n<td align="left">LINE Messaging API &amp; Azure Bot Service などなど (LINEさま＆Microsoftさま)</td>\n</tr>\n<tr>\n<td align="left">14:00</td>\n<td align="left">ハンズオン or ミニハッカソン</td>\n<td align="left">ハンズオン：チャットボット開発初心者向け<br>ミニハッカソン：開発経験者向け<br>※どちらかご自由にご参加ください</td>\n</tr>\n<tr>\n<td align="left">16:00</td>\n<td align="left">LT 大会</td>\n<td align="left">※人数把握のため、発表予定の方は <strong>LT枠</strong> でご参加いただけると嬉しいです。(当日 LT 参戦あり(予定))</td>\n</tr>\n<tr>\n<td align="left">17:00</td>\n<td align="left">終了</td>\n<td align="left"></td>\n</tr>\n</tbody>\n</table>\n<h2>内容</h2>\n<p>実際に自分でチャットボット開発を行いますので、LINE から話せるチャットボットをつくりたい開発者 (Developer, Software Engineer, etc) の方、ご参加お待ちしております。<br>\nいずれの場合でも大丈夫です★</p>\n<ul>\n<li>チャットボット開発初めての方</li>\n<li>チャットボット開発のご経験のある方</li>\n<li>Azure を使ったことのない方</li>\n<li>Azure を使ったことのある方</li>\n</ul>\n<h3>今日のハンズオン &amp; ミニハッカソン で使うテクノロジー説明</h3>\n<p>(予定内容)</p>\n<ul>\n<li>LINE Messaging API とは？使い方などなど (LINE さま)</li>\n<li>Azure Bot Service &amp; Cognitive Services 使い方などなど (Microsoft さま)</li>\n</ul>\n<h3>ハンズオン or ミニハッカソン</h3>\n<p><strong>■ チャットボット開発が初めての方</strong></p>\n<p>一緒に <strong>ハンズオン</strong> で基本的なチャットボットの作り方をマスターしちゃいましょう！\nハンズオンテキスト(予定)</p>\n<ul>\n<li><a href="https://qiita.com/annie/items/1926fc16731fcaad0666" rel="nofollow">翻訳チャットボットを作ろう！</a></li>\n<li><a href="https://qiita.com/annie/items/7b63e366deeaeae63f94" rel="nofollow">一問一答(FAQ)チャットボットを作ろう！</a></li>\n</ul>\n<p><strong> ■ 経験者の方</strong></p>\n<p>「こんなチャットボットがあるといいな」を形にする <strong>ミニハッカソン</strong> にご参加ください。ひとりでモクモクするもよし、仲間を募るもよし、できたら LT で皆さんにシェアしてください (任意ですが是非～)！ <br>\n「こんなチャットボットつくるよ★(またはつくったよ☆)」ということが決まっていて発表 OK な方は <strong>LT 枠</strong> でお申込みをお願いいたします。 <br>\n※今回は Bot Framework (Azure Bot Service), Cognitive Services を使っていただけると嬉しいです！</p>\n<h2>持ち物</h2>\n<p><strong>PC</strong><br>\n会場の WIFI に接続できるご自身のPC(Win/Mac)をお持ち込みください。\nブラウザーから操作しますので、あまり小さい画面の機種やタブレットは操作が厳しい可能性があります。また、文字入力なども行いますので、キーボードがある方が望ましいです。</p>\n<p><strong>Azure サブスクリプション</strong><br>\n作成したチャットボット環境をお持ち帰りいただくため、Azureサブスクリプション (無償版でも構いません) をお申込みいただき、ご準備をお願いいたします。<br>\nAzure サブスクリプションは マイクロソフトアカウント (または組織・学校アカウント) に紐づけされます。<br>\n<a href="https://azure.microsoft.com/ja-jp/free/" rel="nofollow">Azure サブスクリプション無料版申し込み</a></p>\n<p><strong>LINE アカウント</strong><br>\n<a href="https://developers.line.biz/ja/" rel="nofollow">LINE Developer ページ</a> にアクセスして Message API を作成、設定を行います。\nメールアドレスへの紐づけ、ログインに必要なスマートフォンなどもご準備ください。</p>\n<p>※上記の内容は予告なく変更する場合があります。あらかじめご了承ください。</p>',
#    'address': '東京都新宿区新宿四丁目1番6号 (JR新宿ミライナタワー)',
#    'catch': '祝！Azure Bot Service LINE 対応記念だよ Special Day!',
#    'accepted': 46,
#    'ended_at': '2019-04-20T17:00:00+09:00',
#    'place': 'LINE株式会社'},
#   {'event_url': 'https://to-kei.connpass.com/event/124982/',
#    'event_type': 'participation',
#    'owner_nickname': 'avilen',
#    'series': {'url': 'https://to-kei.connpass.com/',
#     'id': 5302,
#     'title': '全人類がわかる統計学'},
#    'updated_at': '2019-03-20T15:52:23+09:00',
#    'lat': '35.701205200000',
#    'started_at': '2019-04-02T19:45:00+09:00',
#    'hash_tag': '',
#    'title': 'R言語データ分析入門',
#    'event_id': 124982,
#    'lon': '139.776340500000',
#    'waiting': 0,
#    'limit': 3,
#    'owner_id': 256794,
#    'owner_display_name': 'avilen',
#    'description': '<h1>R言語データ分析入門<br></h1>\n<h2>概要</h2>\n<p>2時間の間にR言語の基本動作の習得、簡単なデータ分析をハンズオン形式で行います。</p>\n<p>R言語は簡潔な記述で、データ分析が出来るプログラミング言語です。しかし、プログラミングの初心者にとっては、必ずしも簡単に入門できるというわけでも有りません。そこでプログラミングの初心者に、線形回帰分析が出来るというレベルまでの入門講座を提供いたします。全くの初心者も安心してご参加ください。</p>\n<p>また、データ分析のためのR言語文法講座も合わせて受講していただけると、当講座で学んだデータ分析法をR言語の文法を用いて効率よく実装する手順を習得することが出来ます。どちらを先に受けていただいても良いカリキュラムにしていますので、都合のつく方からご受講ください。さらに深く学びたい方は、<a href="https://techplay.jp/event/713832" rel="nofollow">「R言語で代表的な統計的手法を色々実装するセミナー」</a>の受講もおすすめ致します。</p>\n<p>※当日は実戦形式で進めていきますので、R言語を<a href="https://to-kei.net/r-beginner/#R-2" rel="nofollow">インストール</a>したPCの持参をお願いいたします。</p>\n<h2>講座を通じて得られること</h2>\n<p>・データ分析の一連の流れを体験<br>\n・R言語の基本的な文法の習得<br>\n・簡単な機械学習（線形回帰分析）の実装体験<br></p>\n<h2>内容</h2>\n<p>・Rでのプログラムの実行の仕方。<br>\n・Rにおける変数の扱い方<br>\n・ベクトル、行列、データフレームの基本操作。<br>\n・データの読み込み<br>\n・データの整形。<br>\n・線形回帰分析の理論の紹介<br>\n・R言語を用いた回帰分析の実装<br>\n・分析結果の見方や取り出し方<br>\n・分析結果をcsvファイルへ保存する方法<br>\n・演習問題、質問対応<br></p>\n<p>※ 当日予告なく時間配分・内容が変更になる可能性がございます。</p>\n<h2>こんな人にオススメ</h2>\n<p>・R言語を最短ルートで入門したい方<br>\n・R入門を考えているが自分で出来るか不安な方。<br>\n・プログラミングは初心者だけど、データ分析したい方<br>\n・統計や機械学習を勉強したことが有って、実装を体験してみたい方。<br>\n・これから統計や機械学習を学びたいと考えている方<br></p>\n<h2>講師</h2>\n<div class="codehilite"><pre><span></span>黒木 裕鷹\n金融における資産価格モデルや、マーケティングにおけるPOSデータ解析、生産ラインの異常検知など、様々なプロジェクトに携わる。R言語コミュティTOKYO.Rなどの勉強会でも積極的に登壇。統計関連学会連合大会などでの受賞経験あり、大学院にてデータサイエンスの応用研究に従事。\n</pre></div>\n\n\n<h2>持ち物</h2>\n<p>・R言語の実行環境をインストール済みのPC(windows Mac)</p>\n<p>インストールの方法は下記リンクを参照↓ <br>\n・<a href="https://to-kei.net/r-beginner/r-install-mac/" rel="nofollow">Mac</a><br>\n・<a href="https://to-kei.net/r-beginner/r-install-windows/" rel="nofollow">Windows</a></p>\n<p>※インストールでお困りの方はinfo@to-kei.netまでご連絡いただければ、可能な範囲で対応致します。</p>\n<h2>領収書について</h2>\n<p><strong>【Stripeで事前決済の方】</strong><br>\nクレジットカード会社が発行する明細を領収書の代わりとしてご利用ください。当社より重複しての領収書発行は行なっておりません。</p>\n<p><strong>【Paypalの方】</strong><br>\n決済処理後にPaypalから送付されるメール内容、またはPaypalの取引履歴から該当項目を確認の上、「詳細」をご覧ください。それらが領収書の代わりとなります。また、クレジットカード会社発行の利用明細書も領収書としてご利用いただけます。（当社より重複しての発行は行えません)</p>\n<h2>受付・入場時間</h2>\n<p>開始の15分前から</p>\n<h2>お問い合わせ</h2>\n<p>・メールでのお問い合わせは、info@to-kei.net\u3000までご連絡ください。<br>\n・こちらで⇨<a href="https://line.me/R/ti/p/%40ldy9583d" rel="nofollow">LINE＠</a>からもお問い合わせいただけます。（推奨）</p>\n<h2>お申し込みにあたっての注意事項</h2>\n<p>・当講座は『実戦形式で学ぶ初心者向けR言語入門』の講座名を変更したものであり、以前受講された方は内容がほぼ同じであるため、2回目の参加枠からお申し込みください。<br>\n・講義コンテンツは全て「全人類がわかる統計学」に帰属していますので、複・リクルーティング、勧誘、採用活動など、目的に沿わない行為につきまして、主催者が相応しくないと判断した場合は即刻退出処分とします。全員が気持ちよく過ごすことが出来るよう、ご協力をお願い致します。<br>\n・講座内で扱うコンテンツは全て「全人類がわかる統計学」に帰属しています。複製はご遠慮ください。<br>\n・個人ブログへの講義コンテンツの掲載はご遠慮ください。<br>\n・最小遂行人数は「3名」です。開催日の前日までにこの人数に達しない場合は中止となります。ただし、複数の媒体で募集を行っているので、本サイトの申込者数が最小遂行人数に達しない場合でも開催になる場合がございます。もし、中止が決定した場合はその時点で登録しているメールアドレスにご連絡させていただきます。<br></p>\n<h2>全人類がわかる統計学とは</h2>\n<p>統計学の学習サイト、<a href="https://to-kei.net" rel="nofollow">全人類がわかる統計学</a>を運営、管理している団体です。統計学とその関連分野について、出来るだけわかりやすく多くの人々に届けるということを目指して活動しています。</p>',
#    'address': '台東区台東１丁目11番4号 誠心Oビル3F',
#    'catch': '',
#    'accepted': 0,
#    'ended_at': '2019-04-02T22:00:00+09:00',
#    'place': '秋葉原駅徒歩5分'}],
#  'results_start': 1,
#  'results_available': 686}

# %% [markdown]
# 一度に 100 件縛りがあるので、そこだけが問題だろうか？
# とりあえず 100 件でリクエストしてみて、100 件未満になるまでループしてリクエストしてみる。
#
# ### 実際に勉強会データ（名前と参加者数）を拾ってみた
#
# 尚、やってみてわかったのだけど、ソート順がデフォルト以外だと、タイムアウトでコケるようだ。
# 多分インデックスが不足してるか何かしてるんだろうなーと思いつつ。
# （いや、それ以外はそこそこ高速で返ってくる事を考えれば、RDB じゃなくて Mongo とか Cassandra とか使ってそう）

# %%
class ClassRoom:
    def __init__(self, title, limit, accepted, waiting):
        def or_zero(v):
            if isinstance(v, int):
                return v
            return 0
        self.title = title
        self.limit = or_zero(limit)
        self.joins = or_zero(accepted) + or_zero(waiting)
        self.score = self.joins / self.limit if self.limit != 0 else 1
        
    def __str__(self):
        return f'ClassRoom({self.title}, {self.limit}, {self.joins}, {self.score})'

def convert(event):
    return ClassRoom(event['title'], event['limit'], event['accepted'], event['waiting'])


def request_to_compass(start):
    params = {"ym":"201904", "count":WANT_EVENT, "order":1,"start":start}
    query = '&'.join([f'{key}={params[key]}' for key in params.keys()])
    return requests.get(compass_rest_api + '?' + query)


WANT_EVENT = 100
getted = WANT_EVENT
current_start = 1
class_rooms = []

while getted == WANT_EVENT:
    r_get = request_to_compass(current_start)
    respond_json = r_get.json()

    getted = respond_json['results_returned']
    current_start += WANT_EVENT
    print(f'{getted}, {current_start}')

    for ev in respond_json['events']:
        class_rooms.append(convert(ev))

# least 100
r_get = r_get = request_to_compass(current_start)
respond_json = r_get.json()
for ev in respond_json['events']:
    class_rooms.append(convert(ev))
# Out:
# 100, 101
# 100, 201
# 100, 301
# 100, 401
# 100, 501
# 100, 601
# 86, 701

# %%
[str(s) for s in class_rooms]
# Out:
# ['ClassRoom(初心者向けのディープラーニング講座【サポーターズCoLab勉強会】, 20, 0, 0.0)',
#  'ClassRoom(赤坂 Masonite Python 勉強会, 15, 0, 0.0)',
#  'ClassRoom(Docker+Python+Django\u3000WEB開発ハンズオン, 12, 16, 1.3333333333333333)',
#  'ClassRoom([再演] 外国人との英語での働き方講座 (講師：ロッシェルさん, ちょまど, 他), 220, 0, 0.0)',
#  'ClassRoom(技術同人誌を書こう【サポーターズCoLab勉強会】, 20, 0, 0.0)',
#  'ClassRoom(技術同人誌を書こう【サポーターズCoLab勉強会】, 20, 0, 0.0)',
#  'ClassRoom(Unagi.py 勉強会16枚目～Pythonでアルゴリズムの基本、他～, 20, 5, 0.25)',
#  'ClassRoom(#ProLabo(プロラボ)渋谷もくもく会（#駆け出しエンジニア or 初心者歓迎web系)#4, 100, 59, 0.59)',
#  'ClassRoom(定例モクモク勉強会, 5, 0, 0.0)',
#  'ClassRoom(超入門・サーバー構築勉強会 #037 in 横浜, 8, 0, 0.0)',
#  'ClassRoom(try! Swift報告会 + Swift 5勉強会【iPhone Dev Sapporo番外編】, 20, 3, 0.15)',
#  'ClassRoom(MINI Hardening Project #3.2@メルカリ, 20, 0, 0.0)',
#  'ClassRoom(DjangoCongress JP 2019 4月作業日, 10, 2, 0.2)',
#  'ClassRoom(Webデザイン・Web制作に関する勉強会 #5, 20, 11, 0.55)',
#  'ClassRoom(DevRel/Beginners #4, 14, 9, 0.6428571428571429)',
#  'ClassRoom(Ansibleもくもく会 （サーバ編）2019.04 in 甲府！, 32, 1, 0.03125)',
#  'ClassRoom(PWA Night vol.3 ～PWAのミライや活用方法をみんなで考えよう～, 50, 0, 0.0)',
#  'ClassRoom(表参道.rb #45, 40, 10, 0.25)',
#  'ClassRoom(Global Azure Bootcamp 2019@Tokyo, 140, 82, 0.5857142857142857)',
#  'ClassRoom(第14回 CoderDojo Nada(灘)(深江会場)【メンター募集】, 12, 0, 0.0)',
#  'ClassRoom(第14回 CoderDojo Nada(灘)（深江会場）【忍者募集】, 16, 0, 0.0)',
#  'ClassRoom(PyLadies Tokyo Meetup #40 Python入学式, 67, 17, 0.2537313432835821)',
#  'ClassRoom(かごもく #19 シングルサインオン!, 10, 2, 0.2)',
#  'ClassRoom(『Vue.js/PWA/JavaScript…新&定番なんでもあり』表参道Web勉強会 Vol.2, 50, 43, 0.86)',
#  'ClassRoom(Inside IT #2, 40, 6, 0.15)',
#  'ClassRoom(【4/4（木）】『Deep Learning』輪読会#11, 8, 1, 0.125)',
#  'ClassRoom(マスターしちゃう Docker＆AWS ECSハンズオン, 18, 2, 0.1111111111111111)',
#  'ClassRoom(知りたいを解決！ゼロから始めるAI講座, 18, 2, 0.1111111111111111)',
#  'ClassRoom(akiba.ex#01：Elixirもくもく会, 11, 11, 1.0)',
#  'ClassRoom(お花見！オープンデータソン in 京都, 29, 29, 1.0)',
#  'ClassRoom(Pythonによるスクレイピング入門, 3, 3, 1.0)',
#  'ClassRoom(微分幾何勉強会 ∇_6, 26, 18, 0.6923076923076923)',
#  'ClassRoom(Pythonで学ぶ時系列データ解析入門, 3, 0, 0.0)',
#  'ClassRoom(Python機械学習入門, 3, 0, 0.0)',
#  'ClassRoom(PyData.Tokyo Meetup #19 SysML, 208, 0, 0.0)',
#  'ClassRoom(【参加無料】雑談CAFE 第10弾 #41 【少人数制】, 6, 1, 0.16666666666666666)',
#  'ClassRoom(熊本アジャイル勉強会 #4, 20, 1, 0.05)',
#  'ClassRoom(Zeroichiハッカソン Lev.1 ~(初心者向け)~, 25, 0, 0.0)',
#  'ClassRoom(群馬高専 IT勉強会#2, 49, 3, 0.061224489795918366)',
#  'ClassRoom(アクセシビリティキャンプ東京 2019 － GAAD発起人と振り返る 「CSUN 2019」, 50, 16, 0.32)',
#  'ClassRoom(「陽春 桜川 演奏会」, 20, 0, 0.0)',
#  'ClassRoom(【Little Engineer Hobby】もくもく会（4月その1）, 4, 1, 0.25)',
#  'ClassRoom(Japan OSS Promotion Forum 2019, 150, 51, 0.34)',
#  'ClassRoom(Firebaseハンズオン- Webクラウドアルバム編 -【MarkingCloud】, 20, 9, 0.45)',
#  'ClassRoom(職場のダイバーシティーとアクセシビリティー技術トレンド, 60, 23, 0.38333333333333336)',
#  'ClassRoom(Apache Kafka Meetup Japan #6 @Yahoo! JAPAN, 91, 153, 1.6813186813186813)',
#  'ClassRoom(量子コンピュータハッカソン by Team AI 4/14(日), 17, 6, 0.35294117647058826)',
#  'ClassRoom(データ前処理研究会 by Team AI 4/12(金), 15, 13, 0.8666666666666667)',
#  'ClassRoom(機械学習論文輪読\xad\xad会(NIPS他) by Team AI 4/10(水), 17, 4, 0.23529411764705882)',
#  'ClassRoom(延期・4月29日【ブロックチェーンエンジニアが教える】PyTorch・kaggle勉強会, 15, 0, 0.0)',
#  'ClassRoom(プログラミング勉強部屋\u30004月9日（ほぼ毎週開催）, 15, 0, 0.0)',
#  'ClassRoom(女性限定♡デザイナーのもくもく会 in いずきゃん渋谷！, 15, 6, 0.4)',
#  'ClassRoom(プログラミング勉強部屋\u30004月2日（ほぼ毎週開催）, 15, 0, 0.0)',
#  'ClassRoom(Dappsに興味がある人向け「Blockstackを触ってみよう！」, 20, 7, 0.35)',
#  'ClassRoom(あなたの知らないキーボードの世界【サポーターズ勉強会】, 20, 0, 0.0)',
#  'ClassRoom(スペシャリストとして組織をつくる、というキャリア【サポーターズCoLab勉強会】, 20, 0, 0.0)',
#  'ClassRoom(アプリを最速で構築するための強い味方、Amplifyに入門してみませんか？【サポーターズ勉強会】, 20, 0, 0.0)',
#  'ClassRoom(いまさら聞けないネットワーク基礎！【サポーターズCoLab勉強会】, 60, 0, 0.0)',
#  'ClassRoom(AWS サーバーレスアーキテクチャでつくるSlack ChatOps【サポーターズCoLab勉強会】, 20, 0, 0.0)',
#  'ClassRoom(【交流会/女性限定】エンジニア "女子会" ミートアップ #2【meetup】, 44, 0, 0.0)',
#  'ClassRoom(【4/16（火）】Firebase 勉強会 in 大阪 × 沖縄, 15, 5, 0.3333333333333333)',
#  'ClassRoom(【4/9(火)in品川】Unityを使ったテクスチャチューニングと海外展開の開発事例を紹介, 30, 4, 0.13333333333333333)',
#  'ClassRoom(【参加無料】gumi TECH Drinkup #6 - Elixir -, 16, 6, 0.375)',
#  'ClassRoom(xR Tech Tokyo #15 @ メルカリ, 170, 47, 0.27647058823529413)',
#  'ClassRoom(ビール片手にLT大会 vol.2 (at 大名WeWork), 25, 0, 0.0)',
#  'ClassRoom(Singularity Workshop, 25, 12, 0.48)',
#  'ClassRoom(大岡山で もくもく #9, 7, 0, 0.0)',
#  'ClassRoom(第12回CoderDojo瑞穂, 8, 1, 0.125)',
#  'ClassRoom(【Hedge #3】失敗LT祭！ 〜俺の話を聞いてくれ〜, 48, 14, 0.2916666666666667)',
#  'ClassRoom(C++ MIX #3, 50, 48, 0.96)',
#  'ClassRoom(IBM TEC-J Presents 「知性を問う」勉強会第二弾, 55, 49, 0.8909090909090909)',
#  'ClassRoom(九州インフラ交流勉強会(Kixs) Vol.009, 27, 30, 1.1111111111111112)',
#  'ClassRoom(AteamDesignMeetUp_Vol.05 組織におけるデザイナの働き方/コミュニケーション, 33, 2, 0.06060606060606061)',
#  'ClassRoom(AR Fukuoka：8thWallWebで始めるWebAR ~好評につき再々開催！~, 8, 3, 0.375)',
#  'ClassRoom(【なごスタ】第40回効果が上がるWebサイトのコツを一挙公開！！, 20, 0, 0.0)',
#  'ClassRoom(第1回CoderDojo瑞穂マイクラカップ2019, 12, 6, 0.5)',
#  'ClassRoom(CentOS7を堅牢化しよう！（したい）, 15, 15, 1.0)',
#  'ClassRoom(第11回CoderDojo瑞穂, 11, 3, 0.2727272727272727)',
#  'ClassRoom(フロントエンドBBQ - 2019 春のJIN, 20, 13, 0.65)',
#  'ClassRoom(【6名限定】Vue.js & Nuxt.jsで脱jQueryを目指す1ヶ月少人数講習, 7, 5, 0.7142857142857143)',
#  'ClassRoom(Scrapbox SQUARE TOKYO #2 ～開発現場の活用会議～, 68, 32, 0.47058823529411764)',
#  'ClassRoom(【神戸】GCPUG KOBE #5 【GCP】～はじめてのGCP～, 43, 7, 0.16279069767441862)',
#  'ClassRoom(BlockChain on the Cloud, 0, 2, 1)',
#  'ClassRoom(『ベイズ統計モデリング―R,JAGS,Stanによるチュートリアル―』読書会 #16, 8, 4, 0.5)',
#  'ClassRoom(分析基盤トーク DAFT #2, 53, 0, 0.0)',
#  'ClassRoom(【発表枠〆】Mix Leap LT #16 - LT会\u3000初心者の館「フリーテーマ」, 56, 29, 0.5178571428571429)',
#  'ClassRoom(4/12開催 SORACOM UG 宮城 初心者向けSORACOMワークショップ (もくもく会), 20, 5, 0.25)',
#  'ClassRoom(【未経験者歓迎】【初心者向け】Kaggleの事例を学ぼう！（モデルを作る前の予習） #2, 18, 15, 0.8333333333333334)',
#  'ClassRoom(ZOZO RESEARCH Meetup in KITAKYUSHU \x10#4, 35, 23, 0.6571428571428571)',
#  'ClassRoom(比較でわかる！OracleCloud 〜AWSと比べてみよう〜, 50, 27, 0.54)',
#  'ClassRoom(JANOG43.5 Interim Meeting, 136, 3, 0.022058823529411766)',
#  'ClassRoom(フリーランス交流の場！お酒を飲みながらゆるーく情報交換しましょう, 20, 4, 0.2)',
#  'ClassRoom(No-Code JP 第0回, 174, 112, 0.6436781609195402)',
#  'ClassRoom(JBUG (広島#2 mini開催) Backlogを使うと何がいいの？初級編, 11, 0, 0.0)',
#  'ClassRoom(【python高速化】Faster Python Meet up LT会#1, 14, 16, 1.1428571428571428)',
#  'ClassRoom(インフラエンジニアの為の運用自動化入門, 9, 3, 0.3333333333333333)',
#  'ClassRoom(構成管理自動化の為のKc Sonar入門セミナー, 9, 0, 0.0)',
#  'ClassRoom(「音声の未来を語る〜メディア論編〜」松浦シゲキさん、久保田大海さん×Voicy緒方, 30, 0, 0.0)',
#  'ClassRoom(「ラズパイとNode-REDでロボット(TJBot zero)を体験しよう！ 」, 20, 4, 0.2)',
#  'ClassRoom(【技術書典6】サークル主LT, 69, 26, 0.37681159420289856)',
#  'ClassRoom(初心者歓迎！SPA開発現場あるある〜ぶっちゃけトーク〜, 34, 23, 0.6764705882352942)',
#  'ClassRoom(第125回オープンソースサロン, 0, 0, 1)',
#  'ClassRoom(Glodiaもくもく会 #9, 0, 0, 1)',
#  'ClassRoom(『失敗から学ぶ RDBの正しい歩き方』発刊記念！そーだいさんから直接学ぶ会, 70, 0, 0.0)',
#  'ClassRoom(セキュリティマイスター道場(SecDojo) ~春場所~, 50, 27, 0.54)',
#  'ClassRoom(音 x 機械学習はどこまで実現できているか？ - 最新理論とユースケース -, 25, 0, 0.0)',
#  'ClassRoom(WEBエンジニア MeetUp＠札幌 #3, 15, 2, 0.13333333333333333)',
#  'ClassRoom(【初心者向け】RPA勉強会＆相談会, 4, 2, 0.5)',
#  'ClassRoom(銀座Rails#8 @リンクアンドモチベーション, 132, 0, 0.0)',
#  'ClassRoom(国際規格SQuaREに基づくソフトウェア品質の測定評価と認証セミナー (2019年4月19日), 200, 201, 1.005)',
#  'ClassRoom(【東京開催】AI活用ユーザー事例の紹介, 3, 1, 0.3333333333333333)',
#  'ClassRoom(【メンター募集】第15回 CoderDojoみのお 2019/4/14(日), 5, 0, 0.0)',
#  'ClassRoom(第15回 CoderDojoみのお（箕面）2019/4/14(日), 9, 0, 0.0)',
#  'ClassRoom(CommunitySummitTokyo #3, 40, 75, 1.875)',
#  'ClassRoom(IoT寺子屋：深層学習の数学勉強会(1)_演習分厚版_0428, 9, 0, 0.0)',
#  'ClassRoom(Visual Studio 2019 Launch Event in Fukuoka, 38, 38, 1.0)',
#  'ClassRoom(新潟 Web アプリ 勉強会(FE/BE) Vol. 1.1, 12, 0, 0.0)',
#  'ClassRoom(量子コンピューティング勉強会（実践編） #1, 12, 5, 0.4166666666666667)',
#  'ClassRoom(BMXUGハンズオン「LINEでお絵描きメッセージを送ってみよう♪」, 10, 6, 0.6)',
#  'ClassRoom(IBM Cloud Community Summit 2019.04, 220, 14, 0.06363636363636363)',
#  'ClassRoom(PyData.Fukui  AI機械学習コラボでコラボ, 4, 4, 1.0)',
#  'ClassRoom(第３回【ファミリーテックIoTLT】家庭で実践！IoT縛りの勉強会＠ヴァル研究所, 42, 24, 0.5714285714285714)',
#  'ClassRoom(第四陣 信玄パイ「機械学習を業務で利用するのに必要なこと」, 10, 5, 0.5)',
#  'ClassRoom(Blockchain GIG #2, 90, 90, 1.0)',
#  'ClassRoom((2019/4/20PM)第71回オープンCAE勉強会@関西, 0, 1, 1)',
#  'ClassRoom(次世代 Tokyo DG を考える会, 15, 7, 0.4666666666666667)',
#  'ClassRoom(データサイエンス勉強会 第5回, 0, 8, 1)',
#  'ClassRoom(第35回 Machine Learning 15minutes!, 50, 0, 0.0)',
#  'ClassRoom(Data Analyst Meetup Tokyo vol.9, 80, 35, 0.4375)',
#  'ClassRoom(ChatBot Community Meetup #01, 30, 19, 0.6333333333333333)',
#  'ClassRoom(Pythonデータ分析入門, 3, 1, 0.3333333333333333)',
#  'ClassRoom(【tensorflowで学ぶ】ディープラーニング実装入門, 3, 0, 0.0)',
#  'ClassRoom(【初心者歓迎】Python入門講座, 3, 1, 0.3333333333333333)',
#  'ClassRoom(PythonによるRNN・LSTM入門, 3, 1, 0.3333333333333333)',
#  'ClassRoom(1000 speakers conference in English 71st, Apr 23, 40, 7, 0.175)',
#  'ClassRoom(Pythonもくもく自習室 #19 @ Rettyオフィス, 19, 1, 0.05263157894736842)',
#  'ClassRoom(Data Gateway Talk vol.1, 42, 0, 0.0)',
#  'ClassRoom(ALGYAN4周年\u3000IoT祭り2019『IoTとAIとセキュリティ』大講演会＆豪華ノベルティ抽選会！, 0, 259, 1)',
#  'ClassRoom(#ProLabo(プロラボ)渋谷もくもく会（ノンコーディングで簡単にAlexaスキル作成ハンズオン）, 10, 0, 0.0)',
#  "ClassRoom(Voicy's もくもく会 〜ノンコーディングで簡単にAlexaスキルを作ろうハンズオン〜, 10, 0, 0.0)",
#  'ClassRoom([もくもく会共催] ノンコーディングで簡単にAlexaスキルを作ろうハンズオン(Voiceflow), 10, 0, 0.0)',
#  'ClassRoom(Agileware Drinkup at RubyKaigi 2019, 100, 27, 0.27)',
#  'ClassRoom(VAE; Auto-Encoding Variational Bayes｜ 論文輪読会 #21, 18, 8, 0.4444444444444444)',
#  'ClassRoom(PythonでWebアプリを作ろう@会津若松 [女性対象/男女コーチ] 2019.04, 15, 11, 0.7333333333333333)',
#  'ClassRoom(【東京体験版】他では絶対教えてくれない！常識に惑わされない！ユーザー視点のUIデザイン, 12, 0, 0.0)',
#  'ClassRoom(【AI】第1回 初学者向け ビジネスへのAI活用勉強会 in 名古屋, 20, 0, 0.0)',
#  'ClassRoom(平成最後のはんなりPython #16  ディスカッション会, 15, 10, 0.6666666666666666)',
#  'ClassRoom(【AI】第1回 初学者向け ビジネスへのAI活用勉強会 in 名古屋, 20, 0, 0.0)',
#  'ClassRoom(【東京4月開催】04：直感的で快適なWEB環境を作る｢スマホ用UIデザイン｣, 11, 1, 0.09090909090909091)',
#  'ClassRoom(【東京4月開催】03：ユーザーの視点に寄り添う「わかりやすいUIデザインのツボ」, 7, 1, 0.14285714285714285)',
#  'ClassRoom(【AI】第8回 初学者向け ビジネスへのAI活用勉強会 in 名古屋, 20, 0, 0.0)',
#  'ClassRoom(第29回北海道情報セキュリティ勉強会, 33, 22, 0.6666666666666666)',
#  'ClassRoom(【AI】第3回 【統計・情報科学専攻】学生向け ビジネスへのAI適用勉強会 in 名古屋, 20, 0, 0.0)',
#  'ClassRoom(【AI】第1回  【統計・情報科学専攻】学生向け ビジネスへのAI適用勉強会 in 名古屋, 10, 0, 0.0)',
#  'ClassRoom(PyData.Fukui \u3000PythonでAIましょう, 9, 5, 0.5555555555555556)',
#  'ClassRoom(韓国におけるマーケティング戦略を語る 〜エウレカ×LIFE PEPPER〜, 35, 5, 0.14285714285714285)',
#  'ClassRoom(【無料ワークショップ@大阪】機械学習を成功させるためのデータ前処理と特徴量エンジニアリング（再演）, 66, 10, 0.15151515151515152)',
#  'ClassRoom(【4/6】Generative Art With JavaScript【ハンズオン/初心者歓迎】, 26, 22, 0.8461538461538461)',
#  'ClassRoom(Global AI Nights Fukui, 30, 27, 0.9)',
#  'ClassRoom(デザインわくわく会 #1, 10, 2, 0.2)',
#  'ClassRoom(「コンテキストの理解と実践」UXワークショップ：【第50回】, 30, 20, 0.6666666666666666)',
#  'ClassRoom(ティール組織 - 新しい働き方のスタイル - 読書会 第6回, 10, 3, 0.3)',
#  'ClassRoom(第16回 #hiro_it（4/14開催）, 0, 1, 1)',
#  'ClassRoom(Python for Finance読書会#7~ 第7章前半(旧fin-py読書会), 0, 5, 1)',
#  'ClassRoom(【4/24】水曜ワトソンカフェvol.19「3年間、ガチな現場のチャットボットとAssistant」, 50, 20, 0.4)',
#  'ClassRoom(認定スクラムマスター資格の更新をモブワークでやろうの会, 12, 10, 0.8333333333333334)',
#  'ClassRoom(新しい量子化学―電子構造の理論入門〈上〉輪講その12, 0, 4, 1)',
#  'ClassRoom(RejectKaigi2019 東京会場, 105, 8, 0.0761904761904762)',
#  'ClassRoom(【AI】第6回 初学者向け ビジネスへのAI活用勉強会 in 名古屋, 20, 2, 0.1)',
#  'ClassRoom(【AI】第5回 初学者向け ビジネスへのAI活用勉強会 in 名古屋, 20, 2, 0.1)',
#  'ClassRoom(熊ゆに Unityもくもく会\u30002019/4/6（土）, 10, 2, 0.2)',
#  'ClassRoom(RubyKaigi 2019 After Hack by Fukuoka.rb!! (#132), 51, 27, 0.5294117647058824)',
#  'ClassRoom(あるあるLT〜サーバーサイドエンジニア〜 Vol.2, 30, 25, 0.8333333333333334)',
#  'ClassRoom(RejectKaigi 2019 福岡会場 (a.k.a. Fukuoka.rb #131), 35, 6, 0.17142857142857143)',
#  'ClassRoom(MIDIとMQTTを使ってリモート演奏する仕組みを作ってみよう, 8, 15, 1.875)',
#  'ClassRoom(Creator Lounge vol.1 - お悩み解決ラウンジ, 50, 0, 0.0)',
#  'ClassRoom(エンジニアの未来を考えるMeetup「驚くほど簡単なAI開発」, 95, 34, 0.35789473684210527)',
#  'ClassRoom(OpenCensus meetup vol.1, 0, 5, 1)',
#  'ClassRoom(Docker Workshop in Kyoto #03, 20, 13, 0.65)',
#  'ClassRoom(【初心者向け】HTML/CSS/Java Script/GAS/Python総復習！初参加も大歓迎, 11, 3, 0.2727272727272727)',
#  'ClassRoom(3D CADを使いこなそう勉強会, 0, 0, 1)',
#  'ClassRoom(Hash Tech Meeting #3 【OFC 2019 報告会】, 50, 0, 0.0)',
#  'ClassRoom(【満席御礼】第1回 サブスタンスワークフロー会, 50, 50, 1.0)',
#  'ClassRoom(Repro Tech #7 Practical AI Supported by NAVITIME, 70, 59, 0.8428571428571429)',
#  'ClassRoom(Cogbot 勉強会 Special ★ LINE から話せる楽しいチャットボットを作ろう！, 130, 46, 0.35384615384615387)',
#  'ClassRoom(R言語データ分析入門, 3, 0, 0.0)',
#  'ClassRoom(Pythonによる勾配ブースティング【入門編】, 3, 1, 0.3333333333333333)',
#  'ClassRoom(業務システムデザイン勉強会, 25, 34, 1.36)',
#  'ClassRoom(HTML5再入門講座, 25, 20, 0.8)',
#  'ClassRoom(C++20を相談しながら調べる会, 10, 10, 1.0)',
#  'ClassRoom(G Suiteを磨きたい！使い倒したい！みんなでナレッジをシェアしましょう, 5, 0, 0.0)',
#  'ClassRoom(EC-CUBE東京ユーザグループ開発者向け勉強会4月, 75, 3, 0.04)',
#  'ClassRoom(麻布十番もくもく会（フルスタックなCTOに質問可能）, 8, 3, 0.375)',
#  'ClassRoom(【CEO監修】プログラミング未経験から月50万稼げるエンジニアになる方法, 50, 1, 0.02)',
#  'ClassRoom(【非エンジニア向け】Freelance Engineer Conference, 50, 0, 0.0)',
#  'ClassRoom(ポケラボオリジナルの組織で創り上げる『SINoALICE -シノアリス-』アート発注・制作の裏側, 30, 19, 0.6333333333333333)',
#  'ClassRoom(2019 アジャイル事業部 新年度のご挨拶, 25, 6, 0.24)',
#  'ClassRoom(【4/5(金) 19:00-現在11名 】クリエイター&エンジニア交流会【新宿】, 20, 4, 0.2)',
#  'ClassRoom(ブロックチェーンのビジネス利用入門, 40, 0, 0.0)',
#  'ClassRoom(【大阪開催】実例で知るAI/ディープラーニング活用最前線, 5, 0, 0.0)',
#  'ClassRoom(【東京開催】実例で知るAI/ディープラーニング活用最前線, 5, 0, 0.0)',
#  'ClassRoom(【Raspberry Pi + AI + IoT】人工知能を使ったリアルタイム物体検出, 2, 1, 0.5)',
#  'ClassRoom(Azure Functions と キューで構築するNoOpsスケーラブルバッチ処理基盤, 8, 2, 0.25)',
#  'ClassRoom(仮想空間のビジネス活用, 10, 0, 0.0)',
#  'ClassRoom(プログラミング・エラーなんかコワくない??, 15, 7, 0.4666666666666667)',
#  'ClassRoom(ID-based Security イニシアティブ\u3000第5回全体ミーティング, 100, 41, 0.41)',
#  'ClassRoom(【福岡】CircleCI ユーザーコミュニティミートアップ #1, 50, 9, 0.18)',
#  'ClassRoom(Firebase ハンズオン in 愛媛, 14, 13, 0.9285714285714286)',
#  'ClassRoom(Houdini 17.5 東京セミナー, 100, 68, 0.68)',
#  'ClassRoom(建設・不動産×IT Meetup\u3000～レガシーな業界を変えるテクノロジーの最前線～, 45, 45, 1.0)',
#  'ClassRoom(第16回4月ゆるもく合宿, 0, 1, 1)',
#  'ClassRoom(■U-29■フリーランス？会社員？悩める若手エンジニアの会, 15, 0, 0.0)',
#  'ClassRoom(Amazon EC2 F1インスタンス入門ワークショップ(4月開催分), 20, 13, 0.65)',
#  'ClassRoom(【店舗をお持ちの企業限定】ローカル検索を最適化, 5, 0, 0.0)',
#  'ClassRoom(【初！広島開催！】RPA勉強＆LT会！RPALT 広島 vol.01, 43, 14, 0.32558139534883723)',
#  'ClassRoom(アジャイルコーチング読書会 第4回(外苑前), 0, 4, 1)',
#  'ClassRoom(第3回データベース比較セミナー, 80, 86, 1.075)',
#  'ClassRoom(テストもぐもぐ会\u3000～2019 春の陣～, 20, 1, 0.05)',
#  'ClassRoom(Unityゆるゆる勉強会#3, 7, 4, 0.5714285714285714)',
#  'ClassRoom(Otemachi.swift #03, 56, 34, 0.6071428571428571)',
#  'ClassRoom(第12回CAE勉強会&相談会, 0, 4, 1)',
#  'ClassRoom(DevRel Meetup in Tokyo #40 〜オウンドメディア成功の秘訣〜, 45, 37, 0.8222222222222222)',
#  'ClassRoom(【CoderDojo生駒】：子ども向けプログラミング道場（No.34）, 32, 7, 0.21875)',
#  'ClassRoom(上越TechMeetup #3, 35, 9, 0.2571428571428571)',
#  'ClassRoom(4/21子どもの無料プログラミングサークル【第1回CoderDojo溝口】(川崎,初心者歓迎), 10, 8, 0.8)',
#  'ClassRoom(第2回CoderDojo小机, 0, 0, 1)',
#  'ClassRoom(【増枠】RPA勉強＆LT会！RPALT 大阪 vol.03, 103, 93, 0.9029126213592233)',
#  'ClassRoom(4/17（水）デザイン×呼び方 -「見た目」の話を抜け出そう, 10, 0, 0.0)',
#  'ClassRoom(beststagemoku #04 DjangoからVue(Nuxt)もくもく会, 12, 2, 0.16666666666666666)',
#  'ClassRoom(Introducing EventStorming読書会@西新宿#3, 10, 4, 0.4)',
#  'ClassRoom(Oct Drink up at RubyKaigi 2019 in Fukuoka, 30, 3, 0.1)',
#  'ClassRoom(Cloud Native Okayama #01, 30, 11, 0.36666666666666664)',
#  'ClassRoom(ProDevelopers GameJam #1, 40, 0, 0.0)',
#  'ClassRoom(SMETA  FREELANCE NIGHT #1 〜フリーランス与信問題について語らナイト！〜, 50, 6, 0.12)',
#  'ClassRoom(【Launch 記念】Visual Studio 2019 を試してみる会, 48, 30, 0.625)',
#  'ClassRoom((若手)もくもく会＠静岡, 10, 1, 0.1)',
#  'ClassRoom(Mercari GDC 2019 報告会, 70, 0, 0.0)',
#  'ClassRoom(【メンター、見学受付専用】第1回CoderDojo日吉, 0, 0, 1)',
#  'ClassRoom(#ふくばねてす node-1, 35, 37, 1.0571428571428572)',
#  'ClassRoom(【増枠】GYOMU Hackers Night vol.13 おすすめのSaaS教えます, 45, 48, 1.0666666666666667)',
#  'ClassRoom(第1回CoderDojo日吉, 10, 0, 0.0)',
#  'ClassRoom(Python Boot Camp in 福井, 18, 6, 0.3333333333333333)',
#  'ClassRoom(（第31回SOIL水曜セミナー）はじめようARCore, 8, 2, 0.25)',
#  'ClassRoom(Azure DevOps Tokyo, Japan 4th answer, 100, 98, 0.98)',
#  'ClassRoom(【CTOmeetup】kubernetes（k8s）導入とその後, 40, 0, 0.0)',
#  'ClassRoom(Satellite Hack #5, 70, 29, 0.4142857142857143)',
#  'ClassRoom(【京都開催】AI活用ユーザー事例の紹介, 3, 1, 0.3333333333333333)',
#  'ClassRoom(【名古屋開催】AI活用ユーザー事例の紹介, 3, 0, 0.0)',
#  'ClassRoom(【マッチング特集】アドフラウドとアプリ内マーケティングからみるアプリマーケティング最前線！, 40, 6, 0.15)',
#  'ClassRoom(AI業界エンジニア向け\u3000最短・最速でスキルアップする方法セミナー 4/9(火）, 10, 12, 1.2)',
#  'ClassRoom(Chatwork Café 東京 Vol.4「Chatworkで働き方改革＆LT会！」, 35, 32, 0.9142857142857143)',
#  'ClassRoom(AI業界のプリセールス職・セールスコンサルタントになる方法セミナー 4/2(火）, 10, 8, 0.8)',
#  'ClassRoom(BPLL #32, 0, 4, 1)',
#  'ClassRoom(【AI】第1回 初学者向け ビジネスへのAI活用勉強会 in 名古屋, 20, 0, 0.0)',
#  'ClassRoom(LINE Things触ってみようハンズオン, 13, 32, 2.4615384615384617)',
#  'ClassRoom(Sansan Software Architecture Meetup Kyoto, 15, 11, 0.7333333333333333)',
#  'ClassRoom(MySQL Technology Cafe #3, 55, 40, 0.7272727272727273)',
#  'ClassRoom(ブランドを理解し自分ブランドを見つけるワークショップ, 13, 1, 0.07692307692307693)',
#  'ClassRoom(4月28日【初心者向け】LoomのSDKを活用しDappsを作成する, 22, 0, 0.0)',
#  "ClassRoom(大人の数学リベンジ！第7限「ユークリッド原論 第1回」Euclid's Elements, 10, 1, 0.1)",
#  'ClassRoom(Automation Anywhere RPA体験セミナー＠銀座オフィス, 5, 0, 0.0)',
#  'ClassRoom(【eLV勉強会】 ICTを支える「考え方」シリーズ：S00 ICTにおける学術分野統合学習の必然性, 25, 37, 1.48)',
#  'ClassRoom(Webクリエイターのための勉強会 vol.1, 15, 2, 0.13333333333333333)',
#  'ClassRoom(VoiceUIライトニングトーク！/ VUILT vol.8 @アイリッジ, 57, 77, 1.3508771929824561)',
#  'ClassRoom(@大阪淀屋橋開催\u3000第14回 文系のための「統計超入門セミナー」 ～目で見てわかるビジネス統計学, 6, 3, 0.5)',
#  'ClassRoom(Women Techmakers Kyushu vol.7 - もくもく会 -, 15, 6, 0.4)',
#  'ClassRoom(OSSのプロジェクト管理「Redmine」ベースに必要機能を包括する「Easy Redmine」とは, 3, 0, 0.0)',
#  'ClassRoom(経済産業省「DXレポート」の解説と、「2025年の崖」の克服, 3, 3, 1.0)',
#  'ClassRoom(ROS Japan UG #29 ROS2講習会, 50, 47, 0.94)',
#  'ClassRoom(ぎのわん勉強会 #8 春のプログラミング言語まつり, 23, 6, 0.2608695652173913)',
#  'ClassRoom(【東京：高円寺】テスト駆動飲み会 -Test Driven Drinking-【4/01】, 20, 8, 0.4)',
#  'ClassRoom([学生無料]未経験からのPythonプログラミング入門6回目-ディープラーニング編\u3000札幌校, 9, 0, 0.0)',
#  'ClassRoom(Nefrock勉強会in大岡山「宇宙アイディアソン」, 15, 0, 0.0)',
#  'ClassRoom(Rustもくもく会@八丁堀\u3000２, 10, 3, 0.3)',
#  'ClassRoom(AI・IoTを活用したい人のためのIPネットワーク入門, 0, 2, 1)',
#  'ClassRoom(Code for Oita シビックハックナイト #49, 10, 0, 0.0)',
#  'ClassRoom(Nutanix Meetup #38 ～どんと来いHCI初心者～, 100, 36, 0.36)',
#  'ClassRoom(cluster.unity #1, 1004, 132, 0.13147410358565736)',
#  'ClassRoom(SORACOM Drinkup #1 - SORACOM Lagoon, 33, 0, 0.0)',
#  'ClassRoom(DevRel/Community #2, 30, 21, 0.7)',
#  'ClassRoom(もくもく執筆会☆出張版 REV.20 @ 神田神保町 〜技術系同人誌／商業誌・発表資料・ブログ〜, 0, 20, 1)',
#  'ClassRoom(純粋関数型データ構造読書会 第23回, 6, 1, 0.16666666666666666)',
#  'ClassRoom(Kubernetes Meetup Tokyo #18, 195, 18, 0.09230769230769231)',
#  'ClassRoom(【デモ】iPadで AI:人工知能・ML:機械学習を体験, 20, 7, 0.35)',
#  'ClassRoom(実践者向けディープラーニング勉強会\u3000第二回, 50, 29, 0.58)',
#  'ClassRoom(オトナのキャッシュレス勉強会(JP_Stripes 熊本 #1), 23, 13, 0.5652173913043478)',
#  'ClassRoom(最終回 初心者向け Ruby on Rails 勉強会 in 門前仲町, 15, 5, 0.3333333333333333)',
#  'ClassRoom(第12回 初心者向け Ruby on Rails 勉強会 in 門前仲町, 15, 5, 0.3333333333333333)',
#  'ClassRoom(PORT Firebase x Stripe, 41, 0, 0.0)',
#  'ClassRoom(iOSアプリの仕組み・UIViewController, 15, 7, 0.4666666666666667)',
#  'ClassRoom(Azureもくもく会@新宿 No.30, 16, 5, 0.3125)',
#  'ClassRoom(【初心者向け】Laravel（PHPフレームワーク）入門②, 15, 3, 0.2)',
#  'ClassRoom([秋葉原] 第6回 はじめてのディープラーニングLT会（発表・LT大歓迎！）, 12, 11, 0.9166666666666666)',
#  'ClassRoom(Pythonのもくもく会とボランティア\u3000#42, 6, 0, 0.0)',
#  'ClassRoom(Pythonのもくもく会とボランティア\u3000#41, 6, 0, 0.0)',
#  'ClassRoom(Mobile Act Kyoto #1, 28, 0, 0.0)',
#  'ClassRoom(Global AI Nights Osaka, 46, 56, 1.2173913043478262)',
#  'ClassRoom(【東京】はじめてのRPA～ハンズオンセミナー＠銀座4/12開催, 8, 1, 0.125)',
#  'ClassRoom(【東京】はじめてのRPA～ハンズオンセミナー＠銀座4/23開催, 8, 0, 0.0)',
#  'ClassRoom(IIJmio meeting 23 大阪会場, 120, 112, 0.9333333333333333)',
#  'ClassRoom(マグロを堪能する会 in Tokyo #03, 12, 4, 0.3333333333333333)',
#  'ClassRoom(ガツン！IT部（第四回）, 8, 0, 0.0)',
#  'ClassRoom(IoT寺子屋：深層学習の数学勉強会(1)_演習分厚版_0407, 10, 10, 1.0)',
#  'ClassRoom(4/20 午前の部 Artで学ぶプログラミング はじめてクラス in 本郷三丁目, 20, 3, 0.15)',
#  'ClassRoom(ブロックチェーンでビジネスチャンスをつかむ！第３回 - 仮想通貨周辺・金融, 20, 0, 0.0)',
#  'ClassRoom(酔いどれ設計ナイト2019, 9, 2, 0.2222222222222222)',
#  'ClassRoom(集まれ！Web系やきうLT大会, 30, 18, 0.6)',
#  'ClassRoom(CoderDojo枚方\u3000第25回子ども向けプログラミングワークショップ, 4, 0, 0.0)',
#  'ClassRoom(【新大阪】MotionBoardマイスターになろう！大阪 #3, 20, 15, 0.75)',
#  'ClassRoom(【上級者も歓迎】ハンズオンで学ぶ実践的ベイズ統計モデリング【発展編】, 5, 2, 0.4)',
#  'ClassRoom(Tokyo Quantopian User Group Vol.07 コンテストに応募しよう！, 15, 7, 0.4666666666666667)',
#  'ClassRoom(第39回 平日夜から五反田もくもく会（駆け出しエンジニア or 初心者\u3000非エンジニア歓迎, 7, 1, 0.14285714285714285)',
#  'ClassRoom(自然言語処理を体系的に学べる講座【全4回】, 3, 0, 0.0)',
#  'ClassRoom(第15回-Nomikai KYOTO ゲーム業界交流会, 0, 1, 1)',
#  'ClassRoom(【シューマイ】もくもく花見会, 21, 6, 0.2857142857142857)',
#  'ClassRoom(第三十二回 Azureもくもく会 @ 品川, 30, 7, 0.23333333333333334)',
#  'ClassRoom(Emscripten & WebAssembly night !! #7, 68, 49, 0.7205882352941176)',
#  'ClassRoom(ゆるゆるもくもく会 特別編 - お花見タイカイ2019 -, 20, 18, 0.9)',
#  'ClassRoom(『サブスクリプションアプリ』のマーケティング戦略, 20, 7, 0.35)',
#  'ClassRoom(#ssmjp 2019/04, 105, 8, 0.0761904761904762)',
#  'ClassRoom(ScratchDojo 原\u3000…N002, 0, 8, 1)',
#  'ClassRoom(ScratchDojo 原\u3000…N001, 0, 13, 1)',
#  'ClassRoom(第8回 CoderDojo厚木, 0, 0, 1)',
#  'ClassRoom(現5名【4/14(日)14時～】デザイナー、WEB、イラスト、エンジニア関連のクリエイター交流会, 30, 1, 0.03333333333333333)',
#  'ClassRoom(【初心者向け】Laravel（PHPフレームワーク）入門, 15, 11, 0.7333333333333333)',
#  'ClassRoom(第１２８回 三鷹ハードウェアエンジニアカフェ, 8, 1, 0.125)',
#  'ClassRoom(im@sparqlハンズオン, 23, 5, 0.21739130434782608)',
#  'ClassRoom(WordPress, Adobe Illustrator/Photoshop：初心者向けフリー勉強会, 6, 1, 0.16666666666666666)',
#  'ClassRoom(日本Androidの会浜松支部 第93回ミーティング, 20, 1, 0.05)',
#  'ClassRoom(第39回CoderDojo浜松, 0, 5, 1)',
#  'ClassRoom(第３回 CoderDojo 六ツ野, 6, 0, 0.0)',
#  'ClassRoom(Nagoya.Swift+ 4月度勉強会, 15, 5, 0.3333333333333333)',
#  'ClassRoom(SBCamp. CMS をつかってみよう WordPressハンズオン！, 10, 2, 0.2)',
#  'ClassRoom(第16回 子どもためのプログラミング道場 - CoderDojo 立川, 10, 14, 1.4)',
#  'ClassRoom(濱せっく 出張版 #6, 45, 157, 3.488888888888889)',
#  'ClassRoom(【4/5(金) 19:00- 】クリエイター&エンジニア交流会【新宿】, 20, 0, 0.0)',
#  'ClassRoom(Sphinx+翻訳 Hack-a-thon 2019.04, 16, 3, 0.1875)',
#  'ClassRoom(Shonan.pyもくもく会 #13, 12, 4, 0.3333333333333333)',
#  'ClassRoom(DeFi Meetup #2, 25, 0, 0.0)',
#  'ClassRoom(進捗確認会(4), 10, 1, 0.1)',
#  'ClassRoom(CoderDojo伊那 #001, 0, 2, 1)',
#  'ClassRoom(【宇都宮】プログラミングもくもく会 #1, 10, 6, 0.6)',
#  'ClassRoom(低レベル勉強会2019年4月, 10, 0, 0.0)',
#  'ClassRoom(#14  WP ZoomUP （仮題）アクセシビリティ, 1100, 28, 0.025454545454545455)',
#  'ClassRoom(第25回 CoderDojo 新羽, 9, 7, 0.7777777777777778)',
#  'ClassRoom(第7回 CoderDojo保土ヶ谷, 10, 4, 0.4)',
#  'ClassRoom(VSCode の深イイ話 ~おすすめsettingとか、拡張機能の作り方とか...~, 20, 18, 0.9)',
#  'ClassRoom(Mix Leap Study #40 - Spring BootベースのDDDサンプル徹底解説！, 150, 150, 1.0)',
#  'ClassRoom(Craft もくもく会 #3, 15, 5, 0.3333333333333333)',
#  'ClassRoom(4/6 Artで学ぶProgramming【FLAP&PLAY】 はじめてクラス in吉祥寺, 20, 0, 0.0)',
#  'ClassRoom(実践Scala入門読書会 with モブプログラミング 2019/4, 14, 2, 0.14285714285714285)',
#  'ClassRoom(4月12日\u3000アニメ作成ワークショップ\u3000in\u3000横浜バンガロー, 6, 0, 0.0)',
#  'ClassRoom(IoT もくもく会 KOIL vol.30, 16, 3, 0.1875)',
#  'ClassRoom(Shinjukuもくもくプログラミング #42, 13, 3, 0.23076923076923078)',
#  'ClassRoom(【AIジョブカレ勉強会】数式と実装から復習するツリーアルゴリズム2, 20, 11, 0.55)',
#  'ClassRoom(4/21 子どもプログラミングサークル CoderDojo 鴨居 vol.07, 8, 1, 0.125)',
#  'ClassRoom(第86回 ProofCafe, 0, 2, 1)',
#  'ClassRoom(鎌倉Pythonもくもく会 #5, 5, 0, 0.0)',
#  'ClassRoom(Android相談会 vol.1, 10, 5, 0.5)',
#  "ClassRoom(International Women's Day, 50, 0, 0.0)",
#  'ClassRoom(個人でWEBサービス作ってる人であつまる「もくもく会」, 9, 1, 0.1111111111111111)',
#  'ClassRoom(LINE Developer Community : 第 2 回 ボット自慢 LT 大会, 29, 32, 1.103448275862069)',
#  'ClassRoom(やまぐちウェブまわり勉強会 #3 もくもく会, 6, 3, 0.5)',
#  'ClassRoom(HackerzLab.博多 Vol20, 40, 0, 0.0)',
#  'ClassRoom(RubyKaigi 2019 前夜祭 - Ippudo Party!! -, 45, 25, 0.5555555555555556)',
#  'ClassRoom(第51回【フリースタイル】PORTもくもく会【学生歓迎！】, 55, 22, 0.4)',
#  'ClassRoom(Rust Book 勉強会 #7, 15, 5, 0.3333333333333333)',
#  'ClassRoom(CorpTech Lounge #1, 50, 0, 0.0)',
#  'ClassRoom(プログラミング道場 CoderDojo甲斐竜王 #9, 10, 1, 0.1)',
#  'ClassRoom(第10回CoderDojo静岡, 24, 20, 0.8333333333333334)',
#  'ClassRoom(MikanLT #4, 16, 2, 0.125)',
#  'ClassRoom(Women Techmakers Tokyo Dinner Party 2019, 120, 42, 0.35)',
#  'ClassRoom(ソフトウェア開発もくもく会\u3000#5, 6, 1, 0.16666666666666666)',
#  'ClassRoom(CoderDojo天白-N045, 0, 9, 1)',
#  'ClassRoom(CoderDojo天白-N044, 0, 10, 1)',
#  'ClassRoom(第2回 HTTP/3 研究会, 6, 4, 0.6666666666666666)',
#  'ClassRoom(WTDC Meeting #01, 20, 9, 0.45)',
#  'ClassRoom(【熊本】DataVizualizationもくもく会, 10, 1, 0.1)',
#  'ClassRoom(Cocoa.swift 2019-04 （macOS/iOSアプリケーション開発勉強会）, 10, 4, 0.4)',
#  'ClassRoom(Code and Response Day Numazu, 15, 1, 0.06666666666666667)',
#  'ClassRoom(【初心者向け】ソフトウェアテスト・品質勉強会 Ver3.4【いまさら聞けないテスト・品質の基礎】, 90, 101, 1.1222222222222222)',
#  'ClassRoom(Rancher k3s もくもく勉強会 #02, 10, 14, 1.4)',
#  'ClassRoom(Meguro.LYAHFGG #2, 10, 3, 0.3)',
#  'ClassRoom(スタートアップ向け人事労務セミナー, 10, 0, 0.0)',
#  'ClassRoom(Mobile Act NAGOYA #15, 25, 5, 0.2)',
#  'ClassRoom(【ハンズオン】WebGLで動く3DブラウザゲームをPlayCanvasで簡単に作っちゃおう, 10, 7, 0.7)',
#  'ClassRoom(ブロックチェーンMeet Up in OSAKA 第1回「データ経済は民主化できるか？」, 80, 29, 0.3625)',
#  'ClassRoom(サウナdeもくもく会 in スカイスパYOKOHAMA, 10, 5, 0.5)',
#  'ClassRoom(【4月11日福岡開催】ＡＩも見た目が９割！？ 〜画像認識ＡＩで遊んでみよう〜, 15, 7, 0.4666666666666667)',
#  'ClassRoom(【4/18 新橋】効果抜群！アニメーションで作るPR動画！, 10, 1, 0.1)',
#  'ClassRoom(【4/16 藤沢】効果抜群！アニメーションで作るPR動画！, 6, 0, 0.0)',
#  'ClassRoom(【4月18日開催】ＡＩも見た目が９割！？ 〜画像認識ＡＩで遊んでみよう〜, 15, 4, 0.26666666666666666)',
#  'ClassRoom(ラズパイ初心者の会 vol.6 ～GLORIAを聞きながらラズパイじゃなくてWebAPIをイジる～, 15, 13, 0.8666666666666667)',
#  'ClassRoom(DIST.26 「Webサービスの個性を支えるデザイン」, 155, 178, 1.1483870967741936)',
#  'ClassRoom(体を動かそう！クリエイター卓球部 #9, 24, 3, 0.125)',
#  'ClassRoom(Perl入学式 in東京 春開講 第1回 〜環境構築編〜, 20, 9, 0.45)',
#  'ClassRoom(PWAハンズオン, 60, 72, 1.2)',
#  'ClassRoom(ものづくりの『今』を知る, 10, 1, 0.1)',
#  'ClassRoom(ECサイト成功の鍵を握る秘訣を伝授！サイト制作から集客・購入率UPのメソッド公開, 80, 18, 0.225)',
#  'ClassRoom(JAWS-UG アーキテクチャ専門支部 議論会, 17, 15, 0.8823529411764706)',
#  'ClassRoom(BtoBスタートアップのブランディングイベント#01, 85, 55, 0.6470588235294118)',
#  'ClassRoom(IIJmio meeting 23 東京会場, 250, 241, 0.964)',
#  'ClassRoom(#JBUG (東京#9) 春の新ネタ プロジェクトマネジメント, 46, 40, 0.8695652173913043)',
#  'ClassRoom([機械学習/DL/TDA]ReNom User Group (RNUG) #11, 80, 49, 0.6125)',
#  'ClassRoom(Drupal Meetup Tokyo #32 - April 2019, 16, 6, 0.375)',
#  'ClassRoom(【寿司懇親会付き】企業で活用されるAI技術 #7, 24, 0, 0.0)',
#  'ClassRoom(VoiceWorld Z Meetup vol.4  こころの声・感情を 知って使って元気になろう！, 43, 23, 0.5348837209302325)',
#  'ClassRoom(ブロックチェーンでビジネスチャンスをつかむ！第２回 - ビットコイン・仮想通貨の基礎知識, 20, 0, 0.0)',
#  'ClassRoom(ブロックチェーンでビジネスチャンスをつかむ！第１回 - ブロックチェーンの技術概観, 20, 0, 0.0)',
#  'ClassRoom(ブロックチェーンでビジネスチャンスをつかむ！第４回 - 非金融・トークンエコノミー, 20, 1, 0.05)',
#  'ClassRoom(2019年 SPRING「WEB TOUCH MEETING」懇親会, 20, 18, 0.9)',
#  'ClassRoom(寺子屋 at CoderDojo 下北沢, 6, 0, 0.0)',
#  'ClassRoom(体験会 at CoderDojo 下北沢, 6, 0, 0.0)',
#  'ClassRoom(寺子屋 at CoderDojo 下北沢, 6, 0, 0.0)',
#  'ClassRoom(UXを踏まえた UIガイドライン作成の心得(第8回)：ワークショップ, 20, 5, 0.25)',
#  'ClassRoom(【第6回】ビジネス・UXに役立つビジュアル化ワークショップ：基礎, 30, 30, 1.0)',
#  'ClassRoom(Android＆iOS もくもく会 in eureka #8, 20, 11, 0.55)',
#  'ClassRoom(.NETのエンタープライズアプリケーションアーキテクチャ読書会 Vol.18, 20, 7, 0.35)',
#  'ClassRoom(第22回 セキュリティ共有勉強会（テーマ:インシデント対応）, 44, 69, 1.5681818181818181)',
#  'ClassRoom(2019/4/6 CoderDojo港北ニュータウン第4回@横浜センター南駅, 0, 5, 1)',
#  'ClassRoom(RubyKaigi 2019 コード懇親会, 45, 34, 0.7555555555555555)',
#  'ClassRoom(【導入検討企業限定】SIer不要、自社でRPAを導入・活用するためには？, 2, 1, 0.5)',
#  "ClassRoom(Hacker's GATE もくもく会 #24, 5, 0, 0.0)",
#  'ClassRoom(イイラボ 秋葉原もくもく会 in コワーキングスペースRampart #04, 20, 2, 0.1)',
#  'ClassRoom(アプリマーケティング最前線！アドフラウド対策とアプリ内マーケティングによる新規ユーザ獲得から定着まで, 40, 10, 0.25)',
#  'ClassRoom(【大阪・梅田】エンジニアもくもく勉強会4月 ＠ RAKUS, 10, 3, 0.3)',
#  'ClassRoom(長野版IoT縛りの勉強会 IoTLT長野 vol.2, 20, 3, 0.15)',
#  'ClassRoom(【大阪】はじめてのRPA ~ ハンズオンセミナー@WeWorkなんばスカイオ 4/5開催, 4, 4, 1.0)',
#  'ClassRoom(体験最終回！Processingで学ぶArt × Programming 90分無料体験講座！, 7, 0, 0.0)',
#  'ClassRoom(IoTを体感出来るハンズオン【無料】, 9, 5, 0.5555555555555556)',
#  'ClassRoom(緊急開催！[LINE チャネル対応記念]開発ツール不要で作れるお手軽LINE ボット体験セミナー, 60, 47, 0.7833333333333333)',
#  'ClassRoom(大阪Pythonの会 #20, 20, 4, 0.2)',
#  'ClassRoom(基礎から応用やトレンドまで学ぶ量子コンピューティング入門セミナー #2, 8, 4, 0.5)',
#  'ClassRoom(Web Creators MeetUp 新卒・若手登壇ビアバッシュLT会 #10, 45, 13, 0.28888888888888886)',
#  'ClassRoom(第15回 Python勉強会@仙台, 15, 4, 0.26666666666666666)',
#  'ClassRoom(PHP.Sendai#16, 15, 1, 0.06666666666666667)',
#  'ClassRoom(IOSTech Hack The 1st - IOST ハッカソン, 15, 0, 0.0)',
#  'ClassRoom(現役社員と半日で学ぶ、開発ワークショップ！「JavaScriptでテトリスを作ろう！」の会, 4, 16, 4.0)',
#  'ClassRoom(Pythonもくもく会 in 名古屋 #3, 18, 5, 0.2777777777777778)',
#  'ClassRoom(Flutterもくもく自習室 in スタディプラス #2, 0, 1, 1)',
#  'ClassRoom(【第3回目】プログラミング名古屋もくもく会, 11, 4, 0.36363636363636365)',
#  'ClassRoom(【大阪・梅田】WEB系言語もくもく会＋交流, 15, 1, 0.06666666666666667)',
#  'ClassRoom(『実用Common Lisp』読書会(29), 40, 2, 0.05)',
#  'ClassRoom(【メンター募集】第2回 CoderDojoとよなか 2019/04/07(Sun), 8, 0, 0.0)',
#  'ClassRoom(第2回 CoderDojoとよなか（豊中）2019/04/07(Sun), 10, 0, 0.0)',
#  'ClassRoom(IBM Cloud Community Summit 2019.04 打ち合わせ #10, 0, 2, 1)',
#  'ClassRoom(IBM Cloud Community Summit 2019.04 打ち合わせ #9, 0, 2, 1)',
#  'ClassRoom(IBM Cloud Community Summit 2019.04 打ち合わせ #8, 0, 2, 1)',
#  'ClassRoom(IBM Cloud Community Summit 2019.04 打ち合わせ #7, 0, 3, 1)',
#  'ClassRoom(Drupal Meetup 羽田 #19, 35, 4, 0.11428571428571428)',
#  'ClassRoom(三重で働く！ITエンジニアのためのUIJターン企業説明会, 30, 0, 0.0)',
#  'ClassRoom(Salesforce女子部 Tokyo #28 〜Salesforce管理者アプリ構築のヒント〜, 50, 55, 1.1)',
#  'ClassRoom(【初参加歓迎】Webアプリ開発塾 もくもく勉強会★今週のテーマはPuppeteer, 8, 2, 0.25)',
#  'ClassRoom(【初参加歓迎】Webアプリ開発塾 もくもく勉強会★今週のテーマはTypeScript, 8, 0, 0.0)',
#  'ClassRoom(【初参加歓迎】Webアプリ開発塾 もくもく勉強会★今週のテーマはReact Hooks, 8, 1, 0.125)',
#  'ClassRoom(【無料】ゼロからはじめるPython入門講座（テックジム・オープン講座）, 5, 0, 0.0)',
#  'ClassRoom(【無料】ゼロからはじめるPython入門講座（テックジム・オープン講座）, 5, 1, 0.2)',
#  'ClassRoom(【無料】ゼロからはじめるPython入門講座（テックジム・オープン講座）, 5, 2, 0.4)',
#  'ClassRoom(【無料】ゼロからはじめるPython入門講座（テックジム・オープン講座）, 5, 2, 0.4)',
#  'ClassRoom(International IT/AI Meetup - Networking Party 4/3水, 20, 12, 0.6)',
#  'ClassRoom(お客様事例から学ぶ『マーケティングオートメーション×Salesforce活用セミナー』, 20, 0, 0.0)',
#  'ClassRoom(日本Androidの会 OSAWG 方針相談会合\u3000一般の方も参加可能です。, 20, 2, 0.1)',
#  'ClassRoom(第26回横浜Go読書会, 10, 7, 0.7)',
#  'ClassRoom(『ゲームアプリ2.0』成長を加速させるためのデータ活用最前線, 20, 0, 0.0)',
#  'ClassRoom(Goもくもく会（ごもくかい）#14, 40, 20, 0.5)',
#  'ClassRoom(Meguro.vim #15, 20, 15, 0.75)',
#  'ClassRoom(JAZUG札幌支部（きたあず） 第22回勉強会, 20, 10, 0.5)',
#  'ClassRoom(業務改善職勉強会 Vol.01, 50, 36, 0.72)',
#  'ClassRoom(【渋谷朝活】もくもく会 @la billage, 60, 1, 0.016666666666666666)',
#  'ClassRoom(【渋谷朝活】もくもく会 @la billage, 60, 1, 0.016666666666666666)',
#  'ClassRoom(Cloud Native Tokyo #01, 92, 79, 0.8586956521739131)',
#  'ClassRoom(【渋谷朝活】もくもく会 @la billage, 60, 2, 0.03333333333333333)',
#  'ClassRoom(【渋谷朝活】もくもく会 @la billage, 60, 2, 0.03333333333333333)',
#  "ClassRoom(Hacker's GATE もくもく会 #23, 5, 0, 0.0)",
#  'ClassRoom(ファウンダーが語る「toC × Big Market の最前線」 #10XTALK, 63, 0, 0.0)',
#  'ClassRoom(第17回 CoderDojo 福岡, 8, 2, 0.25)',
#  'ClassRoom(Alexa KoBuilder Challenge in Alexa Day 2019 登壇者募集!, 7, 7, 1.0)',
#  'ClassRoom(第7回\u3000Clean Architecture輪読会, 8, 5, 0.625)',
#  'ClassRoom(OSS Gate東京ミートアップ for Red Data Tools in Speee, 0, 7, 1)',
#  'ClassRoom(Agile459運営ミーティング(オンライン) 2019 #3, 10, 5, 0.5)',
#  'ClassRoom(第3回アラサー技術者交流会（テーマ：デザイン思考）, 40, 15, 0.375)',
#  'ClassRoom(2019 SPRING「WEB TOUCH MEETING」, 100, 98, 0.98)',
#  'ClassRoom(Global AI Nights Tokyo, 85, 119, 1.4)',
#  'ClassRoom(ARカメラを使ったプロモーション事例の紹介と最近のSNSマーケティング動向, 53, 1, 0.018867924528301886)',
#  'ClassRoom(Tokyo HoloLens ミートアップ vol.14, 187, 151, 0.8074866310160428)',
#  "ClassRoom(UniFa Developer's MeetUp＆LT会 #1, 20, 4, 0.2)",
#  'ClassRoom(Rancher k3s もくもく勉強会 札幌 #01, 10, 3, 0.3)',
#  'ClassRoom(Meguro.es # 20 @ Drecom, 57, 78, 1.368421052631579)',
#  'ClassRoom(＜無料RPAセミナー＞ 最新事例に学ぶ！RPAの活用方法, 15, 1, 0.06666666666666667)',
#  'ClassRoom(新規ビジネス企画をHackする勉強会, 2, 1, 0.5)',
#  'ClassRoom(AI×スマートメーターデータの活用, 30, 29, 0.9666666666666667)',
#  'ClassRoom(Global Azure Bootcamp 2019@Sendai, 20, 11, 0.55)',
#  'ClassRoom(オープンネットワーキングによるIT自動化セミナー, 11, 11, 1.0)',
#  'ClassRoom(High Performance I/O ミートアップ！, 30, 6, 0.2)',
#  'ClassRoom(売上アップに繋げるソーシャルメディアマーケティング【TTT.14】, 60, 2, 0.03333333333333333)',
#  'ClassRoom(OnTimeをさわりつくそう会\u3000第十八回, 8, 1, 0.125)',
#  'ClassRoom(ゲームアセット向けプロシージャルツール紹介セミナー\u30004月\u3000東京, 45, 40, 0.8888888888888888)',
#  'ClassRoom(第6回 Clean Architecture 読書会, 15, 10, 0.6666666666666666)',
#  'ClassRoom(iOS Test Night #10, 87, 3, 0.034482758620689655)',
#  'ClassRoom(いま押さえておくべきJavaScriptの最新機能とは？, 50, 104, 2.08)',
#  'ClassRoom(【初心者・初学者歓迎】恵比寿で学ぶJavaScript学習会 初めて〜学び直したい人など, 6, 10, 1.6666666666666667)',
#  'ClassRoom(Global Graph Celebration Day Kanazawa (金沢), 30, 5, 0.16666666666666666)',
#  'ClassRoom(みんなで情シス！第4回, 25, 28, 1.12)',
#  'ClassRoom(PR TIMES Drinkup at RubyKaigi 2019, 123, 57, 0.4634146341463415)',
#  'ClassRoom((会場変更)Pythonのもくもく会とボランティア\u3000#40, 6, 1, 0.16666666666666666)',
#  'ClassRoom((会場変更)Pythonのもくもく会とボランティア\u3000#39, 6, 1, 0.16666666666666666)',
#  'ClassRoom(CoderDojo日進 子供向けプログラミング道場\u30002019/04/13, 0, 11, 1)',
#  'ClassRoom(量子コンピューターについて語ろうLT大会＆懇親会（2019年4月）, 45, 34, 0.7555555555555555)',
#  'ClassRoom(現5名【4/3(水)19:30～】異業種×クリエイター交流会 in 吉祥寺, 20, 1, 0.05)',
#  'ClassRoom(【初心者歓迎】プログラミング相談所【毎月開催 もくもく作業でもOK】, 5, 0, 0.0)',
#  'ClassRoom(【初心者歓迎】プログラミング相談所【毎月開催 もくもく作業でもOK】, 5, 0, 0.0)',
#  'ClassRoom(Mobile Act OSAKA #9, 100, 33, 0.33)',
#  'ClassRoom(Chainer Compiler のソースコードをグダグダ語る会, 30, 0, 0.0)',
#  'ClassRoom(お茶の水ロボットクラブ：2019/4, 20, 20, 1.0)',
#  'ClassRoom(もくもく会 with トライデントワークス in 宇都宮 #2, 20, 2, 0.1)',
#  'ClassRoom(Vue.jsのサーバーレスアーキテクチャ /メディアサイト制作を進めるために知っておきたいこと, 10, 30, 3.0)',
#  'ClassRoom(GCPUG Kochi  #WEBサイトを実際にGCPで作ってみよう！, 28, 5, 0.17857142857142858)',
#  'ClassRoom(多摩地区ノンジャンルもくもく会「たまもく」#2 at SEEDPLACE, 11, 9, 0.8181818181818182)',
#  'ClassRoom(bmxug.tokyo もくもく会#9 Code Patterns, 15, 2, 0.13333333333333333)',
#  'ClassRoom(AWS .NET Developer User Group 勉強会 #1, 120, 112, 0.9333333333333333)',
#  'ClassRoom(ehime.rb（愛媛の地域 Ruby・Rails コミュニティ）, 0, 1, 1)',
#  'ClassRoom(fukuoka.R #13, 40, 15, 0.375)',
#  'ClassRoom(Global Azure Bootcamp 2019@Sapporo, 55, 10, 0.18181818181818182)',
#  'ClassRoom(Ruby on rails もくもく＆もぐもぐ会 @浜町. #11, 10, 0, 0.0)',
#  'ClassRoom([Meet Up] What is Google Cloud Platform ?, 45, 1, 0.022222222222222223)',
#  'ClassRoom(Rakuten Commerce QA Night#1, 100, 127, 1.27)',
#  'ClassRoom(第22回 たけともそん in 高円寺, 15, 15, 1.0)',
#  'ClassRoom(エンジニア向けの「ウェブ開発勉強会（HTMLから脆弱性対策まで）」＠北九州開催, 5, 9, 1.8)',
#  'ClassRoom(第9回コーダー道場名護（会場：ヒューマンキャンパス高等学校・名護本校）, 0, 4, 1)',
#  'ClassRoom(第8回コーダー道場名護（会場：名護市マルチメディア館）, 0, 4, 1)',
#  'ClassRoom((平成最後の！) サイボウズ バグハンター合宿 2019, 12, 12, 1.0)',
#  'ClassRoom(Nerima.rb #1, 10, 20, 2.0)',
#  'ClassRoom(ファシリテーション デザイン講座, 65, 2, 0.03076923076923077)',
#  'ClassRoom(【第8回】フロントエンド× ビアバッシュ初心者勉強会 酒がナイト in 銀座, 44, 10, 0.22727272727272727)',
#  'ClassRoom(“アーキテクチャとファシリテーション”ミニ解説&対話の会, 5, 1, 0.2)',
#  'ClassRoom(Visual Studio 2019 Launch Event Sendai, 20, 11, 0.55)',
#  'ClassRoom(Toyama.rb #39 もくもく会, 12, 4, 0.3333333333333333)',
#  'ClassRoom(リアルVtuberが語るフロントエンド開発入門セミナー #2, 12, 8, 0.6666666666666666)',
#  'ClassRoom(M5Stackユーザーミーティング vol.4, 108, 84, 0.7777777777777778)',
#  'ClassRoom(@大阪淀屋橋開催\u3000第15回 文系のための「統計超入門セミナー」 ～目で見てわかるビジネス統計学, 6, 2, 0.3333333333333333)',
#  'ClassRoom(4月21日【初心者向け】ERC20独自トークンを検証環境（Ropsten）にデプロイする（WebBe, 22, 0, 0.0)',
#  'ClassRoom(Open Source UN-Conference 2019 Kawagoe 当日スタッフ集合, 0, 14, 1)',
#  'ClassRoom(Open Source UN-Conference 2019 Kawagoe, 70, 26, 0.37142857142857144)',
#  'ClassRoom(TypeScript 勉強会, 21, 27, 1.2857142857142858)',
#  'ClassRoom(はじめてのGo言語教室, 16, 17, 1.0625)',
#  'ClassRoom(第6回CoderDojoあざみ野(横浜青葉), 0, 0, 1)',
#  'ClassRoom(ポートフォリオセッション, 30, 0, 0.0)',
#  'ClassRoom(イイラボ 秋葉原もくもく会 in コワーキングスペースRampart #05, 20, 0, 0.0)',
#  'ClassRoom(イイラボ 秋葉原もくもく会 in コワーキングスペースRampart #03, 20, 0, 0.0)',
#  'ClassRoom(Processing勉強会 #25, 6, 1, 0.16666666666666666)',
#  'ClassRoom(【NEM9】VUIがつくる未来, 50, 13, 0.26)',
#  'ClassRoom(NEM9 懇親会, 20, 10, 0.5)',
#  'ClassRoom(Global Graph Celebration Day Fukuoka (福岡), 20, 14, 0.7)',
#  'ClassRoom(【TECH×GAME COLLEGE#17】スマホ向け HTML5ゲームのすべて, 30, 3, 0.1)',
#  'ClassRoom(上越TechMeetup #3 懇親会, 10, 4, 0.4)',
#  'ClassRoom(CoderDojo師勝, 11, 0, 0.0)',
#  'ClassRoom(【初心者大歓迎】たった4時間でWebサイトを開発！無料プログラミング体験会, 20, 0, 0.0)',
#  'ClassRoom(【初心者大歓迎】たった4時間でゲームを開発！無料プログラミング体験会, 20, 0, 0.0)',
#  'ClassRoom(【初心者大歓迎】たった4時間でWebサイトを開発！無料プログラミング体験会, 20, 0, 0.0)',
#  'ClassRoom(Laravel LT会 with もくもく #2, 9, 7, 0.7777777777777778)',
#  'ClassRoom(RubyKaigi2019_Classi Scholarship Sponsor, 5, 0, 0.0)',
#  'ClassRoom(NaITE#31\u3000「テストレベル定義について考える」, 34, 18, 0.5294117647058824)',
#  'ClassRoom(SpringBootでマイクロサービスを作ってKubernetesにデプロイしてみる【実践編】, 30, 0, 0.0)',
#  'ClassRoom(クリエイター・デザイナー勉強会（Webデザイン、DTP、HTMLウェブコーディング）, 10, 1, 0.1)',
#  'ClassRoom(クリエイター・デザイナー勉強会（Webデザイン、DTP、HTMLウェブコーディング）, 10, 1, 0.1)',
#  'ClassRoom(Hackers:桑名（プログラミング勉強会・もくもく会）, 10, 1, 0.1)',
#  'ClassRoom(Hackers:桑名（プログラミング勉強会・もくもく会）, 10, 1, 0.1)',
#  'ClassRoom(【女性限定】月刊フィントーク その24, 10, 4, 0.4)',
#  'ClassRoom(プリッカソン #7 (プリリズ/プリパラ/プリチャン), 0, 20, 1)',
#  'ClassRoom(4月14日【初心者向け】BlockchainをGolangで実装する(WebBench), 22, 4, 0.18181818181818182)',
#  'ClassRoom(【初心者歓迎】ゆるふぁい#16 - Delphi のゆる～い集まり, 15, 3, 0.2)',
#  'ClassRoom(無料で！かんたんにディープラーニングが学べる\u3000体験コース, 12, 2, 0.16666666666666666)',
#  'ClassRoom(【福岡】ゆるっとIT vol.10「ソフトウェアテストの話を聞こう」, 48, 59, 1.2291666666666667)',
#  'ClassRoom(Angularで始めるモダンWeb開発セミナー, 24, 6, 0.25)',
#  'ClassRoom(ハシラス・オープンデイ #11 (JapanVR Fest. Special), 30, 0, 0.0)',
#  'ClassRoom(SpringBootでマイクロサービスを作ってKubernetesにデプロイしてみる【実践編】, 30, 59, 1.9666666666666666)',
#  'ClassRoom(E2F 組込みエンジニアフォーラム 第9回交流会, 0, 21, 1)',
#  'ClassRoom(第18回\u3000機械学習超入門, 6, 4, 0.6666666666666666)',
#  'ClassRoom(Power Query 秘密特訓「虎の穴」 #3, 30, 0, 0.0)',
#  'ClassRoom(第17回\u3000機械学習超入門, 6, 6, 1.0)',
#  'ClassRoom(@新橋回\u3000第2回 文系のための「統計超入門セミナー」 ～目で見てわかるビジネス統計学～, 6, 3, 0.5)',
#  'ClassRoom(【初！福岡開催！】RPA勉強＆LT会！RPALT 福岡 vol.01, 73, 28, 0.3835616438356164)',
#  'ClassRoom(第211回 文系のための「統計超入門セミナー」 ～目で見てわかるビジネス統計学～, 8, 0, 0.0)',
#  'ClassRoom(第212回 文系のための「統計超入門セミナー」 ～目で見てわかるビジネス統計学～, 8, 2, 0.25)',
#  'ClassRoom(第210回 文系のための「統計超入門セミナー」 ～目で見てわかるビジネス統計学～, 8, 1, 0.125)',
#  'ClassRoom(第209回 文系のための「統計超入門セミナー」 ～目で見てわかるビジネス統計学～, 8, 0, 0.0)',
#  'ClassRoom(＠新橋回\u3000第2回 データセンス超入門セミナー ～苦手な数字を扱うために～, 6, 1, 0.16666666666666666)',
#  'ClassRoom(第67回 データセンス超入門セミナー ～苦手な数字を扱うために～, 6, 0, 0.0)',
#  'ClassRoom(第66回 データセンス超入門セミナー ～苦手な数字を扱うために～, 6, 0, 0.0)',
#  'ClassRoom(第65回 データセンス超入門セミナー ～苦手な数字を扱うために～, 6, 0, 0.0)',
#  'ClassRoom(Nagoya.php #15, 30, 9, 0.3)',
#  'ClassRoom(Cloud Native Sapporo #02, 50, 46, 0.92)',
#  'ClassRoom(つくばPythonもくもく会(tsukuba.py) No.5, 13, 12, 0.9230769230769231)',
#  'ClassRoom(【無料4/12】インサイドセールス支援ツール「みやすい解析」で興味層への訴求に最適な営業リストの形成, 30, 1, 0.03333333333333333)',
#  'ClassRoom(やさしく学ぶ「BtoBウェブ担当者のためのGoogle アナリティクス活用戦略」, 30, 5, 0.16666666666666666)',
#  'ClassRoom(GCPUG Okinawa!#7 午前「GKEハンズオン」午後「GCPと課題解決と意思決定」, 117, 18, 0.15384615384615385)',
#  'ClassRoom(座駆動LT大会20190413, 60, 24, 0.4)',
#  'ClassRoom(Salesforce Saturday 日本橋#02, 31, 34, 1.096774193548387)',
#  'ClassRoom(【東京】ドローン × ミートアップ, 10, 0, 0.0)',
#  'ClassRoom(帰り道もくもく会＋ＩＴエンジニアとお話し会\u3000#13, 17, 3, 0.17647058823529413)',
#  'ClassRoom(出張 kintone Café 浜松 Vol.17 @袋井, 20, 7, 0.35)',
#  'ClassRoom(Data Pipeline Casual Talk Vol.2, 42, 6, 0.14285714285714285)',
#  'ClassRoom(4/5（金）デザイン x コンセプトづくり〜デザインをつくる前に考える"構想", 10, 4, 0.4)',
#  'ClassRoom(【大阪】はじめてのRPA ~ ハンズオンセミナー@WeWorkなんばスカイオ 4/12開催, 5, 0, 0.0)',
#  'ClassRoom(【4月6日14:00開催】制作物から学ぶ！共感力を生むデザインとブランディング, 60, 1, 0.016666666666666666)',
#  'ClassRoom(Robotics勉強会 in Osaka 2019 Spring, 9, 4, 0.4444444444444444)',
#  'ClassRoom(v-sapporo MeetUp #1, 25, 19, 0.76)',
#  'ClassRoom(【無料】第２回リスクマネジメントセミナー【恵比寿】, 0, 1, 1)',
#  'ClassRoom(Python3ではじめるシステムトレード入門\u3000第24回連続セミナー人工知能入門１\u3000午前の部, 5, 0, 0.0)',
#  'ClassRoom(Python3ではじめるシステムトレード入門\u3000第24回連続セミナー 人工知能入門２ 午後の部, 5, 0, 0.0)',
#  'ClassRoom(岡山IT座談会#8, 10, 2, 0.2)',
#  'ClassRoom(現代のマーケターにおくる！フレームワークから抜け出しアプリのユーザー体験向上のために必須な2つの目線, 50, 2, 0.04)',
#  'ClassRoom(京都！街歩き！マッピングパーティ：第7回 天橋立、成相寺, 4, 4, 1.0)',
#  'ClassRoom(渋茶駒玉川エンジニアLT会 #3, 18, 6, 0.3333333333333333)',
#  'ClassRoom(パターン認識と機械学習(下) by Christopher M. Bishop 輪読会 #11, 12, 8, 0.6666666666666666)',
#  'ClassRoom(スクラムチームが「自己組織化」するには？(仮), 44, 24, 0.5454545454545454)',
#  'ClassRoom(総関西サイバーセキュリティＬＴ大会（第14回）, 135, 124, 0.9185185185185185)',
#  'ClassRoom(HoudiniAid #01, 40, 33, 0.825)',
#  'ClassRoom(Umeda.go 2019 Spring, 45, 41, 0.9111111111111111)',
#  'ClassRoom(Global Azure Bootcamp 2019@Osaka, 65, 38, 0.5846153846153846)',
#  'ClassRoom(#21_メイプルもくもく会, 18, 15, 0.8333333333333334)',
#  'ClassRoom(#20_メイプルもくもく会, 18, 23, 1.2777777777777777)',
#  'ClassRoom(Tokyo Agile Community (TACO) #1 ようこそ!, 30, 23, 0.7666666666666667)',
#  'ClassRoom(【第13回】フリーなITもくもく会＠ギーク, 23, 4, 0.17391304347826086)',
#  'ClassRoom(AI開発カリキュラム『LAD』開講説明会, 0, 0, 1)',
#  'ClassRoom(第28回 CoderDojo 嘉手納, 8, 8, 1.0)',
#  'ClassRoom(4AI #2 - 機械学習(基礎 & 自然言語処理), 35, 5, 0.14285714285714285)',
#  'ClassRoom(岐阜デザイン勉強会＃1\u3000｢デザインを勉強する方法｣, 20, 11, 0.55)',
#  'ClassRoom(第25回 CoderDojo Owari, 24, 4, 0.16666666666666666)',
#  'ClassRoom(プログラミングLT 2019, 0, 31, 1)',
#  'ClassRoom(第４回CoderDojo博多, 9, 0, 0.0)',
#  'ClassRoom(絶対に手ブレさせない撮影術を学ぶ\u3000ジンバルを使ったカメラワーク講座, 15, 10, 0.6666666666666666)',
#  'ClassRoom(SalesforceSaturday 池袋 #05, 14, 12, 0.8571428571428571)',
#  'ClassRoom(同ソもくもく会 in 富山 ＃１, 10, 2, 0.2)',
#  'ClassRoom(第5回：Angular もくもく会@グンマー, 5, 1, 0.2)',
#  'ClassRoom(対応付けて学ぶデータサイエンスと戦略・マーケティング勉強会 #4, 10, 2, 0.2)',
#  'ClassRoom([京都] テクテクテック #8 サーバ監視や負荷テストどうやってるの？, 10, 12, 1.2)',
#  'ClassRoom(Salesforce Saturday 日本橋#02 懇親会, 30, 19, 0.6333333333333333)',
#  'ClassRoom(第48回 iOS馬場 #ios_baba, 15, 7, 0.4666666666666667)',
#  'ClassRoom(#VRSionUp! #3 「LavalVirtual2019公式報告会&VTuber番組技術特集」, 39, 2, 0.05128205128205128)',
#  'ClassRoom(DTPerのスクリプトもくもく会スピンオフ, 20, 0, 0.0)',
#  'ClassRoom(マーケティングオートメーション導入の成功と失敗のポイント, 20, 2, 0.1)',
#  'ClassRoom(Visual Studio 2019 Launch Event in Tokyo., 90, 160, 1.7777777777777777)',
#  'ClassRoom(Python Boot Camp in 福井 懇親会, 10, 3, 0.3)',
#  'ClassRoom(一般社団法人PyCon JP運営会議 #29, 0, 9, 1)',
#  'ClassRoom(本郷言語処理勉強会 #3, 20, 8, 0.4)',
#  'ClassRoom(日本PMO協会 2019年Spring 特別セミナー, 50, 10, 0.2)',
#  'ClassRoom(Roppongi.unity #2 in メルカリ@六本木ヒルズ, 113, 0, 0.0)',
#  'ClassRoom(#エンジニア銭湯, 26, 54, 2.076923076923077)',
#  'ClassRoom(帰り道もくもく会＋ＩＴエンジニアとお話し会\u3000#12, 17, 6, 0.35294117647058826)',
#  'ClassRoom(第22回 CoderDojo長津田, 0, 18, 1)',
#  'ClassRoom(実習編 JavaScriptで学ぶ プログラミング入門丸一日コース 4月27日（祝日）@c, 6, 0, 0.0)',
#  'ClassRoom(第10回関西Lispユーザ会, 18, 3, 0.16666666666666666)',
#  'ClassRoom(第75回オープンCAE勉強会＠関東（流体など）【大崎】, 25, 8, 0.32)',
#  'ClassRoom(那覇もくもく会 #05, 6, 2, 0.3333333333333333)',
#  'ClassRoom(AI実践入門！NVIDIA Jetson TX2×Azure GPU生体験ハンズオン@大阪TEQS, 0, 37, 1)',
#  'ClassRoom(同ソもくもく会 ＃11, 10, 5, 0.5)',
#  'ClassRoom(初心者からの3DCGデザイン・モデリング【Blender入門講習会】, 5, 0, 0.0)',
#  'ClassRoom(【拡大版】サーバー構築ハンズオン in 大阪 #102, 12, 3, 0.25)',
#  'ClassRoom(4月19日（金）\u3000IT交流会\u3000渋谷 【50名規模】, 50, 1, 0.02)',
#  'ClassRoom(はじめての英語プレゼン #8, 13, 11, 0.8461538461538461)',
#  'ClassRoom(Python Boot Camp in 和歌山 懇親会, 15, 6, 0.4)',
#  'ClassRoom(Python Boot Camp in 和歌山, 26, 14, 0.5384615384615384)',
#  'ClassRoom(IoT入門セミナー！センスウェイLoRaWANハンズオン@ひろしまCamps, 0, 16, 1)',
#  'ClassRoom(IWDD (vol.150) / アイーナ816部屋 14:00〜, 0, 1, 1)',
#  'ClassRoom(名古屋データ分析もくもく会#8, 8, 1, 0.125)',
#  'ClassRoom(技術書典6\u3000非公式アフター(4/14), 160, 92, 0.575)',
#  'ClassRoom(【eLV】ITコンサルタントへの第一歩シリーズ\u3000～セルフブランディング戦略～, 45, 63, 1.4)',
#  'ClassRoom(豊田市IT勉強会\u30004月\u3000もくもく会, 15, 2, 0.13333333333333333)',
#  'ClassRoom(【さいたま・上尾】仕組から学ぶWordPress入門講座, 12, 0, 0.0)',
#  'ClassRoom(【さいたま・上尾】仕組から学ぶWordPress入門講座, 12, 0, 0.0)',
#  'ClassRoom(【さいたま・上尾】仕組から学ぶWordPress入門講座, 12, 0, 0.0)',
#  'ClassRoom(#13 第6回 DRF勉強会 (全6回), 10, 10, 1.0)',
#  'ClassRoom(高専キャンプ in 讃岐, 267, 11, 0.04119850187265917)',
#  'ClassRoom(OWASP 北信越ミーティング \u300019年４月度, 40, 7, 0.175)',
#  'ClassRoom(Cloud Native Sapporo #02 懇親会, 15, 7, 0.4666666666666667)',
#  'ClassRoom(情シス in 新潟＃1 @Prototype Cafe, 20, 15, 0.75)',
#  'ClassRoom(みんなのPython勉強会#44, 200, 63, 0.315)',
#  'ClassRoom(ゼロからまなぶ統計学(Python編), 10, 0, 0.0)',
#  'ClassRoom(ゲームで強化学習（と組合せ最適化）がんばる会５, 55, 82, 1.490909090909091)',
#  'ClassRoom(量子ゲートで量子アニーリングをプログラミングする, 55, 66, 1.2)',
#  'ClassRoom(量子コンピュータで量子化学を全般的に見返す, 55, 61, 1.1090909090909091)',
#  'ClassRoom(衛星画像の地表面の物体認識や二値分類機, 51, 79, 1.5490196078431373)',
#  'ClassRoom(2019年度オープン「新入社員Java+AI研修」, 20, 0, 0.0)',
#  'ClassRoom(スプラウト.rb 第５８回, 0, 0, 1)',
#  'ClassRoom(第４回 関西日曜数学 友の会, 50, 14, 0.28)']
